# %% [markdown]
# # Exploring 'Hacker News' Posts - “What time should you post to receive the highest average of comments?”
# In this project, we'll work a dataset of submissions to popular technology site Hacker News.
#
# For convenience of this practice, the data has been reduced from almost 300,000 rows to approximately 20,000 rows by removing all submissions that didn't receive any comments and then randomly sampling the remaining submissions.
#
# The full data set is available right here.
#
# In our analysis we are specifically interested in posts that begin with 'Ask HN'(To ask the hacker news community about specific topics) and 'Show HN'(to show the hacker news community their projects, product or something interesting).
#
# So we will compare these two type Ask HN and Show HN to determine which one gets more reach or comments and whether the most comments are posted during a specific time of day.

# %%
from csv import reader
import datetime as dt

# %%
file = open("hacker_news.csv","r",encoding="utf-8")
a = reader(file)
hn = list(a)
headers = hn[:1]
hn = hn[1:]

# %%
file = open("hacker_news.csv","r",encoding='utf-8')

# %%
a = reader(file)
a

# %%
hn[:5]
# Out:
# [['12579008',
#   'You have two days to comment if you want stem cells to be classified as your own',
#   'http://www.regulations.gov/document?D=FDA-2015-D-3719-0018',
#   '1',
#   '0',
#   'altstar',
#   '9/26/2016 3:26'],
#  ['12579005',
#   'SQLAR  the SQLite Archiver',
#   'https://www.sqlite.org/sqlar/doc/trunk/README.md',
#   '1',
#   '0',
#   'blacksqr',
#   '9/26/2016 3:24'],
#  ['12578997',
#   'What if we just printed a flatscreen television on the side of our boxes?',
#   'https://medium.com/vanmoof/our-secrets-out-f21c1f03fdc8#.ietxmez43',
#   '1',
#   '0',
#   'pavel_lishin',
#   '9/26/2016 3:19'],
#  ['12578989',
#   'algorithmic music',
#   'http://cacm.acm.org/magazines/2011/7/109891-algorithmic-composition/fulltext',
#   '1',
#   '0',
#   'poindontcare',
#   '9/26/2016 3:16'],
#  ['12578979',
#   'How the Data Vault Enables the Next-Gen Data Warehouse and Data Lake',
#   'https://www.talend.com/blog/2016/05/12/talend-and-Â\x93the-data-vaultÂ\x94',
#   '1',
#   '0',
#   'markgainor1',
#   '9/26/2016 3:14']]

# %%
len(hn)
# Out:
# 293119

# %%
headers
# Out:
# [['id', 'title', 'url', 'num_points', 'num_comments', 'author', 'created_at']]

# %%
#Displaying header and first 5 rows of the dataset

# %%
print(headers,"\n")
for i in hn[:5]:
    print(i)
    print("\n")
# Out:
# [['id', 'title', 'url', 'num_points', 'num_comments', 'author', 'created_at']]
#
# ['12579008', 'You have two days to comment if you want stem cells to be classified as your own', 'http://www.regulations.gov/document?D=FDA-2015-D-3719-0018', '1', '0', 'altstar', '9/26/2016 3:26']
#
#
# ['12579005', 'SQLAR  the SQLite Archiver', 'https://www.sqlite.org/sqlar/doc/trunk/README.md', '1', '0', 'blacksqr', '9/26/2016 3:24']
#
#
# ['12578997', 'What if we just printed a flatscreen television on the side of our boxes?', 'https://medium.com/vanmoof/our-secrets-out-f21c1f03fdc8#.ietxmez43', '1', '0', 'pavel_lishin', '9/26/2016 3:19']
#
#
# ['12578989', 'algorithmic music', 'http://cacm.acm.org/magazines/2011/7/109891-algorithmic-composition/fulltext', '1', '0', 'poindontcare', '9/26/2016 3:16']
#
#
# ['12578979', 'How the Data Vault Enables the Next-Gen Data Warehouse and Data Lake', 'https://www.talend.com/blog/2016/05/12/talend-and-Â\x93the-data-vaultÂ\x94', '1', '0', 'markgainor1', '9/26/2016 3:14']

# %% [markdown]
# # Extracting Ask HN and Show HN posts
# To find the posts that begin with either Ask HN or Show HN, we'll use the string method startswith. Since, startswith is case sensitive, here in this project we are using lower method, to have a control on case.

# %%
ask_posts=[]
show_posts=[]
other_posts = []

for row in hn:
    title = row[1]
    
    if title.lower().startswith("ask hn"):
         ask_posts.append(row)
    
    elif title.lower().startswith("show hn"):
        show_posts.append(row)
    
    else:
        other_posts.append(row)
    
print("number of all posts",len(hn))
print("number of ask_posts",len(ask_posts))
print("number of show_posts",len(show_posts))
print("number of other_posts",len(other_posts))
# Out:
# number of all posts 293119
# number of ask_posts 9139
# number of show_posts 10158
# number of other_posts 273822

# %%
ask_posts
# Out:
# [['12578908',
#   'Ask HN: What TLD do you use for local development?',
#   '',
#   '4',
#   '7',
#   'Sevrene',
#   '9/26/2016 2:53'],
#  ['12578522',
#   'Ask HN: How do you pass on your work when you die?',
#   '',
#   '6',
#   '3',
#   'PascLeRasc',
#   '9/26/2016 1:17'],
#  ['12577908',
#   'Ask HN: How a DNS problem can be limited to a geographic region?',
#   '',
#   '1',
#   '0',
#   'kuon',
#   '9/25/2016 22:57'],
#  ['12577870',
#   'Ask HN: Why join a fund when you can be an angel?',
#   '',
#   '1',
#   '3',
#   'anthony_james',
#   '9/25/2016 22:48'],
#  ['12577647',
#   'Ask HN: Someone uses stock trading as passive income?',
#   '',
#   '5',
#   '2',
#   '00taffe',
#   '9/25/2016 21:50'],
#  ['12576946',
#   'Ask HN: How hard would it be to make a cheap, hackable phone?',
#   '',
#   '2',
#   '1',
#   'hkt',
#   '9/25/2016 19:30'],
#  ['12576899',
#   'Ask HN: What is that one deciding factor that makes a website successful?',
#   '',
#   '22',
#   '22',
#   'ziggystardust',
#   '9/25/2016 19:22'],
#  ['12576398',
#   'Ask HN: Is the world really short of software developers?',
#   '',
#   '2',
#   '3',
#   'chirau',
#   '9/25/2016 17:55'],
#  ['12575803',
#   'Ask HN: Geolocalized public API?',
#   '',
#   '1',
#   '0',
#   'andreapaiola',
#   '9/25/2016 15:48'],
#  ['12575743',
#   'Ask HN: How to sell and idea?',
#   '',
#   '12',
#   '13',
#   'hacknat',
#   '9/25/2016 15:35'],
#  ['12575717',
#   "Ask HN: Doesn't matter what p. say about U, as long as  Do You Agree?",
#   '',
#   '1',
#   '0',
#   'sztwiorok',
#   '9/25/2016 15:28'],
#  ['12575528',
#   'Ask HN: What React charting lib. do you use?',
#   '',
#   '2',
#   '0',
#   'qaq',
#   '9/25/2016 14:43'],
#  ['12575410',
#   'Ask HN: Is cloud storage a solved problem?',
#   '',
#   '3',
#   '3',
#   'boduh',
#   '9/25/2016 14:17'],
#  ['12575141',
#   'Ask HN: Can a marketer become a tech entrepreneur and start a startup?',
#   '',
#   '1',
#   '2',
#   'halninethousand',
#   '9/25/2016 13:08'],
#  ['12574867',
#   'Ask HN: Why would government security and hacking be any good?',
#   '',
#   '1',
#   '2',
#   'forgottenacc56',
#   '9/25/2016 11:27'],
#  ['12574778',
#   'Ask HN: Are Americans really ready to give up their cars?',
#   '',
#   '1',
#   '0',
#   'SQL2219',
#   '9/25/2016 10:51'],
#  ['12574759',
#   'Ask HN: Have you ever visited example.com?',
#   '',
#   '9',
#   '6',
#   'glaberficken',
#   '9/25/2016 10:47'],
#  ['12574510',
#   'Ask HN: What are the best practises for using SSH keys?',
#   '',
#   '276',
#   '97',
#   'TheCustardKing',
#   '9/25/2016 9:04'],
#  ['12574314',
#   'Ask HN: Know how transfer as a freelancer',
#   '',
#   '5',
#   '4',
#   'patatino',
#   '9/25/2016 7:09'],
#  ['12573681',
#   'Ask HN: Where can I learn more about and contribute to the AI singularity?',
#   '',
#   '1',
#   '1',
#   'DSteinmann',
#   '9/25/2016 3:00'],
#  ['12573026',
#   'Ask HN: Payment processing for group purchases?',
#   '',
#   '2',
#   '0',
#   'johnreagan',
#   '9/24/2016 23:04'],
#  ['12572838',
#   'Ask HN: What LaTeX editor do you use?',
#   '',
#   '1',
#   '7',
#   'Lxr',
#   '9/24/2016 22:02'],
#  ['12572698',
#   'Ask HN: Recommended platform for small discussion lists?',
#   '',
#   '5',
#   '2',
#   'Mz',
#   '9/24/2016 21:18'],
#  ['12572612',
#   "Ask HN: Why don't online stores display return rates for individual products?",
#   '',
#   '2',
#   '0',
#   'toennisforst',
#   '9/24/2016 20:58'],
#  ['12572353',
#   'Ask HN: Is Riak a viable alternative to Cassandra?',
#   '',
#   '5',
#   '1',
#   'nvarsj',
#   '9/24/2016 19:57'],
#  ['12572092',
#   'Ask HN: Is there a tool to observe data and notify me about significant changes?',
#   '',
#   '1',
#   '0',
#   'LukaszWiktor',
#   '9/24/2016 19:02'],
#  ['12571848',
#   'Ask HN: How do you manage server ssh fingerprints?',
#   '',
#   '1',
#   '0',
#   'IgorPartola',
#   '9/24/2016 17:55'],
#  ['12571744',
#   'Ask HN: What are the best (free if possible) Wordpress themes for coding blogs?',
#   '',
#   '2',
#   '1',
#   'kexari',
#   '9/24/2016 17:27'],
#  ['12571603',
#   'Ask HN: The best apps / devices for replacing testing done by a doctor?',
#   '',
#   '1',
#   '0',
#   'peterbsmith',
#   '9/24/2016 16:50'],
#  ['12571426',
#   'Ask HN: Why not openai hire using a kaggle competition?',
#   '',
#   '2',
#   '5',
#   'master_yoda_1',
#   '9/24/2016 16:03'],
#  ['12571287',
#   "Ask HN: What's the best way to learn about the blockchain?",
#   '',
#   '247',
#   '66',
#   'm52go',
#   '9/24/2016 15:29'],
#  ['12570947',
#   "Ask HN: If you've successfully outsourced software dev work, how did you do it?",
#   '',
#   '3',
#   '1',
#   'Mattasher',
#   '9/24/2016 14:03'],
#  ['12570310',
#   'Ask HN: Opensource alternatives to tcpdump?',
#   '',
#   '4',
#   '11',
#   'txutxu',
#   '9/24/2016 10:10'],
#  ['12570115',
#   'Ask HN: What do you think about this Android app?',
#   '',
#   '2',
#   '7',
#   'lpellegr',
#   '9/24/2016 8:46'],
#  ['12570091',
#   'Ask HN: What happened to Myra?',
#   '',
#   '2',
#   '1',
#   'heinrichf',
#   '9/24/2016 8:39'],
#  ['12570084',
#   'Ask HN: How do you learn to be in a team',
#   '',
#   '2',
#   '1',
#   'piedradura',
#   '9/24/2016 8:38'],
#  ['12570055',
#   'Ask HN: Why do we put up with such restrictive IP contracts?',
#   '',
#   '2',
#   '1',
#   'Mandatum',
#   '9/24/2016 8:28'],
#  ['12569327',
#   'Ask HN: Any bad experiences going through YC Program?',
#   '',
#   '9',
#   '3',
#   'BIackSwan',
#   '9/24/2016 3:36'],
#  ['12568846',
#   'Ask HN: How might a businesses benefit from using regular expressions?',
#   '',
#   '2',
#   '2',
#   'dr_radiaki',
#   '9/24/2016 0:21'],
#  ['12568678',
#   'Ask HN: How would you monetize this site?',
#   '',
#   '9',
#   '6',
#   'coldshower',
#   '9/23/2016 23:38'],
#  ['12568672',
#   'Ask HN: Do you subvocalize when reading code?',
#   '',
#   '7',
#   '6',
#   'anderspitman',
#   '9/23/2016 23:35'],
#  ['12568327',
#   'Ask HN: What to include in a code of ethics for tech recruiters/hiring managers?',
#   '',
#   '2',
#   '4',
#   'baron816',
#   '9/23/2016 22:13'],
#  ['12567899',
#   'Ask HN: Would you use this service?',
#   '',
#   '2',
#   '2',
#   'canatan01',
#   '9/23/2016 20:58'],
#  ['12567804',
#   'Ask HN: TaskWarrior or Org?',
#   '',
#   '1',
#   '0',
#   'qwertyuiop924',
#   '9/23/2016 20:42'],
#  ['12567681',
#   'Ask HN: Do you think a CLI-based SaaS would be useful?',
#   '',
#   '3',
#   '1',
#   'prmph',
#   '9/23/2016 20:23'],
#  ['12567645',
#   'Ask HN: What do you wish someone would build?',
#   '',
#   '171',
#   '477',
#   'prmph',
#   '9/23/2016 20:18'],
#  ['12567340',
#   'Ask HN: How 000webhost.com makes money',
#   '',
#   '1',
#   '3',
#   'xameeramir',
#   '9/23/2016 19:33'],
#  ['12567327',
#   'Ask HN: How do you get the initial traction for your web side-project?',
#   '',
#   '47',
#   '10',
#   'thakobyan',
#   '9/23/2016 19:32'],
#  ['12567079',
#   'Ask HN: Customer demanding $2400 for dirt marks on driveway, how to handle this?',
#   '',
#   '10',
#   '12',
#   'ChrisDutrow',
#   '9/23/2016 18:56'],
#  ['12567060',
#   "Ask HN: Why are humanity's large systems failing?",
#   '',
#   '9',
#   '4',
#   'alistproducer2',
#   '9/23/2016 18:53'],
#  ['12566502',
#   'Ask HN: Thinking of mentoring? looking for a mentor?',
#   '',
#   '1',
#   '1',
#   'wje',
#   '9/23/2016 17:45'],
#  ['12566428',
#   'Ask HN: East African tech incubators?',
#   '',
#   '4',
#   '1',
#   'vwcx',
#   '9/23/2016 17:35'],
#  ['12566358',
#   'Ask HN: What do you guys use to help organize daily tasks and things to do?',
#   '',
#   '11',
#   '25',
#   'gallonofmilk',
#   '9/23/2016 17:28'],
#  ['12566061',
#   'Ask HN: How to secure your internet activity (eg.emailing) when traveling?',
#   '',
#   '5',
#   '2',
#   'questionr',
#   '9/23/2016 16:56'],
#  ['12565683',
#   'Ask HN: I found a flaw in a card reader. How should I report it?',
#   '',
#   '2',
#   '3',
#   'entangld',
#   '9/23/2016 16:14'],
#  ['12564082',
#   'Ask HN: Is there an appropriate way to host advertisements on my site?',
#   '',
#   '2',
#   '6',
#   'julianj',
#   '9/23/2016 12:39'],
#  ['12563436',
#   'Ask HN: What are you using for integration testing?',
#   '',
#   '2',
#   '1',
#   'nenadg',
#   '9/23/2016 9:58'],
#  ['12562384',
#   'Ask HN: How do you count unread conversations in a messaging app?',
#   '',
#   '1',
#   '2',
#   'amingilani',
#   '9/23/2016 4:47'],
#  ['12561918',
#   'Ask HN: About making posts',
#   '',
#   '1',
#   '3',
#   'mattnumbe',
#   '9/23/2016 2:28'],
#  ['12561803',
#   'Ask HN: Any minimal framework for small website?',
#   '',
#   '5',
#   '8',
#   'damaru',
#   '9/23/2016 1:56'],
#  ['12561678',
#   'Ask HN: Alternatives for gvpr',
#   '',
#   '2',
#   '2',
#   'anderspitman',
#   '9/23/2016 1:24'],
#  ['12561677',
#   'Ask HN: How to convert free users to paid users?',
#   '',
#   '1',
#   '1',
#   'k2xl',
#   '9/23/2016 1:23'],
#  ['12561580',
#   'Ask HN: What companies offer post-hire specialist training?',
#   '',
#   '1',
#   '0',
#   'Futurebot',
#   '9/23/2016 0:58'],
#  ['12561400',
#   'Ask HN: Help with username',
#   '',
#   '2',
#   '5',
#   'bkman',
#   '9/23/2016 0:11'],
#  ['12560599',
#   "Ask HN: Do you support the United States' disengagement from ICANN?",
#   '',
#   '6',
#   '3',
#   'ibejoeb',
#   '9/22/2016 21:45'],
#  ['12560452',
#   'Ask HN: People who looked down upon Node.js/JS, has ES6/etc. changed your views?',
#   '',
#   '5',
#   '5',
#   'zuck9',
#   '9/22/2016 21:19'],
#  ['12559828',
#   'Ask HN: Hiring at crummy wage  how to make it better?',
#   '',
#   '7',
#   '19',
#   'bassmaster',
#   '9/22/2016 19:58'],
#  ['12559698',
#   'Ask HN: Advice on regaining passion at work',
#   '',
#   '2',
#   '6',
#   'throwaway_dev',
#   '9/22/2016 19:42'],
#  ['12559681',
#   'Ask HN: How to get contributions to open source project',
#   '',
#   '6',
#   '23',
#   'billziss',
#   '9/22/2016 19:40'],
#  ['12559436',
#   'Ask HN: Python: Procedural vs. Object-Oriented  what factors matter?',
#   '',
#   '2',
#   '2',
#   'dhruvkar',
#   '9/22/2016 19:18'],
#  ['12558877',
#   'Ask HN: Current state of cellular automata research?',
#   '',
#   '8',
#   '1',
#   'siavosh',
#   '9/22/2016 18:16'],
#  ['12558623',
#   'Ask HN: How big are your software projects and how much does the customer pay',
#   '',
#   '2',
#   '0',
#   'thomasctm',
#   '9/22/2016 17:43'],
#  ['12558586',
#   'Ask HN: Talent management for agile teams. Site design and product feedback',
#   'http://qrtrmstr.com/',
#   '1',
#   '0',
#   'raykanani99',
#   '9/22/2016 17:38'],
#  ['12558503',
#   'Ask HN: Best online courses on Biotech',
#   '',
#   '1',
#   '0',
#   'hjaved',
#   '9/22/2016 17:27'],
#  ['12558502',
#   'Ask HN: If you were paid to learn, 8 hours a day, what would be your routine?',
#   '',
#   '43',
#   '26',
#   'TbobbyZ',
#   '9/22/2016 17:27'],
#  ['12558305',
#   'Ask HN: Any up to date information about the Canadian Startup Visa?',
#   '',
#   '2',
#   '0',
#   'startupdiscuss',
#   '9/22/2016 17:05'],
#  ['12558029',
#   'Ask HN: Why is the FastMail mobile app so horrible?',
#   '',
#   '1',
#   '0',
#   'ryanmccullagh',
#   '9/22/2016 16:34'],
#  ['12557645',
#   'Ask HN: Who is going to the office hours and/or fireside chat in Buenos Aires?',
#   '',
#   '3',
#   '1',
#   'wslh',
#   '9/22/2016 15:44'],
#  ['12557404',
#   'Ask HN: What do you do to relax/re-energize?',
#   '',
#   '4',
#   '10',
#   'LifeQuestioner',
#   '9/22/2016 15:18'],
#  ['12557403',
#   'Ask HN: Developing a 4D VR Experience. Best Tools for the Job?',
#   '',
#   '3',
#   '1',
#   'riebschlager',
#   '9/22/2016 15:18'],
#  ['12557149',
#   'Ask HN: How do you define a Junior developer?',
#   '',
#   '66',
#   '62',
#   'guessmyname',
#   '9/22/2016 14:49'],
#  ['12556550',
#   'Ask HN: What to do with ideas?',
#   '',
#   '1',
#   '0',
#   'arisAlexis',
#   '9/22/2016 13:11'],
#  ['12556473',
#   'Ask HN: Extracting html templates from corpus of rendered html documents',
#   '',
#   '2',
#   '0',
#   'macca321',
#   '9/22/2016 12:58'],
#  ['12556465',
#   'Ask HN: Do you have any experience with burning out in the tech industry?',
#   '',
#   '1',
#   '0',
#   'thomas4567',
#   '9/22/2016 12:55'],
#  ['12556432',
#   'Ask HN: When to ask for my first raise?',
#   '',
#   '7',
#   '3',
#   'raiseta',
#   '9/22/2016 12:50'],
#  ['12556160',
#   'Ask HN: What are the must-read books about economics/finance?',
#   '',
#   '442',
#   '266',
#   'curiousgal',
#   '9/22/2016 11:52'],
#  ['12554849',
#   'Ask HN: Audio books for developers?',
#   '',
#   '2',
#   '1',
#   'source99',
#   '9/22/2016 6:25'],
#  ['12554823',
#   'Ask HN: Popular React Native apps?',
#   '',
#   '1',
#   '2',
#   'palerdot',
#   '9/22/2016 6:19'],
#  ['12554503',
#   'Ask HN: How to spend 6 months (personal development)',
#   '',
#   '3',
#   '0',
#   'doktrin',
#   '9/22/2016 5:03'],
#  ['12554473',
#   'Ask HN: Have you used eclim? How is the experience?',
#   '',
#   '1',
#   '0',
#   'bangda',
#   '9/22/2016 4:55'],
#  ['12553487',
#   'Ask HN: How will YC be helping Project Include?',
#   '',
#   '1',
#   '0',
#   'guggen',
#   '9/22/2016 0:47'],
#  ['12553221',
#   'Ask HN: Would you pay to keep your comms secure, ad-free, based on open tech?',
#   '',
#   '4',
#   '0',
#   'rglullis',
#   '9/21/2016 23:37'],
#  ['12553045',
#   'Ask HN: Domain Dispute',
#   '',
#   '19',
#   '22',
#   'nikolay',
#   '9/21/2016 23:03'],
#  ['12552303',
#   'Ask HN: How do you dive into a new framework/project?',
#   '',
#   '1',
#   '1',
#   'falloutx',
#   '9/21/2016 21:14'],
#  ['12552131',
#   'Ask HN: Best Practices for CSS in a Modern JavaScript App',
#   '',
#   '6',
#   '6',
#   'xwvvvvwx',
#   '9/21/2016 20:53'],
#  ['12551977',
#   'Ask HN: Have you played emoji movies the game in Google assistant?',
#   '',
#   '3',
#   '1',
#   'crypticlizard',
#   '9/21/2016 20:35'],
#  ['12551958',
#   'Ask HN: What behavioral biometric can be reliable for both auth. and anonymity?',
#   '',
#   '1',
#   '1',
#   'scobar',
#   '9/21/2016 20:33'],
#  ['12551428',
#   'Ask HN: What do you feel the best source of data / research based news source?',
#   '',
#   '1',
#   '1',
#   'caruana',
#   '9/21/2016 19:30'],
#  ['12551331',
#   'Ask HN: Top rules as a good-developer to stay on top of your game',
#   '',
#   '50',
#   '46',
#   'samblr',
#   '9/21/2016 19:18'],
#  ['12551006',
#   'Ask HN: Anyone interested in connecting with me?',
#   '',
#   '1',
#   '0',
#   'user321',
#   '9/21/2016 18:39'],
#  ['12550746',
#   'Ask HN: How to get a high load on a website in a short time?',
#   '',
#   '1',
#   '2',
#   'user321',
#   '9/21/2016 18:11'],
#  ['12550597',
#   'Ask HN: What products have you used regularly for years?',
#   '',
#   '6',
#   '5',
#   'neilsharma',
#   '9/21/2016 17:56'],
#  ['12550484',
#   'Ask HN: Anyone interested in connecting with a mentor?',
#   '',
#   '22',
#   '23',
#   'pan_w',
#   '9/21/2016 17:46'],
#  ['12550406',
#   'Ask HN: Is anyone having problems with Couchbase?',
#   '',
#   '1',
#   '0',
#   'base698',
#   '9/21/2016 17:36'],
#  ['12550278',
#   'Ask HN: 2017 Software Engineer Winter Internships in US/UK with Visa Sponsorship',
#   '',
#   '3',
#   '0',
#   'samparsky',
#   '9/21/2016 17:24'],
#  ['12548656',
#   'Ask HN: How do you manage your personal software projects?',
#   '',
#   '72',
#   '62',
#   'ciaoben',
#   '9/21/2016 14:50'],
#  ['12548506',
#   'Ask HN: What are the potential pitfalls of stock options?',
#   '',
#   '2',
#   '2',
#   'jonyt',
#   '9/21/2016 14:35'],
#  ['12548102',
#   'Ask HN: How would you know if there is a virus that has infected your MAC?',
#   '',
#   '2',
#   '2',
#   'Michie',
#   '9/21/2016 13:49'],
#  ['12548048',
#   "Ask HN: Fulltime software engineers over 250k, how'd you get there(updated)?",
#   '',
#   '78',
#   '61',
#   'throwaway007007',
#   '9/21/2016 13:42'],
#  ['12547510',
#   'Ask HN: Startup lottery',
#   '',
#   '6',
#   '1',
#   'broccolee',
#   '9/21/2016 12:24'],
#  ['12547458',
#   'Ask HN: Review my startup  MD in your pocket',
#   '',
#   '2',
#   '4',
#   'Aidlab',
#   '9/21/2016 12:17'],
#  ['12547351',
#   'Ask HN: Best way to crunch 3 weeks work into 2?',
#   '',
#   '2',
#   '2',
#   'kenips',
#   '9/21/2016 12:00'],
#  ['12547157',
#   'Ask HN: Technology related visit/holiday',
#   '',
#   '2',
#   '0',
#   'worldvisit',
#   '9/21/2016 11:28'],
#  ['12546932',
#   'Ask HN: Top 5 rules as a developer to stay in top your game?',
#   '',
#   '2',
#   '0',
#   'samblr',
#   '9/21/2016 10:41'],
#  ['12546705',
#   'Ask HN: How are you making JavaScript websites (not webapps)',
#   '',
#   '2',
#   '1',
#   'microman',
#   '9/21/2016 9:49'],
#  ['12546363',
#   'Ask HN: is there a cross-device calendar with tasks outside of Outlook and iOS?',
#   '',
#   '2',
#   '1',
#   'ybalkind',
#   '9/21/2016 8:26'],
#  ['12546317',
#   'Ask HN: Do I do my masters in CS if it means staying an extra semester?',
#   '',
#   '3',
#   '2',
#   'dudeget',
#   '9/21/2016 8:16'],
#  ['12546015',
#   'Ask HN: Will the future have several more programmers or a few excellent ones?',
#   '',
#   '3',
#   '10',
#   'animeshk',
#   '9/21/2016 7:12'],
#  ['12545639',
#   'Ask HN: What is the current scientific opinion on the works of Stuart Kauffman?',
#   '',
#   '1',
#   '0',
#   'siavosh',
#   '9/21/2016 5:27'],
#  ['12545522',
#   'Ask HN: How would you improve HN?',
#   '',
#   '1',
#   '2',
#   'ne01',
#   '9/21/2016 4:58'],
#  ['12545289',
#   'Ask HN: How to solve chicken and egg problem?',
#   '',
#   '3',
#   '1',
#   'baj84',
#   '9/21/2016 4:02'],
#  ['12545035',
#   'Ask HN: Which areas of math are practical to programming/algorithms and why?',
#   '',
#   '148',
#   '94',
#   'kevindeasis',
#   '9/21/2016 2:45'],
#  ['12545014',
#   'Ask HN: Settle for less salary or change to make more in prime years',
#   '',
#   '19',
#   '30',
#   'throwaway007007',
#   '9/21/2016 2:36'],
#  ['12544542',
#   'Ask HN: What is the necessary knowledge to build a chatbot?',
#   '',
#   '2',
#   '1',
#   '1_listerine_pls',
#   '9/21/2016 0:38'],
#  ['12544508',
#   'Ask HN: TuSimple achieves state-of-the-art results on KITTI and Cityscapes',
#   '',
#   '1',
#   '1',
#   'readtheinstr',
#   '9/21/2016 0:31'],
#  ['12544191',
#   'Ask HN: How to build something better than HN?',
#   '',
#   '1',
#   '3',
#   'kiloreux',
#   '9/20/2016 23:20'],
#  ['12544035',
#   "Ask HN: Why don't web apps make use of right click?",
#   '',
#   '7',
#   '20',
#   'catskull',
#   '9/20/2016 22:48'],
#  ['12543663',
#   'Ask HN: Google Apps vs. Fastmail',
#   '',
#   '11',
#   '14',
#   'dillonraphael',
#   '9/20/2016 21:41'],
#  ['12543437',
#   'Ask HN: Which podcasts do you listen to regularly?',
#   '',
#   '8',
#   '12',
#   'xwvvvvwx',
#   '9/20/2016 21:07'],
#  ['12543373',
#   "Ask HN: My work permit was just denied because I don't have a degree. Can I",
#   '',
#   '25',
#   '30',
#   'uni_degree',
#   '9/20/2016 21:00'],
#  ['12543155',
#   'Ask HN: WebRTC onion routing between Facebook friend circles',
#   '',
#   '7',
#   '2',
#   'jashper',
#   '9/20/2016 20:37'],
#  ['12542626',
#   'Ask HN: To expose a security flaw or not? (at a company where I Interviewed)',
#   '',
#   '4',
#   '7',
#   'ziggystardust',
#   '9/20/2016 19:39'],
#  ['12542444',
#   'Ask HN: I created a SaaS platform, but I have no idea what to do with it',
#   '',
#   '2',
#   '1',
#   'codedude',
#   '9/20/2016 19:20'],
#  ['12542113',
#   'Ask HN: How to Grow Your Site?',
#   '',
#   '6',
#   '7',
#   'Golddisk',
#   '9/20/2016 18:45'],
#  ['12542031',
#   'Ask HN: Recommend an IDaaS/Login provider?',
#   '',
#   '3',
#   '1',
#   'jdlshore',
#   '9/20/2016 18:37'],
#  ['12541983',
#   'Ask HN: Any distributed-db has redis-like custom c modules/data-types?',
#   '',
#   '1',
#   '0',
#   'ddorian43',
#   '9/20/2016 18:30'],
#  ['12541891',
#   'Ask HN: Thinking about making a website to teach people Excel. Good idea?',
#   '',
#   '1',
#   '3',
#   'Im_a_throw_away',
#   '9/20/2016 18:20'],
#  ['12541417',
#   'Ask HN: How do I build upon what HN did for OldGeekJobs.com?',
#   '',
#   '8',
#   '11',
#   'johnwheeler',
#   '9/20/2016 17:41'],
#  ['12541322',
#   "Ask HN: doesn't the iPhone already have bokeh?",
#   '',
#   '1',
#   '3',
#   'gnicholas',
#   '9/20/2016 17:32'],
#  ['12540831',
#   'Ask HN: Suggestions for email provider separate from vps',
#   '',
#   '1',
#   '1',
#   'tmaly',
#   '9/20/2016 16:35'],
#  ['12540678',
#   'Ask HN: What do you use for company-wide documentation',
#   '',
#   '20',
#   '20',
#   'gtf21',
#   '9/20/2016 16:17'],
#  ['12540586',
#   'Ask HN: How to re-open all browser tabs in a different machine',
#   '',
#   '6',
#   '8',
#   'sureshn',
#   '9/20/2016 16:08'],
#  ['12540267',
#   'Ask HN: Best way to bootstrap?',
#   '',
#   '2',
#   '3',
#   'pvsukale3',
#   '9/20/2016 15:30'],
#  ['12539965',
#   'Ask HN: Should I rebrand my web app?',
#   '',
#   '3',
#   '0',
#   'ceyhunkazel',
#   '9/20/2016 14:54'],
#  ['12539867',
#   'Ask HN: Your experience with a dedicated test team?',
#   '',
#   '5',
#   '4',
#   'maramono',
#   '9/20/2016 14:42'],
#  ['12539708',
#   'Ask HN: How illegal does the code have to be before you refuse to deploy?',
#   '',
#   '3',
#   '2',
#   'throwuway',
#   '9/20/2016 14:22'],
#  ['12539707',
#   'Ask HN: JavaScript Library for creating Simulink-like charts',
#   '',
#   '3',
#   '0',
#   'korczis86',
#   '9/20/2016 14:21'],
#  ['12538861',
#   'Ask HN: I created a scraper, now I think how to utilize scraped data',
#   '',
#   '3',
#   '1',
#   'gorer',
#   '9/20/2016 12:11'],
#  ['12538846',
#   "Ask HN: What are today's End to End encryption solutions for non tech people?",
#   '',
#   '2',
#   '2',
#   'thanpolas',
#   '9/20/2016 12:09'],
#  ['12538656',
#   'Ask HN: Smalltalk, Platonic idea world and Giordano Bruno memory techniques',
#   '',
#   '5',
#   '4',
#   'sa_su_ke_75',
#   '9/20/2016 11:29'],
#  ['12538628',
#   'Ask HN: Why do you really hate ads?',
#   '',
#   '1',
#   '7',
#   'chirau',
#   '9/20/2016 11:23'],
#  ['12538524',
#   'Ask HN: What are some good Crowdsourced Testing Platforms?',
#   '',
#   '2',
#   '2',
#   'Andreafu',
#   '9/20/2016 11:02'],
#  ['12538002',
#   'Ask HN: Do you have any experience with burning out in the tech industry?',
#   '',
#   '1',
#   '0',
#   'thomas4567',
#   '9/20/2016 8:32'],
#  ['12537922',
#   'Ask HN: Is facebook deliberately preventing/discouraging users from logging out?',
#   '',
#   '1',
#   '2',
#   'bangda',
#   '9/20/2016 8:03'],
#  ['12537756',
#   'Ask HN: Donate to Republican/Democratic party via Stripe',
#   '',
#   '2',
#   '0',
#   'shime',
#   '9/20/2016 7:20'],
#  ['12537613',
#   'Ask HN: What simple finance tool for a small business?',
#   '',
#   '3',
#   '3',
#   'illuminated',
#   '9/20/2016 6:43'],
#  ['12537441',
#   'Ask HN: Solo developer on a side project, where to focus?',
#   '',
#   '3',
#   '4',
#   'nullundefined',
#   '9/20/2016 6:04'],
#  ['12537227',
#   'Ask HN: Why does Booking.com have such bad reputation?',
#   '',
#   '2',
#   '3',
#   'employee123',
#   '9/20/2016 5:13'],
#  ['12537197',
#   'Ask HN: What are some iOS apps with the best design?',
#   '',
#   '1',
#   '0',
#   'kbr',
#   '9/20/2016 5:07'],
#  ['12535760',
#   'Ask HN: Of Introverts, the Open Office, and ADHD',
#   '',
#   '6',
#   '10',
#   'alansmitheebk',
#   '9/19/2016 23:55'],
#  ['12535635',
#   'Ask HN: How did you learn coding',
#   '',
#   '24',
#   '59',
#   'applecrazy',
#   '9/19/2016 23:31'],
#  ['12535431',
#   'Ask HN: Stripe for 10k plus transactions?',
#   '',
#   '9',
#   '5',
#   'msencenb',
#   '9/19/2016 22:50'],
#  ['12535046',
#   'Ask HN: Deep learning attack vectors',
#   '',
#   '5',
#   '1',
#   'gtirloni',
#   '9/19/2016 21:48'],
#  ['12535010',
#   "Ask HN: How is the Udacity's Nanodegree Plus worth it?",
#   '',
#   '10',
#   '3',
#   'jklein11',
#   '9/19/2016 21:42'],
#  ['12534816',
#   'Ask HN: After Hour Meetings',
#   '',
#   '2',
#   '1',
#   'adentranter',
#   '9/19/2016 21:19'],
#  ['12534211',
#   'Ask HN: Best way to get started in a different language',
#   '',
#   '1',
#   '0',
#   'throwaway123455',
#   '9/19/2016 19:57'],
#  ['12534097',
#   'Ask HN: File sharing for startup',
#   '',
#   '1',
#   '1',
#   'mgamache',
#   '9/19/2016 19:40'],
#  ['12533971',
#   'Ask HN: New OSS Projects: Go or Java?',
#   '',
#   '19',
#   '28',
#   'kt9',
#   '9/19/2016 19:21'],
#  ['12533855',
#   'Ask HN: Self-taught novice to junior dev position?',
#   '',
#   '1',
#   '2',
#   'olddesktop',
#   '9/19/2016 19:04'],
#  ['12533792',
#   'Ask HN: Which is the smallest size CNN for Pedestrian Detection?',
#   '',
#   '1',
#   '0',
#   'rdabane',
#   '9/19/2016 18:55'],
#  ['12533747',
#   'Ask HN: Do you worry that your product will be killed by one of the tech giants?',
#   '',
#   '8',
#   '14',
#   'shanwang',
#   '9/19/2016 18:51'],
#  ['12533551',
#   'Ask HN: Who owns the Internet?',
#   '',
#   '2',
#   '2',
#   'user321',
#   '9/19/2016 18:28'],
#  ['12533516',
#   'Ask HN: What are your problems in Cloud?',
#   '',
#   '1',
#   '0',
#   'mrg3_2013',
#   '9/19/2016 18:23'],
#  ['12533446',
#   'Ask HN: How would you learn software engineering if you had no responsibilities?',
#   '',
#   '1',
#   '0',
#   'dominici',
#   '9/19/2016 18:16'],
#  ['12532721',
#   'Ask HN: Book on how to build software collaboratively and lead the process?',
#   '',
#   '1',
#   '0',
#   'TbobbyZ',
#   '9/19/2016 16:40'],
#  ['12532431',
#   'Ask HN: Those with small side projects, where did you find part-time talent?',
#   '',
#   '2',
#   '2',
#   'phankinson',
#   '9/19/2016 16:04'],
#  ['12532394',
#   'Ask HN: When is it considered too early to start applying for S.E jobs?',
#   '',
#   '4',
#   '1',
#   'captshiner',
#   '9/19/2016 15:57'],
#  ['12532370',
#   'Ask HN: Online communities for founders or operators',
#   '',
#   '1',
#   '0',
#   'recmend',
#   '9/19/2016 15:54'],
#  ['12532345',
#   'Ask HN: Is there anything I can do to prevent burnout?',
#   '',
#   '5',
#   '7',
#   'CorvusCrypto',
#   '9/19/2016 15:51'],
#  ['12532176',
#   'Ask HN: Does the film industry use stock options for compensation?',
#   '',
#   '1',
#   '2',
#   'spoonie',
#   '9/19/2016 15:31'],
#  ['12532045',
#   "Ask HN: Doesn't Chrome new interface look more *fragile*?",
#   '',
#   '1',
#   '0',
#   'MrBra',
#   '9/19/2016 15:15'],
#  ['12531786',
#   'Ask HN: Software for helping visually impaired persons?',
#   '',
#   '2',
#   '6',
#   'adamwi',
#   '9/19/2016 14:43'],
#  ['12531738',
#   'Ask HN: Time for *cheap* e-notebooks?',
#   '',
#   '2',
#   '10',
#   'grif-fin',
#   '9/19/2016 14:36'],
#  ['12531643',
#   'Ask HN: How to reduce accent?',
#   '',
#   '2',
#   '1',
#   'throwawaymaster',
#   '9/19/2016 14:21'],
#  ['12531334',
#   'Ask HN: How do you read?',
#   '',
#   '18',
#   '11',
#   'dsinecos',
#   '9/19/2016 13:40'],
#  ['12531025',
#   'Ask HN: Should I give equity to early employees?',
#   '',
#   '1',
#   '2',
#   'a3b2',
#   '9/19/2016 12:54'],
#  ['12530100',
#   'Ask HN: Where in European Union should I move to found a startup?',
#   '',
#   '8',
#   '7',
#   'cosmorocket',
#   '9/19/2016 9:45'],
#  ['12530089',
#   'Ask HN: What are the top ten hundred words used on HN and SO?',
#   '',
#   '1',
#   '1',
#   'afarrell',
#   '9/19/2016 9:42'],
#  ['12529829',
#   "Ask HN: I'm Looking for Interview Question about Java Around Web Development",
#   '',
#   '1',
#   '2',
#   'merb',
#   '9/19/2016 8:31'],
#  ['12529649',
#   'Ask HN: What would make your life better?',
#   '',
#   '15',
#   '22',
#   'curryMyLambda',
#   '9/19/2016 7:44'],
#  ['12529310',
#   'Ask HN: In what areas are NoSQL Databases beneficial over Relational Databases?',
#   '',
#   '74',
#   '73',
#   'rochak',
#   '9/19/2016 6:06'],
#  ['12528334',
#   "Ask HN: Why isn't there a `setDay` method on the Date prototype?",
#   '',
#   '2',
#   '14',
#   'saghm',
#   '9/19/2016 2:07'],
#  ['12527922',
#   'Ask HN: Where do you go to get recruiters to find you a job?',
#   '',
#   '89',
#   '61',
#   'nicholas73',
#   '9/19/2016 0:16'],
#  ['12527654',
#   'Ask HN: Why do mail clients not support modern standards?',
#   '',
#   '1',
#   '1',
#   'wouter2203',
#   '9/18/2016 23:05'],
#  ['12526490',
#   'Ask HN: Articles / Stories on failed experiments',
#   '',
#   '1',
#   '0',
#   'recmend',
#   '9/18/2016 18:35'],
#  ['12526475',
#   'Ask HN: I am 21 and lost',
#   '',
#   '3',
#   '9',
#   'chowraid',
#   '9/18/2016 18:33'],
#  ['12526165',
#   "Ask HN: What's the next big thing that will exceed hiring capacity?",
#   '',
#   '1',
#   '0',
#   'daxfohl',
#   '9/18/2016 17:30'],
#  ['12526162',
#   'Ask HN: Moving to US from the UK',
#   '',
#   '1',
#   '2',
#   'iqonik',
#   '9/18/2016 17:28'],
#  ['12525863',
#   'Ask HN: Is there a URI for identifying points in time?',
#   '',
#   '2',
#   '0',
#   'josh-wrale',
#   '9/18/2016 16:24'],
#  ['12525801',
#   'Ask HN: How has your experience with Amazon Prime been?',
#   '',
#   '1',
#   '1',
#   'a_lifters_life',
#   '9/18/2016 16:05'],
#  ['12525751',
#   'Ask HN: Can 32-bit Interact with 64-bit?',
#   '',
#   '1',
#   '1',
#   'sinnska',
#   '9/18/2016 15:51'],
#  ['12525650',
#   'Ask HN: New Server on every SSH connection?',
#   '',
#   '4',
#   '4',
#   'diegorbaquero',
#   '9/18/2016 15:24'],
#  ['12525512',
#   'Ask HN: How to get certificate of employment on a startup?',
#   '',
#   '1',
#   '0',
#   'gdiocarez',
#   '9/18/2016 14:48'],
#  ['12525401',
#   'Ask HN: What has been your experiences with using a terminal on mobile phones?',
#   '',
#   '2',
#   '1',
#   'mkagenius',
#   '9/18/2016 14:20'],
#  ['12524496',
#   'Ask HN: How do you track scientific articles of your interests?',
#   '',
#   '2',
#   '0',
#   'pattttttt',
#   '9/18/2016 8:58'],
#  ['12524086',
#   'Ask HN: Did you spend more on software or saas this year? And your business?',
#   '',
#   '5',
#   '1',
#   'justintocci',
#   '9/18/2016 5:41'],
#  ['12523828',
#   'Ask HN: How long did you work on a side project until it was your full time job?',
#   '',
#   '88',
#   '35',
#   'jorgemf',
#   '9/18/2016 3:40'],
#  ['12523824',
#   'Ask HN: Getting back to work after a brain tumour',
#   '',
#   '5',
#   '2',
#   'temp18Sep2016',
#   '9/18/2016 3:38'],
#  ['12523618',
#   'Ask HN: Malware 32-bit',
#   '',
#   '1',
#   '0',
#   'sinnskax',
#   '9/18/2016 2:20'],
#  ['12523146',
#   "Ask HN: How relevant are Master's degrees in tech today?",
#   '',
#   '11',
#   '6',
#   'red_fox',
#   '9/17/2016 23:48'],
#  ['12523118',
#   'Ask HN: How early is too early to move on from first job?',
#   '',
#   '4',
#   '4',
#   'Bieberfan2003',
#   '9/17/2016 23:40'],
#  ['12522831',
#   'Ask HN: Is there a way to turn off voicemail parsing in IOS10?',
#   '',
#   '2',
#   '0',
#   'jmount',
#   '9/17/2016 22:23'],
#  ['12522505',
#   "Ask HN: What are you usually doing when you have an 'insight'?",
#   '',
#   '3',
#   '2',
#   'adamnemecek',
#   '9/17/2016 21:18'],
#  ['12521869',
#   'Ask HN: Simplest way to build a REST API?',
#   '',
#   '3',
#   '5',
#   'ryanmccullagh',
#   '9/17/2016 19:01'],
#  ['12521805',
#   'Ask HN: Moving from academia to tech?',
#   '',
#   '9',
#   '10',
#   'stablemap',
#   '9/17/2016 18:47'],
#  ['12521745',
#   'Ask HN: What problems can techies solve to help world?',
#   '',
#   '10',
#   '23',
#   'marmot777',
#   '9/17/2016 18:34'],
#  ['12521665',
#   'Ask HN: Any resources on how to move existing premise applications to cloud?',
#   '',
#   '1',
#   '2',
#   'sthustfo',
#   '9/17/2016 18:16'],
#  ['12521506',
#   'Ask HN: How do you monitor server logs',
#   '',
#   '2',
#   '4',
#   'codegeek',
#   '9/17/2016 17:43'],
#  ['12521178',
#   'Ask HN: What are some examples of well written C/C++ codebases?',
#   '',
#   '6',
#   '5',
#   'seagoj',
#   '9/17/2016 16:36'],
#  ['12521052',
#   'Ask HN: What are the big recent tech companies in India other than Olacabs?',
#   '',
#   '1',
#   '0',
#   'traviagio',
#   '9/17/2016 16:07'],
#  ['12521022',
#   'Ask HN: What is your favourite Roald Dhall book?',
#   '',
#   '2',
#   '1',
#   'muzster',
#   '9/17/2016 15:58'],
#  ['12521020',
#   'Ask HN: Any one ever training a NN on a kinect data to guess depth?',
#   '',
#   '1',
#   '4',
#   'sharemywin',
#   '9/17/2016 15:58'],
#  ['12520952',
#   'Ask HN: Would you join a social network run by a non-profit?',
#   '',
#   '14',
#   '35',
#   'sharemywin',
#   '9/17/2016 15:44'],
#  ['12520752',
#   "Ask HN: Best MOOC or Tutorial After Reading Nate Silver's Signal and the Noise",
#   '',
#   '1',
#   '0',
#   'rcarrigan87',
#   '9/17/2016 15:02'],
#  ['12520316',
#   'Ask HN: What does Facebook actually do these days?',
#   '',
#   '28',
#   '25',
#   'kackin',
#   '9/17/2016 13:03'],
#  ['12519953',
#   'Ask HN: Trying to Learn Delphi 7',
#   '',
#   '3',
#   '1',
#   'sinnska',
#   '9/17/2016 10:35'],
#  ['12519912',
#   'Ask HN: Anyone already using the new GitHub Projects feature? Care to share?',
#   '',
#   '12',
#   '10',
#   'ssaunier_',
#   '9/17/2016 10:17'],
#  ['12519879',
#   'Ask HN: Simple database/key-value store web API for throwaway projects?',
#   '',
#   '1',
#   '1',
#   'networked',
#   '9/17/2016 9:57'],
#  ['12519713',
#   'Ask HN: Has anyone been hired by the big 4 companies from outside the US?',
#   '',
#   '7',
#   '14',
#   'employee123',
#   '9/17/2016 8:41'],
#  ['12519557',
#   'ASK HN: How does mosh shell use UDP but provide reliability like TCP?',
#   'https://mosh.org/#about',
#   '3',
#   '1',
#   'sabya',
#   '9/17/2016 7:34'],
#  ['12519433',
#   'Ask HN: Why are we building self driving cars to navigate based off human signs',
#   '',
#   '7',
#   '6',
#   'vincefutr23',
#   '9/17/2016 6:35'],
#  ['12519066',
#   'Ask HN: How to get into $300k+ club?',
#   '',
#   '14',
#   '19',
#   'hehenotnow',
#   '9/17/2016 4:07'],
#  ['12519034',
#   'Ask HN: How do you decide your cloud provider',
#   '',
#   '4',
#   '1',
#   'jmspring',
#   '9/17/2016 3:48'],
#  ['12518723',
#   'Ask HN: Is tutorialspoint.com a good website to learn languages and DSA?',
#   '',
#   '1',
#   '0',
#   'Onixelen',
#   '9/17/2016 2:00'],
#  ['12518551',
#   'Ask HN: Would you sign up if a Phone Number is required?',
#   '',
#   '2',
#   '9',
#   'warewolf',
#   '9/17/2016 1:06'],
#  ['12517984',
#   'Ask HN: I am torn between whether I should do MBA or not. Thoughts?',
#   '',
#   '52',
#   '33',
#   'kakekickball',
#   '9/16/2016 22:56'],
#  ['12517980',
#   'Ask HN: Are plain resumes still relevant today?',
#   '',
#   '42',
#   '39',
#   'enitihas',
#   '9/16/2016 22:56'],
#  ['12517728',
#   'Ask HN: What would you want to see in a DevOps monitoring handbook?',
#   '',
#   '5',
#   '2',
#   'iDemonix',
#   '9/16/2016 22:09'],
#  ['12517559',
#   'Ask HN: Are resold barcodes a scam?',
#   '',
#   '3',
#   '3',
#   'NicoJuicy',
#   '9/16/2016 21:39'],
#  ['12517437',
#   'Ask HN: What is the most novel program you saw?',
#   '',
#   '4',
#   '2',
#   'mrwnmonm',
#   '9/16/2016 21:19'],
#  ['12517318',
#   'Ask HN: How to seek mentorship?',
#   '',
#   '2',
#   '0',
#   'samblr',
#   '9/16/2016 21:02'],
#  ['12517248',
#   'Ask HN: Help me chose a startup vs. contractor',
#   '',
#   '8',
#   '14',
#   'throwawaygrrqq',
#   '9/16/2016 20:51'],
#  ['12517246',
#   "Ask HN: How to find results removed from Google under 'right to be forgotten'?",
#   '',
#   '55',
#   '40',
#   'ch215',
#   '9/16/2016 20:51'],
#  ['12517099',
#   'Ask HN: What error-handling patterns have you found useful for large code-bases?',
#   '',
#   '4',
#   '1',
#   'prmph',
#   '9/16/2016 20:28'],
#  ['12516750',
#   'Ask HN: OldGeekJobs Evolving the MVP',
#   '',
#   '5',
#   '0',
#   'johnwheeler',
#   '9/16/2016 19:46'],
#  ['12516611',
#   'Ask HN: Is it possible for someone to not be cut out for software engineering?',
#   '',
#   '182',
#   '185',
#   'conflicted_dev',
#   '9/16/2016 19:28'],
#  ['12516441',
#   'Ask HN: Master vs. Udacity nanodegree',
#   '',
#   '49',
#   '25',
#   'pgcosta',
#   '9/16/2016 19:00'],
#  ['12516039',
#   'Ask HN: HN Content Filter Stats',
#   '',
#   '2',
#   '2',
#   'nxzero',
#   '9/16/2016 18:14'],
#  ['12516016',
#   'Ask HN: How do you describe organisation wide data structures',
#   '',
#   '1',
#   '0',
#   'nodefortytwo',
#   '9/16/2016 18:11'],
#  ['12515989',
#   'Ask HN: Website or software to teach young kids to type and mouse',
#   '',
#   '1',
#   '1',
#   'fil_a_del_fee_a',
#   '9/16/2016 18:08'],
#  ['12515955',
#   'Ask HN: What problem would you pay for a solution?',
#   '',
#   '1',
#   '0',
#   'neilsharma',
#   '9/16/2016 18:04'],
#  ['12515899',
#   'Ask HN: Best route from developer to pentester',
#   '',
#   '6',
#   '5',
#   'careershift',
#   '9/16/2016 17:56'],
#  ['12515245',
#   'Ask HN: How (not) OK is it to analyze text from SciFi books using torrents?',
#   '',
#   '1',
#   '1',
#   'ddxv',
#   '9/16/2016 16:38'],
#  ['12514908',
#   'Ask HN: Would your company fire you when you place orders automatically?',
#   '',
#   '1',
#   '0',
#   'haosdent',
#   '9/16/2016 15:59'],
#  ['12514801',
#   'Ask HN: Feedback for Interview Survey?',
#   '',
#   '1',
#   '0',
#   '6DM',
#   '9/16/2016 15:47'],
#  ['12514295',
#   'Ask HN: Do I need to inform visitors about LocalStorage?',
#   '',
#   '8',
#   '5',
#   'nealrs',
#   '9/16/2016 14:39'],
#  ['12513902',
#   'Ask HN: Are these signs of a failing startup',
#   '',
#   '3',
#   '6',
#   'employee123',
#   '9/16/2016 13:43'],
#  ['12513725',
#   'Ask HN: Declining NDAs',
#   '',
#   '3',
#   '2',
#   'nxzero',
#   '9/16/2016 13:16'],
#  ['12513415',
#   'Ask HN: Nested Virtualization / NAT Supported VPS',
#   '',
#   '2',
#   '0',
#   'anhsirksai',
#   '9/16/2016 12:06'],
#  ['12513340',
#   'Ask HN: Can you help this quadriplegic organise their medical information?',
#   '',
#   '4',
#   '1',
#   'escapologybb',
#   '9/16/2016 11:47'],
#  ['12513335',
#   "Ask HN: What's your best marketing automation techniques?",
#   '',
#   '2',
#   '5',
#   'rloc',
#   '9/16/2016 11:46'],
#  ['12513074',
#   'Ask HN: How do you motivate yourself?',
#   '',
#   '35',
#   '36',
#   'e19293001',
#   '9/16/2016 10:49'],
#  ['12512814',
#   'Ask HN: Can I be public about a interview process with a Company?',
#   '',
#   '8',
#   '5',
#   'interviewiii',
#   '9/16/2016 9:31'],
#  ['12512645',
#   'Ask HN: Which language for interacting with AWS?',
#   '',
#   '5',
#   '6',
#   'bakery2k',
#   '9/16/2016 8:32'],
#  ['12512635',
#   'Ask HN: Tutorial / reference for building db backed web apps with express/node?',
#   '',
#   '2',
#   '0',
#   'thorin',
#   '9/16/2016 8:29'],
#  ['12512627',
#   'Ask HN: Might Apple be botching their UI design lately, or is it just me?',
#   '',
#   '4',
#   '2',
#   'joshjdr',
#   '9/16/2016 8:26'],
#  ['12512300',
#   'Ask HN: What do you use to make your presentations for talks?',
#   '',
#   '2',
#   '1',
#   'prodicus',
#   '9/16/2016 6:49'],
#  ['12512168',
#   'Ask HN: Selling IDEs for proprietary platforms?',
#   '',
#   '3',
#   '2',
#   'pwr',
#   '9/16/2016 6:06'],
#  ['12512127',
#   'Ask HN: Is Answering Questions on Stackoverflow help us to grow in our carrier?',
#   '',
#   '1',
#   '2',
#   'antoaravinth',
#   '9/16/2016 5:55'],
#  ['12511931',
#   'ASK HN: Acceptable content for Show HN?',
#   '',
#   '1',
#   '2',
#   'ozzmotik',
#   '9/16/2016 4:56'],
#  ['12511714',
#   'Ask HN: Finding a partner for a unique request',
#   '',
#   '1',
#   '2',
#   'newman8r',
#   '9/16/2016 3:54'],
#  ['12510465',
#   "Ask HN: What's a simple app/software that made a lot of money?",
#   '',
#   '7',
#   '9',
#   'kkt262',
#   '9/15/2016 22:42'],
#  ['12510420',
#   'Ask HN: What do you need apply to NFx Guild after being invited?',
#   '',
#   '2',
#   '0',
#   'lwall_mba',
#   '9/15/2016 22:34'],
#  ['12510256',
#   'Ask HN: Any suggestion about server administration tool for solo developer?',
#   '',
#   '3',
#   '1',
#   'ciaoben',
#   '9/15/2016 22:09'],
#  ['12509857',
#   'Ask HN: How to talk to the boss about promotion',
#   '',
#   '2',
#   '1',
#   'blabla_blublu',
#   '9/15/2016 21:09'],
#  ['12509839',
#   "Ask HN: How much would you pay for something like Calibre that Doesn't Suck?",
#   '',
#   '1',
#   '4',
#   'SimplGy',
#   '9/15/2016 21:07'],
#  ['12509790',
#   'Ask HN: Anything Like Kapa99 but for Ghostwriting?',
#   '',
#   '1',
#   '0',
#   'cdvonstinkpot',
#   '9/15/2016 21:01'],
#  ['12509728',
#   'Ask HN: Strategies for porting native code to another OS?',
#   '',
#   '2',
#   '1',
#   'khushia',
#   '9/15/2016 20:54'],
#  ['12509321',
#   'Ask HN: Best approach to getting first job in Bay Area?',
#   '',
#   '5',
#   '0',
#   'brian26235',
#   '9/15/2016 19:58'],
#  ['12509249',
#   'Ask HN: What books are you reading this week?',
#   '',
#   '3',
#   '9',
#   'adamnemecek',
#   '9/15/2016 19:50'],
#  ['12509016',
#   'Ask HN: What is your AWS DynamoDB monthly cost?',
#   '',
#   '2',
#   '0',
#   'allfou',
#   '9/15/2016 19:22'],
#  ['12508556',
#   'Ask HN: 5 most important problems for a 22 yo to work on',
#   '',
#   '1',
#   '1',
#   'kfish15',
#   '9/15/2016 18:30'],
#  ['12508527',
#   'Ask HN: How are teams sharing secrets?',
#   '',
#   '3',
#   '6',
#   'ChartsNGraffs',
#   '9/15/2016 18:26'],
#  ['12508297',
#   "Ask HN: Why aren't their taxes in the country the patent is held?",
#   '',
#   '3',
#   '1',
#   'sharemywin',
#   '9/15/2016 17:57'],
#  ['12507786',
#   'Ask HN: Whats the State of the Art in Due Dilligence and Auditing',
#   '',
#   '1',
#   '0',
#   'WesternStar',
#   '9/15/2016 17:00'],
#  ['12507569',
#   'Ask HN: Health insurance options for founders while bootstrapping',
#   '',
#   '10',
#   '8',
#   'recmend',
#   '9/15/2016 16:36'],
#  ['12507524',
#   'Ask HN: What code makes you happy?',
#   '',
#   '8',
#   '11',
#   'gonification',
#   '9/15/2016 16:30'],
#  ['12507496',
#   'Ask HN: How to justify the bloat of modern JavaScript frameworks?',
#   '',
#   '5',
#   '2',
#   'guessmyname',
#   '9/15/2016 16:28'],
#  ['12507482',
#   "Ask HN: What is the cleanest code sample you've seen?",
#   '',
#   '8',
#   '9',
#   'gonification',
#   '9/15/2016 16:27'],
#  ['12507254',
#   "Ask HN: What's a good software/interface to consume mailing lists?",
#   '',
#   '1',
#   '3',
#   'soulbadguy',
#   '9/15/2016 16:03'],
#  ['12507102',
#   "Ask HN: Automatically download components that can't be distributed?",
#   '',
#   '1',
#   '0',
#   'DougN7',
#   '9/15/2016 15:45'],
#  ['12506961',
#   'Ask HN: How can I get Google to reinstate my adsense account?',
#   '',
#   '2',
#   '1',
#   'mescalito',
#   '9/15/2016 15:27'],
#  ['12506740',
#   "Ask HN: What's the most frustrating part about saving money?",
#   '',
#   '2',
#   '2',
#   'jmaccabee',
#   '9/15/2016 15:04'],
#  ['12506633',
#   'Ask HN: Hosting companies providing gratis hosting to free software projects?',
#   '',
#   '1',
#   '1',
#   'watwatwatwat',
#   '9/15/2016 14:52'],
#  ['12506316',
#   'Ask HN: What features make a good blogging platform for you',
#   '',
#   '1',
#   '1',
#   'vs2370',
#   '9/15/2016 14:17'],
#  ['12506301',
#   'Ask HN: As driverless increases, Uber should disappear, what do you predict?',
#   '',
#   '1',
#   '0',
#   'somid3',
#   '9/15/2016 14:15'],
#  ['12506085',
#   'Ask HN: Devices for multidimensional input of continuous variables by human',
#   '',
#   '1',
#   '7',
#   'inlineint',
#   '9/15/2016 13:51'],
#  ['12506079',
#   'Ask HN: First time managing an internal team, how can I be a successful boss?',
#   '',
#   '2',
#   '1',
#   'wlfsbrg',
#   '9/15/2016 13:50'],
#  ['12506045',
#   'Ask HN: Most impressive SaaS landing page?',
#   '',
#   '3',
#   '1',
#   'fratlas',
#   '9/15/2016 13:46'],
#  ['12505861',
#   'Ask HN: Would anyone be interested in a modular BSP(Board Support Packages)',
#   '',
#   '3',
#   '0',
#   'fazkan',
#   '9/15/2016 13:21'],
#  ['12505609',
#   'Ask HN: Pricing dead zone: 300$-3000$',
#   '',
#   '3',
#   '1',
#   'lukasm',
#   '9/15/2016 12:45'],
#  ['12505316',
#   'Ask HN: What are the hottest startups related to beer / brewing?',
#   '',
#   '44',
#   '55',
#   'caiohdf',
#   '9/15/2016 12:00'],
#  ['12504528',
#   'Ask HN: Did IT matter?',
#   '',
#   '5',
#   '2',
#   'mrspeaker',
#   '9/15/2016 9:17'],
#  ['12504382',
#   'Ask HN: Suggestion on Automated Testing Suit(E2E) for NodeJs/ReactRedux App?',
#   '',
#   '3',
#   '2',
#   'sunasra',
#   '9/15/2016 8:40'],
#  ['12504178',
#   'Ask HN: What does your stack at work look like? What other tools do you use?',
#   '',
#   '1',
#   '0',
#   'sk14',
#   '9/15/2016 7:49'],
#  ['12504080',
#   "Ask HN: What is the most pseudo-technical thing you've heard in your workplace?",
#   '',
#   '1',
#   '0',
#   'exmuslim',
#   '9/15/2016 7:30'],
#  ['12504032',
#   'Ask HN: Angular2 UI Frameworks ng-bootstrap, ng2-bootstrap or material2',
#   '',
#   '2',
#   '1',
#   'jrudolph',
#   '9/15/2016 7:14'],
#  ['12504024',
#   'Ask HN: How to become a Unix/Linux power user?',
#   '',
#   '2',
#   '3',
#   'bangda',
#   '9/15/2016 7:11'],
#  ['12503820',
#   'Ask HN: Do I need to be an expert on some technology to write a book on it?',
#   '',
#   '4',
#   '3',
#   'asadjb',
#   '9/15/2016 6:07'],
#  ['12503814',
#   'Ask HN: Personal C&C software/hardware?',
#   '',
#   '2',
#   '0',
#   'mablap',
#   '9/15/2016 6:06'],
#  ['12503153',
#   'Ask HN: Is Intel Xeon Phi many-core processor vaporware?',
#   '',
#   '4',
#   '1',
#   'ActsJuvenile',
#   '9/15/2016 3:23'],
#  ['12502822',
#   'Ask HN: Who wants to connect talented high schoolers with internships?',
#   '',
#   '2',
#   '0',
#   'samayshamdasani',
#   '9/15/2016 2:04'],
#  ['12502698',
#   'Ask HN: Are there any APIs that expose small claims court data?',
#   '',
#   '2',
#   '0',
#   'udit99',
#   '9/15/2016 1:34'],
#  ['12502620',
#   'Ask HN: Is there a solution to the Bitcoin blockchain growth problem?',
#   '',
#   '2',
#   '2',
#   'marcus_holmes',
#   '9/15/2016 1:11'],
#  ['12502394',
#   'Ask HN: Legal for companies to chatbot and not identify?',
#   '',
#   '1',
#   '1',
#   'TrapperNelson',
#   '9/15/2016 0:12'],
#  ['12502103',
#   'Ask HN: Use Appengine or Stripe? How are your card declined rates?',
#   '',
#   '21',
#   '4',
#   'foxylad',
#   '9/14/2016 23:28'],
#  ['12502090',
#   'Ask HN: Boilerplates for quick prototyping of business ideas',
#   '',
#   '1',
#   '0',
#   'ychandler',
#   '9/14/2016 23:26'],
#  ['12501809',
#   'Ask HN: What would you like to learn in your spare time?',
#   '',
#   '1',
#   '2',
#   'amychong',
#   '9/14/2016 22:39'],
#  ['12501760',
#   'Ask HN: Can you share how you sought mentorship or mentored',
#   '',
#   '2',
#   '0',
#   'samblr',
#   '9/14/2016 22:32'],
#  ['12501128',
#   'Ask HN: YC startup school 2016 meetups?',
#   '',
#   '1',
#   '1',
#   'emanueld',
#   '9/14/2016 20:54'],
#  ['12501062',
#   'Ask HN: Making closed-source software that handles personal data illegal?',
#   '',
#   '1',
#   '1',
#   'seven-dev',
#   '9/14/2016 20:46'],
#  ['12500891',
#   'Ask HN: Are Bitcoins untraceable to a real identity?',
#   '',
#   '1',
#   '2',
#   'bikamonki',
#   '9/14/2016 20:19'],
#  ['12500887',
#   'Ask HN: Which Java framework will replace Spring?',
#   '',
#   '2',
#   '4',
#   'roschdal',
#   '9/14/2016 20:19'],
#  ['12499918',
#   'Ask HN: Why all the software labeled as robots now?',
#   '',
#   '1',
#   '0',
#   'cylinder',
#   '9/14/2016 18:32'],
#  ['12499663',
#   'Ask HN: How do I keep my skills up to date?',
#   '',
#   '2',
#   '0',
#   'gxs',
#   '9/14/2016 18:08'],
#  ['12499606',
#   'Ask HN: Stay in touch with professional friends or former colleagues',
#   '',
#   '15',
#   '27',
#   'recmend',
#   '9/14/2016 18:02'],
#  ['12499535',
#   'Ask HN: How much time do you spend reading VS doing/coding?',
#   '',
#   '1',
#   '0',
#   'joeclef',
#   '9/14/2016 17:55'],
#  ['12499507',
#   'Ask HN: Guidance on dealing with a bug bounty claim',
#   '',
#   '3',
#   '0',
#   '100Mcenturies',
#   '9/14/2016 17:52'],
#  ['12499441',
#   'Ask HN: How to get rid of laziness to read?',
#   '',
#   '3',
#   '1',
#   'ksashikumar',
#   '9/14/2016 17:45'],
#  ['12499279',
#   'Ask HN: Have there been instances of US fed govt acting on illegally gained info?',
#   '',
#   '1',
#   '0',
#   'jc_811',
#   '9/14/2016 17:29'],
#  ['12499088',
#   'Ask HN: How to get computer tech support clients?',
#   '',
#   '1',
#   '0',
#   'bkman',
#   '9/14/2016 17:11'],
#  ['12499031',
#   'Ask HN: What is a good multi-user solution for encrypted cloud data',
#   '',
#   '1',
#   '0',
#   'wuschel',
#   '9/14/2016 17:06'],
#  ['12498772',
#   "Ask HN: What's up with Starfighter?",
#   '',
#   '1',
#   '1',
#   'harperlee',
#   '9/14/2016 16:42'],
#  ['12497911',
#   'Ask HN: What are your favorite sayings?',
#   '',
#   '19',
#   '34',
#   'tmaly',
#   '9/14/2016 15:27'],
#  ['12497856',
#   "Ask HN: What's the biggest life lesson you've learned?",
#   '',
#   '2',
#   '0',
#   'minionslave',
#   '9/14/2016 15:23'],
#  ['12497701',
#   'Ask HN: Is Google Apps Down?',
#   '',
#   '1',
#   '4',
#   'dhruvkar',
#   '9/14/2016 15:10'],
#  ['12497685',
#   'Ask HN: Other worthy news/discussion communities?',
#   '',
#   '2',
#   '0',
#   'fovc',
#   '9/14/2016 15:09'],
#  ['12497498',
#   'Ask HN: What RDBMS GUI client would you recommend',
#   '',
#   '1',
#   '0',
#   'rbanffy',
#   '9/14/2016 14:55'],
#  ['12497210',
#   'Ask HN: Does asking Why am I being downvoted get upvotes?',
#   '',
#   '1',
#   '6',
#   'chippy',
#   '9/14/2016 14:32'],
#  ['12497202',
#   'Ask HN: What are some well documented ReactJS applications?',
#   '',
#   '18',
#   '5',
#   'whicks',
#   '9/14/2016 14:31'],
#  ['12497102',
#   'Ask HN: How can I find a full time job?',
#   '',
#   '1',
#   '1',
#   'sv_code',
#   '9/14/2016 14:22'],
#  ['12497093',
#   'Ask HN: Dropbox down / DNS resolution issue?',
#   '',
#   '1',
#   '1',
#   'maaarghk',
#   '9/14/2016 14:21'],
#  ['12496558',
#   "Ask HN: What's your favorite HN post?",
#   '',
#   '691',
#   '138',
#   'rkhraishi',
#   '9/14/2016 13:20'],
#  ['12496525',
#   "Ask HN: Is Swift worth learning if I'm not into iOS development?",
#   '',
#   '10',
#   '7',
#   '0x70run',
#   '9/14/2016 13:17'],
#  ['12495629',
#   'Ask HN: YCombinator.com down for everyone?',
#   '',
#   '1',
#   '1',
#   'YousefED',
#   '9/14/2016 10:57'],
#  ['12495433',
#   'Ask HN: If you were to reinvent the web, how would your HTML/CSS/JS look like?',
#   '',
#   '4',
#   '1',
#   'johnnydoebk',
#   '9/14/2016 10:13'],
#  ['12495117',
#   'Ask HN: How to Learn OOP',
#   '',
#   '66',
#   '75',
#   'ympavan',
#   '9/14/2016 9:05'],
#  ['12494723',
#   'Ask HN: Categories for news on HN?',
#   '',
#   '2',
#   '0',
#   'mattnumbe',
#   '9/14/2016 7:02'],
#  ['12494523',
#   'Ask HN: If HN were a standalone company, what would it be valued at',
#   '',
#   '5',
#   '1',
#   'mankash666',
#   '9/14/2016 5:54'],
#  ['12493739',
#   'Ask HN: How do you validate business ideas before investing work',
#   '',
#   '1',
#   '2',
#   'm4nu',
#   '9/14/2016 1:50'],
#  ['12493304',
#   'Ask HN: How to test or proove logic programming?',
#   '',
#   '3',
#   '2',
#   'piotr-yuxuan',
#   '9/14/2016 0:09'],
#  ['12492672',
#   'Ask HN: Has anyone ever crawled over a billion pages? How much did it cost?',
#   '',
#   '10',
#   '14',
#   'outpan',
#   '9/13/2016 22:07'],
#  ['12492519',
#   'Ask HN: Can anyone recommend debt collection cloud software?',
#   '',
#   '2',
#   '1',
#   'marcamillion',
#   '9/13/2016 21:43'],
#  ['12492421',
#   'Ask HN: AirPod Security Questions',
#   '',
#   '6',
#   '3',
#   'hNewsLover99',
#   '9/13/2016 21:27'],
#  ['12492322',
#   "Ask HN: Anyone attending YC Startup School 2016? Let's know each other",
#   '',
#   '4',
#   '3',
#   'grigy',
#   '9/13/2016 21:15'],
#  ['12492260',
#   'Ask HN: Will i need separate earphones for my iPhone 7 and my Macbook?',
#   '',
#   '2',
#   '1',
#   'chirau',
#   '9/13/2016 21:09'],
#  ['12492098',
#   'Ask HN: Why is linking to paywalled articles so common here?',
#   '',
#   '43',
#   '17',
#   'whamlastxmas',
#   '9/13/2016 20:48'],
#  ['12491398',
#   'Ask HN: What would you like to see in an improved Who is Hiring site?',
#   '',
#   '1',
#   '0',
#   'lamroger',
#   '9/13/2016 19:26'],
#  ['12490911',
#   'Ask HN: Does your company find value in exit interviews?',
#   '',
#   '6',
#   '7',
#   'probinso',
#   '9/13/2016 18:21'],
#  ['12490633',
#   'Ask HN: Best native postgres client for Mac',
#   '',
#   '2',
#   '5',
#   'stevepike',
#   '9/13/2016 17:51'],
#  ['12490302',
#   'Ask HN: Can I become a programmer with a Computer Programmer Analyst course?',
#   '',
#   '5',
#   '2',
#   'kevinnnz',
#   '9/13/2016 17:16'],
#  ['12489896',
# ...
#   '',
#   '1',
#   '0',
#   'Immortalin',
#   '8/26/2016 15:07'],
#  ['12366498',
#   'Ask HN: Whats the best video talk you have ever seen?',
#   '',
#   '1',
#   '1',
#   'ThomPete',
#   '8/26/2016 14:28'],
#  ['12366364',
#   'Ask HN: Grammar checking Markdown',
#   '',
#   '3',
#   '3',
#   'ehudla',
#   '8/26/2016 14:12'],
#  ['12365252',
#   'Ask HN: That article about client-specific APIs?',
#   '',
#   '2',
#   '1',
#   'trumbitta2',
#   '8/26/2016 10:01'],
#  ['12365206',
#   'Ask HN: Does anyone actually use /newcomments?',
#   '',
#   '5',
#   '2',
#   'kaishiro',
#   '8/26/2016 9:44'],
#  ['12364995',
#   "Ask HN: What's your preferred VPS service for personal projects?",
#   '',
#   '20',
#   '24',
#   'oliverjudge',
#   '8/26/2016 8:39'],
#  ['12364701',
#   'Ask HN: What is the future for custom web developers',
#   '',
#   '2',
#   '1',
#   'quadrant6',
#   '8/26/2016 6:57'],
#  ['12364616',
#   'Ask HN: Can someone explain me the interface of Pinterest?',
#   '',
#   '1',
#   '0',
#   'ben_utzer',
#   '8/26/2016 6:35'],
#  ['12364138',
#   'Ask HN: How do you get started with 360 photo, video, VR?',
#   '',
#   '1',
#   '0',
#   'kevindeasis',
#   '8/26/2016 3:48'],
#  ['12363912',
#   "Ask HN: What are your startup ideas that you aren't pursuing?",
#   '',
#   '6',
#   '6',
#   'marginalcodex',
#   '8/26/2016 2:19'],
#  ['12363846',
#   'Ask HN: Is there any use nowadays for a proprietary C compiler?',
#   '',
#   '8',
#   '10',
#   'ignoramoose',
#   '8/26/2016 1:54'],
#  ['12363790',
#   'Ask HN: What OS are you running on your Macbook and why?',
#   '',
#   '7',
#   '7',
#   'shincert',
#   '8/26/2016 1:39'],
#  ['12363580',
#   'Ask HN: Single or multiple mounting point(s) in React app?',
#   '',
#   '1',
#   '1',
#   'billykwok',
#   '8/26/2016 0:49'],
#  ['12362769',
#   'Ask HN: Optimal strategy to sell startup shares?',
#   '',
#   '7',
#   '5',
#   'HowDoIEquity',
#   '8/25/2016 21:49'],
#  ['12362574',
#   'Ask HN: Looking for amazing apps for my 2 year old. Any suggestions?',
#   '',
#   '1',
#   '0',
#   'j2bax',
#   '8/25/2016 21:16'],
#  ['12362552',
#   'Ask HN: Trying to prevent 24/7 on-call, please help',
#   '',
#   '10',
#   '8',
#   'webappsecperson',
#   '8/25/2016 21:11'],
#  ['12362040',
#   'Ask HN: How can content creators use social n/w aggregation 4 personal websites?',
#   '',
#   '2',
#   '0',
#   'girishnayak',
#   '8/25/2016 20:04'],
#  ['12361451',
#   'Ask HN: Is there a way to link the LinkedIn profile of contacts in Salesforce?',
#   '',
#   '1',
#   '0',
#   'smb06',
#   '8/25/2016 18:53'],
#  ['12360944',
#   'Ask HN: Unusually-located startups',
#   '',
#   '10',
#   '12',
#   'EFruit',
#   '8/25/2016 17:43'],
#  ['12360888',
#   'Ask HN: How you decided which text editor to use and sink time into?',
#   '',
#   '1',
#   '5',
#   'Philipp__',
#   '8/25/2016 17:37'],
#  ['12360101',
#   'Ask HN: Open source webpage snapshot software',
#   '',
#   '3',
#   '3',
#   'needhelpplease',
#   '8/25/2016 16:00'],
#  ['12359817',
#   'Ask HN: Paid alternatives to WhatsApp',
#   '',
#   '8',
#   '10',
#   'reacharavindh',
#   '8/25/2016 15:31'],
#  ['12359660',
#   'Ask HN: How old is the average reader of HN?',
#   '',
#   '2',
#   '1',
#   'titusblair',
#   '8/25/2016 15:18'],
#  ['12359560',
#   'Ask HN: Is there any US bank with a sandbox or API?',
#   '',
#   '82',
#   '59',
#   'kparjaszewski',
#   '8/25/2016 15:07'],
#  ['12359438',
#   'Ask HN: How do you feel about the future prospects of Rust?',
#   '',
#   '2',
#   '1',
#   'AsyncAwait',
#   '8/25/2016 14:51'],
#  ['12359309',
#   'Ask HN: Does your employer pay for online courses, books etc?',
#   '',
#   '1',
#   '0',
#   'J-dawg',
#   '8/25/2016 14:36'],
#  ['12359010',
#   'Ask HN: Bandit algorithms and metrics?',
#   '',
#   '1',
#   '0',
#   'tmaly',
#   '8/25/2016 13:58'],
#  ['12358563',
#   'Ask HN: Learn another programming language',
#   '',
#   '3',
#   '2',
#   'aaossa',
#   '8/25/2016 12:47'],
#  ['12358436',
#   'Ask HN: Did I miss a thread about this $900M acquisition?',
#   '',
#   '7',
#   '8',
#   'webtechgal',
#   '8/25/2016 12:22'],
#  ['12358164',
#   'Ask HN: How should I approach to write a clone of login with QR?',
#   '',
#   '2',
#   '6',
#   'xk0nsid',
#   '8/25/2016 11:20'],
#  ['12358060',
#   "Ask HN: What's the limits of planetary imaging?",
#   '',
#   '2',
#   '2',
#   'forgottenacc56',
#   '8/25/2016 10:49'],
#  ['12357907',
#   'Ask HN: Why open source developers still using GitHub?',
#   '',
#   '4',
#   '2',
#   'Socketubs',
#   '8/25/2016 10:03'],
#  ['12357901',
#   'Ask HN: Most Effective Thing You Did Publicizing New Site or App?',
#   '',
#   '4',
#   '1',
#   'le-mark',
#   '8/25/2016 9:59'],
#  ['12357410',
#   "Ask HN: Starting a new job on Monday, still haven't seen the contract",
#   '',
#   '2',
#   '5',
#   'Sevrene',
#   '8/25/2016 7:33'],
#  ['12357354',
#   'Ask HN: How does billing in man-days work?',
#   '',
#   '5',
#   '2',
#   'agilek',
#   '8/25/2016 7:12'],
#  ['12357323',
#   'Ask HN: Why do you still have linkedin profile?',
#   '',
#   '1',
#   '7',
#   'kilimchoi',
#   '8/25/2016 6:59'],
#  ['12357117',
#   'Ask HN: What is your language choice for coding challenges?',
#   '',
#   '5',
#   '7',
#   'InquisitiveMe',
#   '8/25/2016 5:35'],
#  ['12357012',
#   'Ask HN: How to start an open access journal?',
#   '',
#   '1',
#   '0',
#   'abhas9',
#   '8/25/2016 4:48'],
#  ['12356840',
#   'Ask HN: How do you pull out of a rut?',
#   '',
#   '10',
#   '2',
#   'Pixelicious',
#   '8/25/2016 3:35'],
#  ['12356501',
#   'Ask HN: Need help to choose the front end technology for my startup',
#   '',
#   '3',
#   '2',
#   'himanshuy',
#   '8/25/2016 1:54'],
#  ['12356357',
#   "Ask HN: I'm 28yo. Should I start college now, or get real world experience?",
#   '',
#   '20',
#   '42',
#   'Calist0',
#   '8/25/2016 1:17'],
#  ['12356095',
#   'Ask HN: How do you manage your passwords / internet security?',
#   '',
#   '1',
#   '1',
#   'nbmh',
#   '8/24/2016 23:54'],
#  ['12355801',
#   'Ask HN: Make money as a skilled developer? (Please help)',
#   '',
#   '29',
#   '10',
#   'ffggvv',
#   '8/24/2016 22:41'],
#  ['12355775',
#   'Ask HN: Best place to find contracting gigs?',
#   '',
#   '2',
#   '2',
#   'bkovacev',
#   '8/24/2016 22:34'],
#  ['12355611',
#   "Ask HN: What's your biggest gripe with CSS Media Queries?",
#   '',
#   '3',
#   '6',
#   'obihill',
#   '8/24/2016 22:04'],
#  ['12355541',
#   'Ask HN: Modern live streaming solutions for the web',
#   '',
#   '6',
#   '6',
#   'alanz1223',
#   '8/24/2016 21:52'],
#  ['12355313',
#   'Ask HN: Should unvote and un-favorite be consistent?',
#   '',
#   '2',
#   '0',
#   'joelg',
#   '8/24/2016 21:16'],
#  ['12355240',
#   'Ask HN: Where to live within California',
#   '',
#   '12',
#   '9',
#   'shmapf',
#   '8/24/2016 21:02'],
#  ['12354992',
#   'Ask HN: What should I know about FDM Group?',
#   '',
#   '1',
#   '1',
#   'greyostrich',
#   '8/24/2016 20:27'],
#  ['12354723',
#   'Ask HN: How do you manage prepaid recurring payments for your clients?',
#   '',
#   '1',
#   '0',
#   'cdvonstinkpot',
#   '8/24/2016 19:50'],
#  ['12354267',
#   'Ask HN: Angel Investment and VC  recommended readings?',
#   '',
#   '2',
#   '1',
#   'samblr',
#   '8/24/2016 18:41'],
#  ['12353750',
#   "Ask HN: How to receive money when you don't trust the buyer?",
#   '',
#   '1',
#   '1',
#   'whrobbins',
#   '8/24/2016 17:38'],
#  ['12353219',
#   'Ask HN: Are you happy with unlimited PTO?',
#   '',
#   '1',
#   '0',
#   'yawz',
#   '8/24/2016 16:31'],
#  ['12353040',
#   'Ask HN: Graduated recently, now what?',
#   '',
#   '1',
#   '0',
#   'Introvertuous',
#   '8/24/2016 16:11'],
#  ['12352987',
#   'Ask HN: Calendar as a service',
#   '',
#   '1',
#   '2',
#   'codemod',
#   '8/24/2016 16:03'],
#  ['12352686',
#   'Ask HN: How did you get started with automated stock trading?',
#   '',
#   '3',
#   '2',
#   'jviotti',
#   '8/24/2016 15:23'],
#  ['12352414',
#   'Ask HN: FastMail Alternative with Reseller Option?',
#   '',
#   '6',
#   '2',
#   'cdvonstinkpot',
#   '8/24/2016 14:48'],
#  ['12352114',
#   'Ask HN: Lesson learned notes',
#   '',
#   '1',
#   '0',
#   'selmat',
#   '8/24/2016 14:10'],
#  ['12351988',
#   'Ask HN: Should ethics be built into machine learning models?',
#   '',
#   '3',
#   '0',
#   'bko',
#   '8/24/2016 13:54'],
#  ['12351394',
#   'Ask HN: Should I work for Big company or a startup',
#   '',
#   '2',
#   '1',
#   'hackersy',
#   '8/24/2016 12:09'],
#  ['12351391',
#   'Ask HN: Why is there such high turnover among Designers',
#   '',
#   '1',
#   '2',
#   'lscore720',
#   '8/24/2016 12:07'],
#  ['12351328',
#   'Ask HN: Is it possible to fight back against the big 4 hiring fads?',
#   '',
#   '25',
#   '26',
#   'fspear',
#   '8/24/2016 11:54'],
#  ['12351041',
#   'Ask HN: Should I build a tool that helps founders showcase their team?',
#   '',
#   '15',
#   '10',
#   'grease',
#   '8/24/2016 10:50'],
#  ['12350834',
#   'Ask HN: What is the recommended way to create Windows desktop apps right now?',
#   '',
#   '39',
#   '83',
#   'spapas82',
#   '8/24/2016 9:57'],
#  ['12350493',
#   'Ask HN: Should being a public personae be an engineering job requisite?',
#   '',
#   '2',
#   '0',
#   'somenomadicguy',
#   '8/24/2016 8:11'],
#  ['12350208',
#   'Ask HN: Experience and opinions about chat bot plattforms',
#   '',
#   '1',
#   '0',
#   'patrics123',
#   '8/24/2016 6:48'],
#  ['12350080',
#   'Ask HN: Is downloading and storing user-supplied url content legal?',
#   '',
#   '6',
#   '1',
#   'prmph',
#   '8/24/2016 6:17'],
#  ['12349990',
#   'Ask HN: How to accept ACH payments without microdeposit verification',
#   '',
#   '2',
#   '0',
#   'mattieuga',
#   '8/24/2016 5:56'],
#  ['12349513',
#   'Ask HN: Any cool stories about old DOS extender, EMS or Extended Memory?',
#   '',
#   '8',
#   '5',
#   'sqldba',
#   '8/24/2016 3:41'],
#  ['12349282',
#   'Ask HN: Is the future of server-client communication gRPC or GraphQL?',
#   '',
#   '6',
#   '1',
#   'billykwok',
#   '8/24/2016 2:35'],
#  ['12349205',
#   'Ask HN: Taking a few months off?',
#   '',
#   '16',
#   '23',
#   'throwavay',
#   '8/24/2016 2:15'],
#  ['12349167',
#   'Ask HN: What has the highest cost per megabyte?',
#   '',
#   '1',
#   '2',
#   'foota',
#   '8/24/2016 2:03'],
#  ['12348756',
#   'Ask HN: Failed interview, feeling unemployable and depressed  what do I do?',
#   '',
#   '377',
#   '234',
#   'deathbysw123',
#   '8/24/2016 0:05'],
#  ['12348573',
#   'Ask HN: Java or .NET for a new big enterprise system?',
#   '',
#   '4',
#   '6',
#   'vitoralmeida',
#   '8/23/2016 23:22'],
#  ['12348067',
#   'Ask HN: What free public data-sets do you find most useful or interesting?',
#   '',
#   '3',
#   '1',
#   'prmph',
#   '8/23/2016 21:56'],
#  ['12347614',
#   'Ask HN: I bought Facebook.ky  what should I do with it?',
#   '',
#   '2',
#   '3',
#   'armenarmen',
#   '8/23/2016 21:02'],
#  ['12347470',
#   'Ask HN: Do you routinely use Linux virtual consoles? What for?',
#   '',
#   '2',
#   '0',
#   'ezequiel-garzon',
#   '8/23/2016 20:46'],
#  ['12347021',
#   'Ask HN: Why bing and Google+ is still alive?',
#   '',
#   '5',
#   '2',
#   'justplay',
#   '8/23/2016 20:00'],
#  ['12346572',
#   'Ask HN: Best web host for personal use?',
#   '',
#   '2',
#   '2',
#   'zenbob',
#   '8/23/2016 19:11'],
#  ['12346513',
#   'Ask HN: Wich AdBlocker to use',
#   '',
#   '1',
#   '1',
#   'halotrope',
#   '8/23/2016 19:05'],
#  ['12346241',
#   'Ask HN: Has anyone else skipped El Capitan entirely?',
#   '',
#   '15',
#   '22',
#   'gnicholas',
#   '8/23/2016 18:35'],
#  ['12345855',
#   'Ask HN: Outside of SV, is age discrimination in IT common?',
#   '',
#   '10',
#   '5',
#   '04rob',
#   '8/23/2016 17:58'],
#  ['12345248',
#   "Ask HN: Where can I learn to make better Web App UI's",
#   '',
#   '3',
#   '0',
#   'jsaundersdev',
#   '8/23/2016 17:01'],
#  ['12345180',
#   'Ask HN: Server providers missing from privacy policies?',
#   '',
#   '2',
#   '3',
#   'twa927',
#   '8/23/2016 16:51'],
#  ['12344244',
#   'Ask HN: Your favorite email app',
#   '',
#   '2',
#   '5',
#   'tmaly',
#   '8/23/2016 15:01'],
#  ['12344043',
#   'ASK HN: Ideas for 10k Apart contest',
#   'https://a-k-apart.com/',
#   '3',
#   '2',
#   'abhas9',
#   '8/23/2016 14:36'],
#  ['12343923',
#   'Ask HN: How pyramids are made',
#   '',
#   '1',
#   '1',
#   'subinsebastien',
#   '8/23/2016 14:23'],
#  ['12343671',
#   'Ask HN: How to find users for my beta app?',
#   '',
#   '8',
#   '10',
#   'ishener',
#   '8/23/2016 13:49'],
#  ['12343665',
#   'Ask HN: On how many topics should a good developer focus?',
#   '',
#   '1',
#   '4',
#   'colobas',
#   '8/23/2016 13:48'],
#  ['12343475',
#   'Ask HN: What are the selling points of .NET?',
#   '',
#   '16',
#   '26',
#   'brightball',
#   '8/23/2016 13:23'],
#  ['12343421',
#   "Ask HN: I don't need money, so what's the benefit to Y Combinator?",
#   '',
#   '1',
#   '2',
#   'forgottenacc56',
#   '8/23/2016 13:13'],
#  ['12343326',
#   'Ask HN: In modern CPUs how many ?s to flip a NAND (or other) logic gate?',
#   '',
#   '3',
#   '6',
#   'josh-wrale',
#   '8/23/2016 12:59'],
#  ['12343208',
#   'Ask HN: Gaining Experience as a Full-Stack Developer',
#   '',
#   '6',
#   '1',
#   'alharbi',
#   '8/23/2016 12:43'],
#  ['12343207',
#   'Ask HN: How to learn as much about C or C++ in 3 days',
#   '',
#   '6',
#   '4',
#   'Bumsonfire',
#   '8/23/2016 12:43'],
#  ['12343158',
#   'Ask HN: What is the business opportunity of climate change for startups?',
#   '',
#   '37',
#   '26',
#   'ThomPete',
#   '8/23/2016 12:35'],
#  ['12343157',
#   'Ask HN: In 2016, what are best practices for personal computer security?',
#   '',
#   '1',
#   '0',
#   'davebryand',
#   '8/23/2016 12:34'],
#  ['12342908',
#   'Ask HN: Fault-tolerant database for small datasets?',
#   '',
#   '3',
#   '8',
#   'ffggvv',
#   '8/23/2016 11:50'],
#  ['12342274',
#   'Ask HN: What are new Platforms worth developing for?',
#   '',
#   '3',
#   '3',
#   'geff82',
#   '8/23/2016 8:52'],
#  ['12341988',
#   'Ask HN: Would ML algorithms be able to generate newithbetter sorting algorithms?',
#   '',
#   '2',
#   '2',
#   'nanospeck',
#   '8/23/2016 7:29'],
#  ['12341410',
#   'Ask HN: What else is in your list of daily reads?',
#   '',
#   '2',
#   '3',
#   'gsmethells',
#   '8/23/2016 4:32'],
#  ['12341259',
#   'Ask HN: SF vs. NYC?',
#   '',
#   '8',
#   '12',
#   'warewolf',
#   '8/23/2016 3:50'],
#  ['12340792',
#   'Ask HN: Valuable Training Course or Class You Have Taken?',
#   '',
#   '2',
#   '0',
#   'ChuckClawhammer',
#   '8/23/2016 1:47'],
#  ['12340644',
#   "Ask HN: What's the name of that company that makes an AI that builds apps?",
#   '',
#   '2',
#   '0',
#   'ovatsug25',
#   '8/23/2016 1:17'],
#  ['12340564',
#   'Ask HN: EBook Best Practices',
#   '',
#   '12',
#   '0',
#   'will_brown',
#   '8/23/2016 0:57'],
#  ['12340548',
#   'Ask HN: How to unhide stories?',
#   '',
#   '7',
#   '15',
#   'mattm',
#   '8/23/2016 0:53'],
#  ['12339905',
#   'Ask HN: Where can I find a list of startups at Demo Day S16?',
#   '',
#   '1',
#   '0',
#   'laksmanv',
#   '8/22/2016 22:28'],
#  ['12339373',
#   'Ask HN: Script Library Generator?',
#   '',
#   '1',
#   '1',
#   'bsg75',
#   '8/22/2016 20:56'],
#  ['12338953',
#   'Ask HN: Could HITs (human-intelligence-tasks) compete with in-app video ads?',
#   '',
#   '1',
#   '0',
#   'tlow',
#   '8/22/2016 19:55'],
#  ['12338746',
#   'Ask HN: Google Recruiter contact etiquette',
#   '',
#   '7',
#   '9',
#   'jbooj',
#   '8/22/2016 19:28'],
#  ['12338287',
#   'Ask HN: Recommendations for too-quiet open office?',
#   '',
#   '3',
#   '3',
#   'graham1776',
#   '8/22/2016 18:23'],
#  ['12338125',
#   'Ask HN: Get a foot into the game industry',
#   '',
#   '1',
#   '6',
#   'Entalpi',
#   '8/22/2016 18:01'],
#  ['12337827',
#   'Ask HN: What should I do about a lazy and unproductive programmer?',
#   '',
#   '2',
#   '8',
#   'myceothrowaway',
#   '8/22/2016 17:17'],
#  ['12337720',
#   'Ask HN: How do you manage your cron jobs?',
#   '',
#   '2',
#   '3',
#   'aprdm',
#   '8/22/2016 17:05'],
#  ['12337714',
#   'Ask HN: How to best advertisize my career aspirations?',
#   '',
#   '1',
#   '0',
#   'kshk123',
#   '8/22/2016 17:04'],
#  ['12337657',
#   'Ask HN: What email newsletters are you subscribed to?',
#   '',
#   '1',
#   '0',
#   'oscii',
#   '8/22/2016 16:56'],
#  ['12337571',
#   "Ask HN: Evaluating candidates' tech skills your firm lacks",
#   '',
#   '1',
#   '0',
#   'davidmr',
#   '8/22/2016 16:46'],
#  ['12337537',
#   'Ask HN: What advice would you give your younger self?',
#   '',
#   '33',
#   '44',
#   'titusblair',
#   '8/22/2016 16:41'],
#  ['12336876',
#   'Ask HN: How much memory do concurrencies consume in Go vs other languages?',
#   '',
#   '1',
#   '0',
#   'baristaGeek',
#   '8/22/2016 15:14'],
#  ['12336810',
#   "Ask HN: What's in your Microsoft.PowerShell_profile.ps1?",
#   '',
#   '2',
#   '1',
#   'nailer',
#   '8/22/2016 15:06'],
#  ['12336661',
#   'Ask HN: How much do you make at a remote job?',
#   '',
#   '105',
#   '126',
#   'throwaway0822',
#   '8/22/2016 14:46'],
#  ['12336653',
#   'Ask HN: Legality of web app with encrypted database?',
#   '',
#   '1',
#   '1',
#   'pcarbonn',
#   '8/22/2016 14:45'],
#  ['12336599',
#   'Ask HN: PhantomJS or Protractor?',
#   '',
#   '2',
#   '1',
#   'alistproducer2',
#   '8/22/2016 14:38'],
#  ['12336306',
#   'Ask HN: How do people in F1 get their job?',
#   '',
#   '1',
#   '1',
#   'Donmario',
#   '8/22/2016 13:52'],
#  ...]

# %%
show_posts
# Out:
# [['12578335',
#   'Show HN: Finding puns computationally',
#   'http://puns.samueltaylor.org/',
#   '2',
#   '0',
#   'saamm',
#   '9/26/2016 0:36'],
#  ['12578182',
#   'Show HN: A simple library for complicated animations',
#   'https://christinecha.github.io/choreographer-js/',
#   '1',
#   '0',
#   'christinecha',
#   '9/26/2016 0:01'],
#  ['12578098',
#   'Show HN: WebGL visualization of DNA sequences',
#   'http://grondilu.github.io/dna.html',
#   '1',
#   '0',
#   'grondilu',
#   '9/25/2016 23:44'],
#  ['12577991',
#   'Show HN: Pomodoro-centric, heirarchical project management with ES6 modules',
#   'https://github.com/jakebian/zeal',
#   '2',
#   '0',
#   'dbranes',
#   '9/25/2016 23:17'],
#  ['12577142',
#   'Show HN: Jumble  Essays on the go #PaulInYourPocket',
#   'https://itunes.apple.com/us/app/jumble-find-startup-essay/id1150939197?ls=1&mt=8',
#   '1',
#   '1',
#   'ryderj',
#   '9/25/2016 20:06'],
#  ['12576813',
#   'Show HN: Learn Japanese Vocab via multiple choice questions',
#   'http://japanese.vul.io/',
#   '1',
#   '1',
#   'soulchild37',
#   '9/25/2016 19:06'],
#  ['12576627',
#   'Show HN: Turning a Trello list into a shared helpdesk',
#   'https://boardthreads.com/',
#   '1',
#   '0',
#   'fiatjaf',
#   '9/25/2016 18:32'],
#  ['12576090',
#   'Show HN: Markov chain Twitter bot. Trained on comments left on Pornhub',
#   'https://twitter.com/botsonasty',
#   '3',
#   '1',
#   'keepingscore',
#   '9/25/2016 16:50'],
#  ['12576053',
#   'Show HN: openemacs  a tiny emacs clone, ? 1024 LOC (C), based on kilo (BSD)',
#   'https://github.com/practicalswift/openemacs',
#   '1',
#   '0',
#   'practicalswift',
#   '9/25/2016 16:43'],
#  ['12575471',
#   'Show HN: Project-Okot: Novel, CODE-FREE data-apps in mere seconds',
#   'https://studio.nuchwezi.com/',
#   '3',
#   '1',
#   'nfixx',
#   '9/25/2016 14:30'],
#  ['12574773',
#   'Show HN: Cursor that Screenshot',
#   'http://edward.codes/cursor-that-screenshot',
#   '3',
#   '3',
#   'ed-bit',
#   '9/25/2016 10:50'],
#  ['12574637',
#   'Show HN: Hangman-game in command line. Knowing words is fun',
#   'https://github.com/argonlaser/hangman-game',
#   '2',
#   '0',
#   'argonlaser',
#   '9/25/2016 10:00'],
#  ['12574556',
#   'Show HN: Geto, a mobile local compass',
#   'https://andreapaiola.name/geto/',
#   '2',
#   '1',
#   'andreapaiola',
#   '9/25/2016 9:19'],
#  ['12574555',
#   'Show HN: A Killer Narrative about Info Sec and NSA Somewhere in Africa',
#   'http://genius.com/Nemesis-fixx-the-3lite-hackx0rs-lyrics',
#   '1',
#   '0',
#   'nfixx',
#   '9/25/2016 9:19'],
#  ['12574485',
#   'Show HN: Spotify-playlist-downloader  Easily download you spotify playlists',
#   'https://github.com/ashishmadeti/spotify-playlist-downloader',
#   '3',
#   '0',
#   'rgun',
#   '9/25/2016 8:49'],
#  ['12574288',
#   'Show HN: Component Template  Build and Publish reusable react components',
#   'https://github.com/reactstrap/component-template',
#   '7',
#   '1',
#   'eddywashere',
#   '9/25/2016 6:48'],
#  ['12573707',
#   'Show HN: Semile  simpler profile and diagnose (C++)',
#   'https://github.com/r-kan/semile',
#   '2',
#   '1',
#   'rkan',
#   '9/25/2016 3:06'],
#  ['12573072',
#   'Show HN: PLEENQ  A website plugin to create object links within images',
#   'http://pleenq.com',
#   '2',
#   '0',
#   'bazillion',
#   '9/24/2016 23:18'],
#  ['12572761',
#   'Show HN: Share any website on Facebook or Twitter with just one click',
#   'https://chrome.google.com/webstore/detail/social-media-share/lfimbgdhgeoeadgiejnpbepmooblmigd',
#   '1',
#   '0',
#   'sahil2305dua',
#   '9/24/2016 21:36'],
#  ['12572412',
#   'Show HN: G9.js  Automatically Interactive Differentiable Graphics',
#   'http://omrelli.ug/g9/gallery/',
#   '215',
#   '26',
#   'bijection',
#   '9/24/2016 20:07'],
#  ['12572255',
#   'Show HN: Automatic Forecast  St. Louis FRED Economic Data',
#   'http://ltv.statwonk.com/automatic-forecasting/',
#   '1',
#   '0',
#   'RA_Fisher',
#   '9/24/2016 19:35'],
#  ['12572019',
#   'Show HN: Medical ID, the Android app that could save your life',
#   '',
#   '1',
#   '2',
#   'lpellegr',
#   '9/24/2016 18:42'],
#  ['12572010',
#   'Show HN: Electriq Power  Smarter Energy Storage',
#   'https://electriqpower.com',
#   '1',
#   '0',
#   'traviswingo',
#   '9/24/2016 18:40'],
#  ['12571998',
#   "Show HN: World's first kids art gallery",
#   'http://lillipaint.com/',
#   '1',
#   '0',
#   'lillipaint',
#   '9/24/2016 18:36'],
#  ['12571989',
#   'Show HN: Hacked Together the Peace Day Love Button Seen on Facebook :)',
#   'https://sankalpsans.github.io/2016/09/24/facebook-love-button.html',
#   '1',
#   '1',
#   'sankalp_sans',
#   '9/24/2016 18:35'],
#  ['12571773',
#   'Show HN: MPW Shell',
#   'https://github.com/ksherlock/mpw-shell',
#   '1',
#   '1',
#   'ksherlock',
#   '9/24/2016 17:34'],
#  ['12571251',
#   'Show HN: Lamp  a minimal lava lamp on the web',
#   'https://kingpixil.github.io/lamp',
#   '1',
#   '0',
#   'kbr',
#   '9/24/2016 15:20'],
#  ['12571200',
#   'Show HN: InstaPart  Build circuit boards faster with instant parts',
#   'http://www.snapeda.com/instapart',
#   '301',
#   '102',
#   'natashabaker',
#   '9/24/2016 15:06'],
#  ['12571182',
#   'Show HN: New and Painless Couchbase Java SDK Wrapper for Scala with Futures',
#   'https://github.com/RealityGamesLtd/couchbase-java-sdk-scala-wrapper',
#   '1',
#   '0',
#   'Scotrix',
#   '9/24/2016 15:03'],
#  ['12570492',
#   'Show HN: Five C++ single-header libraries by Chobolabs',
#   'https://github.com/Chobolabs/chobo-shl',
#   '2',
#   '0',
#   'bstanimirov',
#   '9/24/2016 11:24'],
#  ['12570491',
#   'Show HN: WikiMentions  Discover books/people/videos mentioned by great people',
#   'https://wikimentions.com/',
#   '2',
#   '1',
#   'maxds',
#   '9/24/2016 11:23'],
#  ['12570490',
#   'Show HN: PJON website',
#   'http://www.pjon.org/',
#   '14',
#   '5',
#   'gioscarab',
#   '9/24/2016 11:23'],
#  ['12569881',
#   'Show HN: Manipulist, the new text/list manipulation time saver',
#   'http://www.manipulist.com/blog/20160923-save-time.php',
#   '1',
#   '0',
#   'chriscarex',
#   '9/24/2016 7:24'],
#  ['12569437',
#   'Show HN: Elasticsearch geo polygon drawing debugging',
#   'http://attozk.mine.pk/posts/603-elasticsearch-drawing-polygons-for-debugging',
#   '3',
#   '0',
#   'attozk',
#   '9/24/2016 4:16'],
#  ['12568900',
#   'Show HN: Lamp  a soothing lava lamp',
#   'https://kingpixil.github.io/lamp/',
#   '6',
#   '0',
#   'kbr',
#   '9/24/2016 0:41'],
#  ['12568034',
#   'Show HN: Inside  The network of email newsletters',
#   'http://inside.com',
#   '1',
#   '0',
#   'awwstn',
#   '9/23/2016 21:18'],
#  ['12567364',
#   'Show HN: zappa-bittorrent-tracker, a server-less BT tracker',
#   'https://github.com/Miserlou/zappa-bittorrent-tracker',
#   '7',
#   '1',
#   'Mizza',
#   '9/23/2016 19:38'],
#  ['12567073',
#   'Show HN: Code Golf',
#   'http://www.code-golf.com/',
#   '1',
#   '1',
#   'l33t_d0nut',
#   '9/23/2016 18:55'],
#  ['12566885',
#   'Show HN: WikiRoulette  Randomly browse Wikipedia',
#   'http://wikiroulette.co',
#   '8',
#   '8',
#   'minouye',
#   '9/23/2016 18:31'],
#  ['12566574',
#   'Show HN: Free JavaScript video course for Designers',
#   'http://betaflows.com/',
#   '7',
#   '0',
#   'startlaunch',
#   '9/23/2016 17:52'],
#  ['12566374',
#   'Show HN: A web office in/out board that pulls from Google Calendar',
#   'https://github.com/xd1936/inout2',
#   '6',
#   '0',
#   'xd1936',
#   '9/23/2016 17:29'],
#  ['12566331',
#   'Show HN: Tlmtry, realtime sensor streaming from your phone',
#   'http://blog.moritzhaarmann.de/2016/09/21/hello-tlmtry.html',
#   '4',
#   '0',
#   'derwildemomo',
#   '9/23/2016 17:24'],
#  ['12566129',
#   'Show HN: Blow Up Trump  Augmented Reality Game',
#   'https://itunes.apple.com/us/app/blow-up-trump/id1154248528?ls=1&mt=8',
#   '1',
#   '0',
#   'evannnn',
#   '9/23/2016 17:03'],
#  ['12565902',
#   'Show HN: Zero cost verified https using letsencrypt and Nginx for tomcat 8',
#   'https://blog.microideation.com/2016/09/23/zero-cost-verified-https-using-letsencrypt-and-nginx-for-tomcat-8/',
#   '2',
#   '0',
#   'sandheepgr',
#   '9/23/2016 16:37'],
#  ['12565528',
#   'Show HN: Get live football scores, fixtures, results, standings in your terminal',
#   'https://github.com/ManrajGrover/football-cli',
#   '1',
#   '0',
#   'manrajsingh',
#   '9/23/2016 15:55'],
#  ['12565446',
#   'Show HN: QuantBot, give it a URL/link and get related stocks',
#   'https://slack.com/apps/A26G72726-quantbot#cy00',
#   '6',
#   '0',
#   'KasianFranks',
#   '9/23/2016 15:43'],
#  ['12564668',
#   'Show HN: BoardingBot sends TestFlight invites',
#   'https://boardingbot.boorgle.com/',
#   '1',
#   '1',
#   'burgalon',
#   '9/23/2016 14:03'],
#  ['12564410',
#   'Show HN: How many days until?',
#   'https://days.to/',
#   '152',
#   '62',
#   'uptown',
#   '9/23/2016 13:29'],
#  ['12563952',
#   'Show HN: ChalkStory App  A unique new way to message friends',
#   'http://www.chalkstory.com/',
#   '2',
#   '0',
#   'ChalkStory',
#   '9/23/2016 12:11'],
#  ['12563692',
#   'Show HN: CuriositY',
#   'https://shark.fish/curiosity/',
#   '16',
#   '12',
#   'sharkdp',
#   '9/23/2016 11:13'],
#  ['12563337',
#   'Show HN: Fliffr  Mobile Advice Marketplace',
#   'https://www.fliffr.com/',
#   '2',
#   '1',
#   'danieka',
#   '9/23/2016 9:27'],
#  ['12563311',
#   'Show HN: HOWL, a formant synthesizer (v2.0)',
#   'http://protonome.com/apps/howl/',
#   '2',
#   '0',
#   'melloclello',
#   '9/23/2016 9:19'],
#  ['12563286',
#   'Show HN: Domainomo  Domain Name Generator with Word Lists',
#   'http://www.domainomo.com',
#   '2',
#   '0',
#   'stormen',
#   '9/23/2016 9:13'],
#  ['12563250',
#   'Show HN: Umbrella  Open Source Digital and Physical Travel Advice',
#   'https://play.google.com/store/apps/details?id=org.secfirst.umbrella',
#   '1',
#   '0',
#   'secfirstmd',
#   '9/23/2016 9:03'],
#  ['12563217',
#   'Show HN: Validater  a python tool to validate data by schema',
#   'https://github.com/guyskk/validater',
#   '5',
#   '0',
#   'guyskk',
#   '9/23/2016 8:54'],
#  ['12563169',
#   'Show HN: HubGraph  Turn boring GitHub events in an entertaining graph',
#   'https://github.com/nmaggioni/HubGraph',
#   '1',
#   '0',
#   'nmaggioni',
#   '9/23/2016 8:41'],
#  ['12561706',
#   'Show HN: Income Reporters  Tracking bloggers who post their income reports',
#   'http://www.incomereporters.com',
#   '2',
#   '1',
#   'scottatmu',
#   '9/23/2016 1:30'],
#  ['12561671',
#   'Show HN: Ng-seed  Simple Angular 2 seed project',
#   'https://github.com/camargo/ng-seed',
#   '4',
#   '0',
#   'nucleic',
#   '9/23/2016 1:22'],
#  ['12560975',
#   'Show HN: Fundhub.xyz  Search all investment funds',
#   '',
#   '7',
#   '9',
#   'kikowi',
#   '9/22/2016 22:47'],
#  ['12560234',
#   'Show HN: Super Simple Worker Queue in Go',
#   'https://github.com/Xeoncross/goworkqueue',
#   '6',
#   '7',
#   'Xeoncross',
#   '9/22/2016 20:46'],
#  ['12560036',
#   'Show HN: Doctest  the lightest C++ testing framework  version 1.1 released',
#   'https://github.com/onqtam/doctest/tree/master',
#   '3',
#   '1',
#   'onqtam',
#   '9/22/2016 20:22'],
#  ['12559668',
#   'Show HN: Send scribbles and pictures to an Emacs buffer from your Android phone',
#   'https://github.com/yati-sagade/orch',
#   '1',
#   '1',
#   'yati',
#   '9/22/2016 19:39'],
#  ['12559621',
#   'Show HN: Hakkeri for iOS  readable and minimalistic Hacker News',
#   'https://sampsakuronen.github.io/hakkeri/',
#   '2',
#   '1',
#   'sampsa',
#   '9/22/2016 19:35'],
#  ['12558918',
#   'Show HN: Bynd  One App. All Your Favorite Feeds',
#   'http://byndapp.com',
#   '3',
#   '0',
#   'oemerax',
#   '9/22/2016 18:21'],
#  ['12558673',
#   'Show HN: Transdata  flowchart-style data manipulation',
#   'http://www.bfstransdata.com/',
#   '4',
#   '1',
#   'akerfonta',
#   '9/22/2016 17:50'],
#  ['12558449',
#   'Show HN: Introducing EmbedBox, Our Open-Source Embed Code Install UI',
#   'https://eager.io/blog/introducing-embedbox-open-source-embed-code-ui/?',
#   '1',
#   '0',
#   'bosdev',
#   '9/22/2016 17:22'],
#  ['12558371',
#   'Show HN: Graph occurence of any words over time in the Linux kernel',
#   'http://www.vidarholen.net/contents/wordcount/',
#   '2',
#   '0',
#   'koala_man',
#   '9/22/2016 17:14'],
#  ['12557967',
#   'Show HN: Introducing Sauna, a decisioning and response platform',
#   'http://snowplowanalytics.com/blog/2016/09/22/introducing-sauna-a-decisioning-and-response-platform/',
#   '5',
#   '0',
#   'alexatkeplar',
#   '9/22/2016 16:25'],
#  ['12557310',
#   'Show HN: PhraseFinder  A Fast Search Engine for the Google Books Ngram Dataset',
#   'http://phrasefinder.io',
#   '5',
#   '0',
#   'mtrenkmann',
#   '9/22/2016 15:08'],
#  ['12557078',
#   'Show HN: Free the Vote',
#   'https://freethevote.us',
#   '4',
#   '2',
#   'SnacksOnAPlane',
#   '9/22/2016 14:40'],
#  ['12556939',
#   'Show HN: Did you thank your node dependencies?',
#   'https://github.com/musically-ut/appreciate',
#   '1',
#   '0',
#   'musically_ut',
#   '9/22/2016 14:19'],
#  ['12556852',
#   'Show HN: Register to vote via SMS chatbot hello.vote',
#   'https://hello.vote',
#   '8',
#   '4',
#   'jlev',
#   '9/22/2016 14:01'],
#  ['12556538',
#   'Show HN: Weather Extension for Chrome/Firefox/Opera',
#   'https://weather.timleland.com/',
#   '1',
#   '0',
#   'TimLeland',
#   '9/22/2016 13:08'],
#  ['12556526', 'Show HN: Jobbot', '', '2', '0', 'bitshifta', '9/22/2016 13:07'],
#  ['12556499',
#   'Show HN: Automatically Controlling a Dehumidifier with a Nest',
#   'https://medium.com/red-davis/automatically-controlling-a-dehumidifier-with-a-nest-7008fc5670e0#.51l65ly1i',
#   '1',
#   '0',
#   'reddavis',
#   '9/22/2016 13:02'],
#  ['12556384',
#   'Show HN: Amazon review exporter',
#   'http://app.feedcheck.co/amazon-review-exporter',
#   '3',
#   '1',
#   'adibalcan',
#   '9/22/2016 12:43'],
#  ['12555610',
#   'Show HN: Share links with your friends without apps or signups',
#   'http://www.yourpane.com/',
#   '2',
#   '1',
#   'StavrosK',
#   '9/22/2016 9:27'],
#  ['12555443',
#   'Show HN: Reverse Polish Arithmetic Evaluator in Python',
#   'http://blog.klipse.tech/python/2016/09/22/python-reverse-polish-evaluator.html',
#   '1',
#   '0',
#   'viebel',
#   '9/22/2016 8:43'],
#  ['12555403',
#   'Show HN: Changing and throttling http traffic with ARP poisoning',
#   'https://github.com/Shinao/CDansLair',
#   '4',
#   '3',
#   'shinao',
#   '9/22/2016 8:36'],
#  ['12554300',
#   "Show HN: The 'stackoverflow' for startup marketing",
#   'https://capitalandgrowth.org/index.html',
#   '3',
#   '1',
#   'jkuria',
#   '9/22/2016 4:13'],
#  ['12553981',
#   'Show HN: 3d terrain using WebGL',
#   'https://github.com/wybiral/terrain',
#   '6',
#   '0',
#   'wybiral',
#   '9/22/2016 2:50'],
#  ['12553505',
#   'Show HN: Stockharp Best Financial Platform for Investments',
#   'http://www.stockharp.com',
#   '2',
#   '0',
#   'buyitout',
#   '9/22/2016 0:53'],
#  ['12553444',
#   'Show HN: An Open Source Tool to Combat Clickbait Links',
#   'http://links.spince.com/demo.html',
#   '81',
#   '28',
#   'goldMIT',
#   '9/22/2016 0:38'],
#  ['12552820',
#   'Show HN: Have an Italian cheese farmer give you travel tips via text phone Skype',
#   'https://www.yourlocalcousin.com',
#   '7',
#   '4',
#   'yourlocalcousin',
#   '9/21/2016 22:27'],
#  ['12552623',
#   "Show HN: Lemonade  the world's first P2P insurance company",
#   'https://lemonade.com',
#   '184',
#   '167',
#   'gilsadis',
#   '9/21/2016 21:55'],
#  ['12552564',
#   'Show HN: Qoins  Pay off debt with spare change',
#   'https://qoins.io/',
#   '14',
#   '6',
#   'natwash2',
#   '9/21/2016 21:47'],
#  ['12552272',
#   'Show HN: Modern OpenGL Windows Demo',
#   'https://github.com/Const-me/GL3Windows',
#   '3',
#   '1',
#   'Const-me',
#   '9/21/2016 21:09'],
#  ['12551717',
#   'Show HN: Example of a Tcl extension in Swift',
#   'https://tcl.wiki/48057?',
#   '3',
#   '0',
#   'networked',
#   '9/21/2016 20:02'],
#  ['12551420',
#   'Show HN: Test Driven Interviews',
#   'https://testdriveninterviews.com/',
#   '2',
#   '1',
#   'KevinMS',
#   '9/21/2016 19:30'],
#  ['12551221',
#   'Show HN: Gyro Racer  Simple yet addicting gyroscope racing game',
#   'https://itunes.apple.com/us/app/gyro-racer/id1123467641',
#   '7',
#   '0',
#   'Bioengine',
#   '9/21/2016 19:04'],
#  ['12551207',
#   'Show HN: Python program to clean up handwritten notes',
#   'https://mzucker.github.io/2016/09/20/noteshrink.html',
#   '79',
#   '4',
#   'mzucker',
#   '9/21/2016 19:01'],
#  ['12551151',
#   'Show HN: A program that reads for you: Cloud-Based Summarizer',
#   'http://summarizer.intellexer.com/using_summarizer.html',
#   '4',
#   '0',
#   'Yeroniomus',
#   '9/21/2016 18:54'],
#  ['12550854',
#   'Show HN: Demo for Scale API (YC S16) Image Annotation API',
#   'https://annotate-demo.scaleapi.com/#/',
#   '2',
#   '0',
#   'ayw',
#   '9/21/2016 18:22'],
#  ['12550735',
#   'Show HN: Visual map designer for Mapbox GL (free alternative to Mapbox Studio)',
#   'https://github.com/maputnik/editor',
#   '1',
#   '0',
#   'morgenkaffee',
#   '9/21/2016 18:10'],
#  ['12550281',
#   'Show HN: 1000 ideas',
#   'https://github.com/napolux/1000ideas',
#   '11',
#   '12',
#   'napolux',
#   '9/21/2016 17:25'],
#  ['12550022',
#   'Show HN: PANIC  Distributed Jepsen Tests for Everyone',
#   'https://github.com/gundb/panic-server',
#   '1',
#   '1',
#   'marknadal',
#   '9/21/2016 16:59'],
#  ['12549874',
#   'Show HN: Weebly 4  Websites, eCommerce and Email Marketing',
#   'http://www.weebly.com/4',
#   '171',
#   '75',
#   'drusenko',
#   '9/21/2016 16:43'],
#  ['12549615',
#   'Show HN: Scrape Food Network Recipes with Python',
#   'https://github.com/benawad/food_network_wrapper',
#   '5',
#   '0',
#   'benawad',
#   '9/21/2016 16:21'],
#  ['12549595',
#   'Show HN: Akitabot Facebook Messenger app to connect with local businesses',
#   'https://m.me/akitabot',
#   '1',
#   '0',
#   'heyrhett',
#   '9/21/2016 16:19'],
#  ['12549271',
#   'Show HN: IP address to company data API',
#   'https://clearbit.com/docs#reveal-api',
#   '6',
#   '0',
#   'maccman',
#   '9/21/2016 15:47'],
#  ['12549195',
#   'Show HN: Capacity Planning for Product Managers',
#   'http://blog.aha.io/capacity-planning-time-tracking/',
#   '1',
#   '0',
#   'bdehaaff',
#   '9/21/2016 15:40'],
#  ['12549076',
#   'Show HN: Is code the best part of your product to outsource?',
#   'https://medium.com/paper-planes/is-code-is-the-best-part-of-your-product-to-outsource-c76acfbead09#.gw025goau',
#   '1',
#   '0',
#   'dardien',
#   '9/21/2016 15:29'],
#  ['12548871',
#   'Show HN: Phineas  build realtime apps with DynamoDB',
#   'https://gist.github.com/jatins/11aac836f25257148a1d61def2c7270c',
#   '15',
#   '2',
#   'jatins',
#   '9/21/2016 15:11'],
#  ['12548823',
#   'Show HN: Doctest  the lightest C++ testing framework  version 1.1 released',
#   '',
#   '7',
#   '0',
#   'onqtam',
#   '9/21/2016 15:06'],
#  ['12547904',
#   'Show HN: Designing your workplace',
#   'https://medium.com/life-in-belka/designing-your-workspace-bb8d1bc5473b#.eljuem88i',
#   '2',
#   '0',
#   'HipstaJules',
#   '9/21/2016 13:25'],
#  ['12547804',
#   'Show HN: A Collection of the Best Jobs-To-be-Done Resources and Examples',
#   'https://www.jobstobedone.xyz',
#   '2',
#   '0',
#   'guico',
#   '9/21/2016 13:11'],
#  ['12547365',
#   'Show HN: Semi-AI that tries to categorize the world in many languages',
#   'https://github.com/turbo/KnowledgeEngine',
#   '2',
#   '1',
#   'minxomat',
#   '9/21/2016 12:01'],
#  ['12547320',
#   'Show HN: Finn  Fast Raft framework using the Redis protocol',
#   'https://github.com/tidwall/finn/blob/master/README.md',
#   '3',
#   '0',
#   'tidwall',
#   '9/21/2016 11:57'],
#  ['12547304',
#   'Show HN: 3D Printing with Liquid, Sand, and Metal',
#   'http://makefastworkshop.com/hacks/?p=20160920',
#   '2',
#   '0',
#   'akumpf',
#   '9/21/2016 11:55'],
#  ['12547183',
#   'Show HN: f  A JavaScript / Node.js Functional Microservice Request Library',
#   'https://github.com/poly/f',
#   '2',
#   '0',
#   'keithwhor',
#   '9/21/2016 11:33'],
#  ['12547131',
#   'Show HN: StatusGrid  a simple status tracking app for teams',
#   'https://www.statusgrid.io',
#   '7',
#   '1',
#   'mpc',
#   '9/21/2016 11:23'],
#  ['12547124',
#   'Show HN: Compose a cantus firmus following the rules of species counterpoint',
#   'http://musicmachine.io/',
#   '2',
#   '0',
#   'jrleszcz',
#   '9/21/2016 11:22'],
#  ['12546976',
#   'Show HN: Easy HttpStatus. Choosing an HTTP Status Made Easy',
#   'http://vtorosyan.github.io/easy-http-status/',
#   '3',
#   '3',
#   'vtorosyan',
#   '9/21/2016 10:50'],
#  ['12546458',
#   'Show HN: Linux 3D Remake of the Game M.U.L.E. (Sourcecode Release)',
#   'https://github.com/yousry/COOL-The-Game',
#   '2',
#   '0',
#   'yousry',
#   '9/21/2016 8:43'],
#  ['12546412',
#   'Show HN: ZPDer  informs you when an NPM package you use is upgraded',
#   'http://zpder.herokuapp.com',
#   '27',
#   '21',
#   'shaharsol',
#   '9/21/2016 8:36'],
#  ['12546391',
#   'Show HN: DevStickers  iMessage stickers pack for developers',
#   'https://www.producthunt.com/tech/devstickers',
#   '1',
#   '0',
#   'bkmn',
#   '9/21/2016 8:32'],
#  ['12545675',
#   'Show HN: GitHub contribution shown right',
#   'http://gh-activity.com',
#   '3',
#   '5',
#   'natsu90',
#   '9/21/2016 5:35'],
#  ['12545228',
#   'Show HN: RocketAmp  Google AMP for Shopify',
#   'http://www.getrocketamp.com/',
#   '6',
#   '3',
#   'rocketamp',
#   '9/21/2016 3:44'],
#  ['12545219',
#   'Show HN: A comment system over the blockchain',
#   'https://github.com/juanpabloaj/comments_over_the_blockchain',
#   '2',
#   '0',
#   'juanpabloaj',
#   '9/21/2016 3:41'],
#  ['12545162',
#   'Show HN: Get in Job in Tech Without Coding',
#   'http://financeto.tech',
#   '1',
#   '0',
#   'mmckay',
#   '9/21/2016 3:24'],
#  ['12545087',
#   'Show HN: The clientside FormulaCompiler converts pseudocode to valid formulae',
#   'http://minxomat.github.io/FormulaCompiler',
#   '1',
#   '0',
#   'minxomat',
#   '9/21/2016 3:02'],
#  ['12544607',
#   'Show HN: A semi-perma death minecraft server',
#   'http://thequietcraft.com',
#   '2',
#   '1',
#   'reddytowns',
#   '9/21/2016 0:49'],
#  ['12543717',
#   'Show HN: Kello, the sleep revolution device',
#   'https://www.kickstarter.com/projects/8220280/kello-the-sleep-revolution-device-that-upgrades-yo',
#   '3',
#   '0',
#   'joss82',
#   '9/20/2016 21:50'],
#  ['12543457',
#   'Show HN: A-Painter: Paint in VR in Your Browser',
#   'https://blog.mozvr.com/a-painter/',
#   '19',
#   '2',
#   'ngokevin',
#   '9/20/2016 21:09'],
#  ['12543329',
#   'Show HN: Shape  helps you invest in line with your morals',
#   'https://itunes.apple.com/gb/app/shape/id1154658685?mt=8',
#   '2',
#   '1',
#   'tikr',
#   '9/20/2016 20:55'],
#  ['12542566',
#   'Show HN: Purescript-Carpenter, type-safe state management for React applications',
#   'https://github.com/arthur-xavier/purescript-carpenter',
#   '1',
#   '0',
#   'arthur-xavier',
#   '9/20/2016 19:32'],
#  ['12541961',
#   'Show HN: Pepo Campaigns  1st enterprise-grade email marketing platform for AWS',
#   'https://pepocampaigns.com/',
#   '2',
#   '2',
#   'betashop',
#   '9/20/2016 18:27'],
#  ['12541957',
#   'Show HN: Make Website Traffic Less Anonymous',
#   'https://www.leadboxer.com/',
#   '5',
#   '0',
#   'alexkehr',
#   '9/20/2016 18:26'],
#  ['12541493',
#   'Show HN: Changelog Cli Tool',
#   'https://www.npmjs.com/package/changelog-cli',
#   '1',
#   '0',
#   'romellogoodman',
#   '9/20/2016 17:47'],
#  ['12541209',
#   'Show HN: We make a opensource hardware that brings low cost machine to arduino',
#   '',
#   '1',
#   '2',
#   'JosephWang',
#   '9/20/2016 17:22'],
#  ['12540724',
#   'Show HN: Wysiwyg.css, a tiny CSS for generated HTML or Markdown content',
#   'http://jgthms.com/wysiwyg.css/',
#   '4',
#   '0',
#   'bbx',
#   '9/20/2016 16:23'],
#  ['12540032',
#   'Show HN: I made a URL shortener for HN',
#   'https://medium.com/@paulbiggar/introducing-hkrn-ws-4d5dc3ef627a#.2yug1wl1c',
#   '8',
#   '0',
#   'pbiggar',
#   '9/20/2016 15:02'],
#  ['12539829',
#   'Show HN: Our work-life balance app',
#   'http://daily-q.com/',
#   '3',
#   '0',
#   'daily-q',
#   '9/20/2016 14:36'],
#  ['12539576',
#   'Show HN: Spider Launcher for Android(5.0+)  a minimalist launcher with gestures',
#   'https://play.google.com/apps/testing/com.venkat.spiderlauncher',
#   '3',
#   '1',
#   'venkatramanka',
#   '9/20/2016 14:07'],
#  ['12539572',
#   'Show HN: Yet Another Photo Slideshow',
#   'https://silverscreen.io/',
#   '2',
#   '1',
#   'adrianpike',
#   '9/20/2016 14:07'],
#  ['12539291',
#   'Show HN: Security Journey--app security training for developers and testers',
#   'https://www.securityjourney.com/',
#   '3',
#   '1',
#   'edgeroute',
#   '9/20/2016 13:24'],
#  ['12539248',
#   'Show HN: Minimalist (Brutalist?) Real Estate Web Design',
#   'https://danearthur.com',
#   '13',
#   '22',
#   'cabinguy',
#   '9/20/2016 13:16'],
#  ['12539207',
#   'Show HN: Key&Pad. A Web Audio Synthesizer/XY-Pad Built with React.js and Redux',
#   'http://keyandpad.com/',
#   '6',
#   '2',
#   'joshwcomeau',
#   '9/20/2016 13:09'],
#  ['12539109',
#   'Show HN: Primitive Pictures',
#   'https://github.com/fogleman/primitive',
#   '893',
#   '169',
#   'fogleman',
#   '9/20/2016 12:55'],
#  ['12538892',
#   'Show HN: We built a popular plugin-based social app using HTML5',
#   'https://happening.im/hn',
#   '49',
#   '17',
#   'sssparkkk',
#   '9/20/2016 12:17'],
#  ['12538720',
#   'Show HN: Add effects to your webcam with a Chrome extension',
#   'https://www.zombocam.com',
#   '4',
#   '2',
#   'stiaje',
#   '9/20/2016 11:44'],
#  ['12538580',
#   'Show HN: Example of a Tcl extension in Go',
#   'https://tcl.wiki/48054',
#   '6',
#   '0',
#   'networked',
#   '9/20/2016 11:15'],
#  ['12538219',
#   'Show HN: MelodyAPI  GraphQL API for Go Package Metadata',
#   'https://melody-api.github.io/',
#   '4',
#   '0',
#   'rykov',
#   '9/20/2016 9:39'],
#  ['12538040',
#   'Show HN: Next generation Markdown editor based on Electron',
#   'https://github.com/amitmerchant1990/electron-markdownify',
#   '3',
#   '0',
#   'amitmerchant',
#   '9/20/2016 8:45'],
#  ['12537877',
#   'Show HN: React page visibility higher order component',
#   'https://github.com/pgilad/react-page-visibility',
#   '3',
#   '0',
#   'pgilad',
#   '9/20/2016 7:53'],
#  ['12537139',
#   'Show HN: Recursive stacking and modularization of `UITableViewDataSource(s)`',
#   'https://github.com/benguild/BGRecursiveTableViewDataSource',
#   '2',
#   '0',
#   'benguild',
#   '9/20/2016 4:46'],
#  ['12536864',
#   'Show HN: The First P2P In-Browser Internet Speed Test',
#   'https://diegorbaquero.github.io/PeerFast/',
#   '4',
#   '3',
#   'diegorbaquero',
#   '9/20/2016 3:41'],
#  ['12535776',
#   'Show HN: Ng-Elm  Write Angular 2 Components in Elm',
#   'https://github.com/camargo/ng-elm',
#   '8',
#   '0',
#   'nucleic',
#   '9/19/2016 23:59'],
#  ['12535655',
#   'Show HN: ShareRace  news aggregator with rankings',
#   'https://www.sharerace.com',
#   '3',
#   '3',
#   'ShareRace',
#   '9/19/2016 23:35'],
#  ['12534415',
#   'Show HN: rqlite  the lightweight, distributed relational database',
#   'https://github.com/rqlite',
#   '11',
#   '4',
#   'otoolep',
#   '9/19/2016 20:26'],
#  ['12534243',
#   'Show HN: Xcode 8 Source Code Extension to Generate Swift Initializers',
#   'https://github.com/Bouke/SwiftInitializerGenerator',
#   '14',
#   '3',
#   'bouke',
#   '9/19/2016 20:03'],
#  ['12533931',
#   'Show HN: SameTime  Video chat while sharing video, photos and browsing together',
#   'https://itunes.apple.com/ca/app/sametime-video-chat-on-steroids/id1146689962',
#   '5',
#   '2',
#   'coralreef',
#   '9/19/2016 19:15'],
#  ['12533830',
#   'Show HN: Serving streaming templated html in Node',
#   '',
#   '1',
#   '0',
#   'rook2pawn',
#   '9/19/2016 19:02'],
#  ['12533784',
#   'Show HN: Easy CouchDB Web Apps',
#   'https://spartasys.com',
#   '2',
#   '0',
#   'oblib',
#   '9/19/2016 18:54'],
#  ['12533764',
#   "Show HN: A simple expression parser in C++ that uses Dijkstra's Shunting-yard",
#   'https://github.com/bamos/cpp-expression-parser',
#   '2',
#   '0',
#   'bdamos',
#   '9/19/2016 18:53'],
#  ['12533731',
#   'Show HN: I made an app to buy and sell used stuff at workplace',
#   'https://itunes.apple.com/us/app/breakroom-buy-sell-stuff-at/id1143880147?ls=1&mt=8',
#   '2',
#   '0',
#   'baj84',
#   '9/19/2016 18:49'],
#  ['12533704',
#   'Show HN: IPromise  super simple self-motivation tool',
#   'http://ipromise.site/',
#   '1',
#   '0',
#   'semanser',
#   '9/19/2016 18:45'],
#  ['12533650',
#   'Show HN: Inside  The network of email newsletters',
#   'http://inside.com',
#   '4',
#   '0',
#   'awwstn',
#   '9/19/2016 18:40'],
#  ['12533418',
#   'Show HN: Dissemination  2d ASCII Game for IntelliJ IDEA',
#   'https://github.com/vxx1/Dissemination',
#   '1',
#   '0',
#   'vxx1',
#   '9/19/2016 18:13'],
#  ['12533157',
#   'Show HN: SearchTrack - The home for your research. Product Demo YC W2017.',
#   'https://www.youtube.com/watch?v=fJ0_7ndPV7o',
#   '2',
#   '1',
#   'animeshk',
#   '9/19/2016 17:39'],
#  ['12532821',
#   'Show HN: EmoDB  a distributed data store with a global streaming platform',
#   'https://bazaarvoice.github.io/emodb/',
#   '2',
#   '1',
#   'l8again',
#   '9/19/2016 16:55'],
#  ['12532252',
#   'Show HN: A new clean theme for Sphinx document generator',
#   'https://github.com/dmitriid/freja-sphinx',
#   '6',
#   '0',
#   'dmitriid',
#   '9/19/2016 15:41'],
#  ['12532241',
#   'Show HN: Paperbin  Note Taking and Bookmarking and Read Later (online, Mobi, Epub)',
#   'http://paperbin.co',
#   '8',
#   '3',
#   'jwebb99',
#   '9/19/2016 15:39'],
#  ['12531988',
#   'Show HN: Create simulated datasets in Python with Simulacrum',
#   'https://github.com/jbrambleDC/simulacrum',
#   '4',
#   '0',
#   'jbrambleDC',
#   '9/19/2016 15:09'],
#  ['12531487',
#   'Show HN: Arxiv.org/cs feed on telegram',
#   'https://telegram.me/arxiv_feed',
#   '1',
#   '0',
#   'federicoponzi',
#   '9/19/2016 14:00'],
#  ['12531079',
#   'Show HN: Inside  the network of email newsletters',
#   'http://Inside.com',
#   '2',
#   '0',
#   'awwstn',
#   '9/19/2016 13:03'],
#  ['12530943',
#   'Show HN: Fault injection library for testing',
#   'https://github.com/androm3da/libfaultinj',
#   '3',
#   '1',
#   'wyldfire',
#   '9/19/2016 12:43'],
#  ['12530668',
#   'Show HN: Zombocam  Filters and effects for your webcam',
#   'https://www.zombocam.com/',
#   '14',
#   '1',
#   'sigvef',
#   '9/19/2016 12:04'],
#  ['12530128',
#   'Show HN: Query protobufs using SQL',
#   'https://github.com/na-ka-na/object-query/tree/master/src/protobuf-query',
#   '2',
#   '0',
#   'na_ka_na',
#   '9/19/2016 9:55'],
#  ['12530013',
#   'Show HN: A list of CLI tools available on AWS Lambda',
#   'https://github.com/mbrock/whats-on-lambda',
#   '3',
#   '0',
#   'mbrock',
#   '9/19/2016 9:21'],
#  ['12529801',
#   'Show HN: Continuous Delivery in the Cloud',
#   'http://www.sealights.io/',
#   '1',
#   '0',
#   'tgsgsdgs',
#   '9/19/2016 8:24'],
#  ['12529644',
#   'Show HN: SNES Style Canvas Effects',
#   'https://briandgls.github.io/snes-style-canvas-effects/',
#   '18',
#   '4',
#   '__BrianDGLS__',
#   '9/19/2016 7:42'],
#  ['12528287',
#   'Show HN: Facebook Messenger Bot  Voice Recognition, NLP, Restaurant/News Search',
#   'https://github.com/hungtraan/FacebookBot',
#   '57',
#   '9',
#   'hungtraan',
#   '9/19/2016 1:55'],
#  ['12527935',
#   'Show HN: Gorgonia  primitives for building neural networks in Go (like Theano)',
#   'https://github.com/chewxy/gorgonia?hn=1',
#   '3',
#   '1',
#   'chewxy',
#   '9/19/2016 0:19'],
#  ['12527904',
#   'Show HN: CodeBuff  smart code formatter',
#   'https://github.com/antlr/codebuff',
#   '62',
#   '21',
#   'parrt',
#   '9/19/2016 0:11'],
#  ['12527705',
#   'Show HN:Contract Hound  An easy-to-use contract management solution',
#   'http://www.contracthound.com',
#   '4',
#   '0',
#   'bmilford',
#   '9/18/2016 23:16'],
#  ['12527533',
#   'Show HN: A curated list of talks about React or topics related to React',
#   'https://github.com/mightyCrow/awesome-react-talks',
#   '3',
#   '0',
#   'mightyCrow',
#   '9/18/2016 22:27'],
#  ['12527160',
#   'Show HN: Fluent Actions 1.0.2',
#   'https://github.com/ExplicitlyImplicit/AspNetCore.Mvc.FluentActions',
#   '2',
#   '0',
#   'ExplicitlyImpl',
#   '9/18/2016 20:52'],
#  ['12526635',
#   'Show HN: Wd, CLI tool for WebDriver',
#   'https://github.com/mbrock/wd',
#   '1',
#   '1',
#   'mbrock',
#   '9/18/2016 19:06'],
#  ['12526387',
#   'Show HN: GitHub repository view static navigation',
#   'https://github.com/tonglil/github-static-nav',
#   '1',
#   '0',
#   'tonglil',
#   '9/18/2016 18:18'],
#  ['12526189',
#   'Show HN: Knockout-spa implementation of the famous TodoMVC',
#   'https://github.com/onlyurei/todomvc-knockout-spa',
#   '1',
#   '1',
#   'onlyurei',
#   '9/18/2016 17:35'],
#  ['12525665',
#   'Show HN: Use do notation with promises in JS',
#   'https://medium.com/@djfm/an-elegant-form-of-do-notation-for-promises-in-24-lines-of-js-9d35fb2fbcc1#.pw8o0r3si',
#   '1',
#   '0',
#   'djfm',
#   '9/18/2016 15:27'],
#  ['12525494',
#   'Show HN: Noise Reduction Machine using Fourier Transforms',
#   'https://github.com/sanjivsoni/reimagined-computing-machine',
#   '2',
#   '1',
#   'sanjiv1994',
#   '9/18/2016 14:43'],
#  ['12525448',
#   'Show HN: SpaceNeovim  Spacemacs for Neovim',
#   'https://github.com/Tehnix/spaceneovim',
#   '105',
#   '27',
#   'Tehnix',
#   '9/18/2016 14:32'],
#  ['12525413',
#   'Show HN: Weekend Project - Website Uptime Monitoring Service',
#   '',
#   '6',
#   '4',
#   'webtechgal',
#   '9/18/2016 14:23'],
#  ['12525081',
#   'Show HN: A Catalog of React Components',
#   'https://github.com/brillout/awesome-react-components',
#   '2',
#   '1',
#   'rombri',
#   '9/18/2016 12:51'],
#  ['12525068',
#   'Show HN: Simple pendulum simulation with rational trigonometry',
#   'http://grondilu.github.io/pendulum.html',
#   '52',
#   '28',
#   'grondilu',
#   '9/18/2016 12:45'],
#  ['12524901',
#   'Show HN: Header.party  your ip and headers as json',
#   'https://header.party/',
#   '1',
#   '1',
#   'yawniek',
#   '9/18/2016 11:48'],
#  ['12524620',
#   'Show HN: I built a website that simplifies Congress and its activities',
#   'https://4us.com',
#   '96',
#   '33',
#   'bbrez1',
#   '9/18/2016 9:42'],
#  ['12524596',
#   'Show HN: Kizina  Self-Executing, Interactive Music Album Technology',
#   'https://github.com/NuChwezi/KIZINA',
#   '38',
#   '24',
#   'nfixx',
#   '9/18/2016 9:33'],
#  ['12523985',
#   'Show HN: Need feedback on my first Node.js application',
#   '',
#   '1',
#   '0',
#   'sunilkumarc',
#   '9/18/2016 4:52'],
#  ['12523053',
#   'Show HN: SpaceNeovim  Spacemacs for Neovim',
#   '',
#   '24',
#   '2',
#   'Tehnix',
#   '9/17/2016 23:21'],
#  ['12522564',
#   'Show HN: Rill  The universal/isomorphic router for modern JavaScript',
#   'https://rill.site',
#   '4',
#   '1',
#   'piercey4',
#   '9/17/2016 21:31'],
#  ['12520758',
#   'Show HN: Directory Tags for Lazy Programmers',
#   'https://github.com/joowani/dtags',
#   '11',
#   '0',
#   'joohwan',
#   '9/17/2016 15:03'],
#  ['12520326',
#   'Show HN: peek  A new social platform that allows you to create and share events',
#   'http://getpeeking.com',
#   '7',
#   '2',
#   'pranjalsatija',
#   '9/17/2016 13:07'],
#  ['12519659',
#   'Show HN: Crowdsourcing an Internet-only Band',
#   '',
#   '4',
#   '0',
#   'gmf',
#   '9/17/2016 8:22'],
#  ['12519538',
#   'Show HN: Artmaking API',
#   'https://theblackbox.ca/api',
#   '4',
#   '1',
#   'SuperPaintMan',
#   '9/17/2016 7:25'],
#  ['12519112',
#   'Show HN: Helpingo  The app for college life. (Play Store)',
#   'https://play.google.com/store/apps/details?id=com.helpingo.android',
#   '2',
#   '0',
#   'paramaggarwal',
#   '9/17/2016 4:27'],
#  ['12519060',
#   'Show HN: Great Deals on Video Games Delivered Straight to Your Inbox Daily',
#   'http://thecorbie.com',
#   '2',
#   '0',
#   'gohighbrow',
#   '9/17/2016 4:03'],
#  ['12517819',
#   'Show HN: Leave the Light On Written in Swift 3.0 and SpriteKit',
#   'https://itunes.apple.com/us/app/leave-the-light-on/id1138617362',
#   '1',
#   '0',
#   'rezashirazian',
#   '9/16/2016 22:24'],
#  ['12517426',
#   'Show HN: Herd location+interest based chat',
#   '',
#   '2',
#   '0',
#   'brysgo',
#   '9/16/2016 21:18'],
#  ['12517250',
#   'Show HN: PROJECT-0: buldng nxt gen tul. mpowr FREE Afri Afrikings  NU Cwezi',
#   'http://studio.nuchwezi.com',
#   '1',
#   '0',
#   'nfixx',
#   '9/16/2016 20:51'],
#  ['12517182',
#   'Show HN: OCCULT CRYPTO Built in Modern Africa, for Witchcraft and Politics',
#   'http://crypto.nuchwezi.com',
#   '3',
#   '0',
#   'nfixx',
#   '9/16/2016 20:42'],
#  ['12517180',
#   'Show HN:Spring boot style configuration mangement for Go',
#   'https://github.com/narup/gconfig',
#   '3',
#   '0',
#   'purans',
#   '9/16/2016 20:41'],
#  ['12516442',
#   'Show HN: Distributed Cloud YunFS',
#   'https://medium.com/@yunhaia_7306/preface-f086aad65b9e',
#   '3',
#   '0',
#   'yunhai',
#   '9/16/2016 19:00'],
#  ['12516156',
#   'Show HN: Phineas  build realtime apps with DynamoDB',
#   'https://gist.github.com/jatins/11aac836f25257148a1d61def2c7270c',
#   '4',
#   '0',
#   'jatins',
#   '9/16/2016 18:28'],
#  ['12515712',
#   'Show HN: Simple DAW-Like Beat Maker Using React+WebAudio',
#   'http://mixerjs.staging-samlau.us/',
#   '5',
#   '0',
#   'esayemm',
#   '9/16/2016 17:32'],
#  ['12515342',
#   'Show HN: A crowdfunding platform to combat patent trolls',
#   'https://unpatent.co',
#   '12',
#   '5',
#   'luisivan',
#   '9/16/2016 16:51'],
#  ['12515308',
#   'Show HN: Open Synthesis  open platform for CIA-style analysis of current events',
#   'https://open-synthesis-sandbox.herokuapp.com/',
#   '9',
#   '3',
#   'tschiller',
#   '9/16/2016 16:47'],
#  ['12514534',
#   'Show HN: Apply to MuckRocks Thiel Fellowship',
#   'https://www.muckrock.com/news/archives/2016/sep/16/apply-thiel-fellowship/',
#   '5',
#   '1',
#   'morisy',
#   '9/16/2016 15:12'],
#  ['12514516',
#   'Show HN: Coco Color my new invention, a coloring stylus for iOS & Android',
#   'http://www.cococolor.com',
#   '1',
#   '1',
#   'hughbell',
#   '9/16/2016 15:09'],
#  ['12514240',
#   'Show HN: GraphJoiner: Implementing GraphQL with joins',
#   'https://github.com/mwilliamson/node-graphjoiner',
#   '3',
#   '0',
#   'mwilliamson',
#   '9/16/2016 14:31'],
#  ['12514170',
#   'Show HN: dingo - a Google DNS-over-HTTPS caching proxy in Go',
#   'https://github.com/pforemski/dingo',
#   '75',
#   '31',
#   'pjf',
#   '9/16/2016 14:21'],
#  ['12513949',
#   'Show HN: Want some free virtual coins? Take this sort survey',
#   'http://www.1millioncoins.com',
#   '1',
#   '3',
#   'sharemywin',
#   '9/16/2016 13:51'],
#  ['12513874',
#   'Show HN: iOS  Safari-style text fields navigation for native apps',
#   'https://github.com/T-Pham/UITextField-Navigation',
#   '1',
#   '0',
#   'thanhp',
#   '9/16/2016 13:41'],
#  ['12513642',
#   'Show HN: An alternative for universal web app routing',
#   'https://github.com/wesleytodd/nighthawk',
#   '5',
#   '0',
#   'wesleytodd',
#   '9/16/2016 12:56'],
#  ['12513595',
#   'Show HN: Blink Protocol in Ruby',
#   'https://github.com/cjhdev/slow_blink',
#   '1',
#   '0',
#   'cjhdev',
#   '9/16/2016 12:45'],
#  ['12513324',
#   'Show HN: HTTP linter as a Chrome devtool',
#   'https://github.com/activesphere/httpolice-devtool',
#   '3',
#   '0',
#   'roansh',
#   '9/16/2016 11:44'],
#  ['12512933',
#   "Show HN: GitHub's Fixed Header for better accessibility",
#   'https://gist.github.com/amitmerchant1990/faff0fdf541a66093603bdee3d793daf',
#   '45',
#   '26',
#   'amitmerchant',
#   '9/16/2016 10:08'],
#  ['12512897',
#   'Show HN: Twitter stream visualization',
#   'http://statick.org:3001',
#   '3',
#   '1',
#   'nenadg',
#   '9/16/2016 9:56'],
#  ['12512620',
#   'Show HN: DudelDu a simple SHOUTcast server in Go',
#   'https://github.com/krotik/dudeldu',
#   '30',
#   '18',
#   'krotik',
#   '9/16/2016 8:23'],
#  ['12512525',
#   'Show HN: Encouraging STEM Using Advanced Math in Music',
#   'http://genius.com/Nemesis-fixx-do-the-math-lyrics',
#   '28',
#   '8',
#   'nfixx',
#   '9/16/2016 7:46'],
#  ['12512323',
#   'Show HN: Solving a not-so-easy riddle with clojure.math.combinatorics',
#   'http://blog.klipse.tech/clojure/2016/09/16/combinatorics-riddle.html',
#   '2',
#   '0',
#   'viebel',
#   '9/16/2016 6:55'],
#  ['12512208',
#   'Show HN: Try new python packages could be soo easy',
#   'https://github.com/timofurrer/try',
#   '1',
#   '0',
#   'tuxtimo',
#   '9/16/2016 6:18'],
#  ['12511936',
#   'Show HN: JSPerf  Create, Share and Benchmark JavaScript Snippets',
#   'http://jsperf.hasharray.pw/',
#   '10',
#   '2',
#   'hasharray',
#   '9/16/2016 4:57'],
#  ['12511750',
#   'Show HN: A quick tool for dumping packet payloads from pcap files',
#   'https://github.com/wrigby/flowdump',
#   '1',
#   '0',
#   'wrigby',
#   '9/16/2016 4:05'],
#  ['12511241',
#   'Show HN: Start building Pulse templates faster than ever before with Blocs',
#   'https://www.pulsecms.com/blocs',
#   '2',
#   '0',
#   'latteperday',
#   '9/16/2016 1:13'],
#  ['12510265',
#   'Show HN: City Browser, an interface for filtering US cities',
#   'https://sfirrin.github.io/CityBrowser/',
#   '14',
#   '1',
#   'swf',
#   '9/15/2016 22:11'],
#  ['12510190',
#   'Show HN: Private Bitcoin and Blockchain tutoring',
#   'http://www.bitcointutoring.com/?hnews',
#   '5',
#   '1',
#   'bitcointutoring',
#   '9/15/2016 22:00'],
#  ['12510163',
#   'Show HN: Week Over Week Growth Calculator',
#   'https://www.hypemarket.com/growth',
#   '1',
#   '0',
#   'drum',
#   '9/15/2016 21:55'],
#  ['12509817',
#   'Show HN: I built an auto aggregating bot, collecting trending funny pictures',
#   'http://www.pixpit.com',
#   '11',
#   '10',
#   'rezashirazian',
#   '9/15/2016 21:04'],
#  ['12509617',
#   'Show HN: Enhance python interpreter to automatically save your work as a script',
#   'https://github.com/FallibleInc/pysession',
#   '1',
#   '0',
#   'mkagenius',
#   '9/15/2016 20:37'],
#  ['12509330',
#   'Show HN: Coderoulette, a pair programming game for developers',
#   '',
#   '42',
#   '9',
#   'arielcamus',
#   '9/15/2016 19:59'],
#  ['12509179',
#   'Show HN: ShouldBe  Eye-pleasing assertions for complex object graphs in C#',
#   'https://github.com/Martaver/ShouldBe',
#   '1',
#   '1',
#   'martaver',
#   '9/15/2016 19:43'],
#  ['12509106',
#   'Show HN: Text Summarizer available as API, online and desktop application',
#   'http://summarizer.intellexer.com/',
#   '3',
#   '0',
#   'Yeroniomus',
#   '9/15/2016 19:34'],
#  ['12508574',
#   "Show HN: Pay $1 for every day you don't push to GitHub",
#   'http://codeorelse.com',
#   '7',
#   '7',
#   'Andrewbass',
#   '9/15/2016 18:33'],
#  ['12508281',
#   'Show HN: CatTrash',
#   'https://lolz.bottr.co',
#   '2',
#   '0',
#   'bottr',
#   '9/15/2016 17:55'],
#  ['12507912',
#   'Show HN: Daemoniker, OS X/Linux/Win daemonization, signal handling for Python 3.5',
#   'https://github.com/Muterra/py_daemoniker',
#   '2',
#   '0',
#   'nbadg',
#   '9/15/2016 17:14'],
#  ['12507868',
#   'Show HN: My first video course: Excel for Accountants',
#   'http://excelstart.com/welcome',
#   '2',
#   '1',
#   'aarondf',
#   '9/15/2016 17:09'],
#  ['12507776',
#   'Show HN: The wearable that communicates entirely through your sense of touch',
#   'https://wearmoment.com',
#   '16',
#   '8',
#   'jakerockland',
#   '9/15/2016 16:59'],
#  ['12507770',
#   'Show HN: Weekly email about Ethereum and its ecosystem',
#   'http://us14.campaign-archive2.com/?u=4c6ec57a148e890524b6ac91f&id=4e2e1d9a87&e=41430cdddb',
#   '4',
#   '0',
#   'evanvanness',
#   '9/15/2016 16:59'],
#  ['12507379',
#   'Show HN: A minimalistic cloud provider',
#   'https://datamantle.com/',
#   '61',
#   '70',
#   'twelvenmonkeys',
#   '9/15/2016 16:15'],
#  ['12507346',
#   'Show HN: A live-action fighting game made with Lua, Blender and the Gimp',
#   'http://mthompson.org/bloodbath.html',
#   '4',
#   '0',
#   'cblop',
#   '9/15/2016 16:12'],
#  ['12507276',
#   'Show HN: Parenteeno parental monitoring goes FREE',
#   'http://www.parenteeno.com',
#   '1',
#   '1',
#   'parenteeno',
#   '9/15/2016 16:05'],
#  ['12507233',
#   'Show HN: Magic Keyboard',
#   'http://magickeyboard.io/',
#   '12',
#   '6',
#   'feross',
#   '9/15/2016 16:00'],
#  ['12506858',
#   'Show HN: Microblog about your startup journey',
#   'http://ambitiontrek.com',
#   '1',
#   '0',
#   'balconyview',
#   '9/15/2016 15:16'],
#  ['12506846',
#   'Show HN: Color Code Quiz (Hex and RGB)',
#   'https://roche.io/color-quiz/',
#   '2',
#   '0',
#   'rocheio',
#   '9/15/2016 15:15'],
#  ['12506801',
#   'Show HN: Microservices and container monitoring',
#   'https://www.dynatrace.com/capabilities/microservices-and-container-monitoring/',
#   '2',
#   '0',
#   'stevelamont',
#   '9/15/2016 15:10'],
#  ['12506701',
#   'Show HN: Learn to Manage Your Own Cloud Infrastructure Using AWS',
#   'http://awsfordevs.com/',
#   '5',
#   '0',
#   'austenallred',
#   '9/15/2016 14:59'],
#  ['12506219',
#   'Show HN: LightNudge Realtime Demo',
#   'http://makefastworkshop.com/lightnudge/livedemo/?run=1',
#   '1',
#   '0',
#   'akumpf',
#   '9/15/2016 14:06'],
#  ['12506025',
#   'Show HN: Vectr  Free Online Vector Graphics Editor',
#   'https://vectr.com/?source=hn',
#   '11',
#   '1',
#   'gerfficiency',
#   '9/15/2016 13:43'],
#  ['12505906',
#   'Show HN: Logtrail  A Kibana plugin for logs that clones the Papertrail UI',
#   'https://github.com/sivasamyk/logtrail',
#   '65',
#   '17',
#   'avisk',
#   '9/15/2016 13:26'],
#  ['12505139',
#   'Show HN: GraphicsJS, New Powerful Free Open-Source JavaScript Graphics Library',
#   'http://www.graphicsjs.org',
#   '124',
#   '43',
#   'andreykh',
#   '9/15/2016 11:36'],
#  ['12504815',
#   'Show HN: The GoPiGo Line Follower in Python',
#   'https://www.youtube.com/watch?v=1A07_dVoYJc',
#   '1',
#   '0',
#   'johncole',
#   '9/15/2016 10:41'],
#  ['12504789',
#   'Show HN: JavaScript library that manages open-source JavaScript and/or CSS libraries',
#   'https://github.com/bhanu-mnit/jsAssist',
#   '2',
#   '1',
#   'shenanigan',
#   '9/15/2016 10:34'],
#  ['12504774',
#   'Show HN: Motivational Budget, a tool to know how much you can save [no signup]',
#   'http://www.motivationalbudget.com',
#   '1',
#   '3',
#   'iraldir',
#   '9/15/2016 10:31'],
#  ['12504602',
#   'Show HN: High memory Droplets',
#   'https://www.digitalocean.com/pricing/#memory',
#   '3',
#   '1',
#   'fdim',
#   '9/15/2016 9:38'],
#  ['12504490',
#   'Show HN: EliasDB a graph based database in Go',
#   'https://github.com/krotik/eliasdb',
#   '6',
#   '0',
#   'krotik',
#   '9/15/2016 9:06'],
#  ['12504330',
#   'Show HN: Customizable Pub/Sub Service, Scales to Thousands of Hosts',
#   'https://github.com/SocketCluster/socketcluster/blob/master/scc-guide.md',
#   '8',
#   '0',
#   'jondubois',
#   '9/15/2016 8:27'],
#  ['12504285',
#   'Show HN: OldGeekJobs.com',
#   'https://oldgeekjobs.com',
#   '8',
#   '0',
#   'johnwheeler',
#   '9/15/2016 8:16'],
#  ['12504012',
#   'Show HN: I invented a caffeinated toothpaste',
#   'https://www.powertoothpaste.com/',
#   '169',
#   '280',
#   'nappy',
#   '9/15/2016 7:07'],
#  ['12503786',
#   'Show HN: I published a book on Django',
#   '',
#   '4',
#   '3',
#   'asadjb',
#   '9/15/2016 5:58'],
#  ['12503573',
#   'Show HN: Reflexio',
#   'https://github.com/ketanhwr/reflexio',
#   '6',
#   '1',
#   'acidbzeus',
#   '9/15/2016 5:06'],
#  ['12502488',
#   'Show HN: A simple virus-programming game',
#   'http://robodojo.club/doc/#0#2#main:Top#intro:Introduction%20%26%20Demos',
#   '3',
#   '0',
#   'mixermf',
#   '9/15/2016 0:32'],
#  ['12502481',
#   'Show HN: Easily save your favorite music app audio output (macOS, free)',
#   'https://vokally.com',
#   '4',
#   '5',
#   'parisian',
#   '9/15/2016 0:32'],
#  ['12502032',
#   'Show HN: Fundhub.xyz  Make better fund investment decisions',
#   'https://fundhub.xyz/',
#   '2',
#   '1',
#   'kikowi',
#   '9/14/2016 23:17'],
#  ['12501774',
#   'Show HN: Using Parsing Expression Grammars to rewrite source code',
#   'https://github.com/sebcat/move-literals',
#   '63',
#   '26',
#   'sebcat',
#   '9/14/2016 22:33'],
#  ['12501656',
#   "Show HN: Live Beacon  The World's Simplest iBeacon",
#   'http://www.livebeacon.com/',
#   '2',
#   '0',
#   'livebeacon',
#   '9/14/2016 22:15'],
#  ['12501198',
#   'Show HN: Serialization with Colfer code generator',
#   'https://github.com/pascaldekloe/colfer',
#   '3',
#   '0',
#   'kloeq',
#   '9/14/2016 21:03'],
#  ['12500943',
#   'Show HN: Tutorial  OTG networking on the Raspberry Pi',
#   'http://blog.alexellis.io/pizero-otg-swarm/',
#   '4',
#   '0',
#   'alexellisuk',
#   '9/14/2016 20:25'],
#  ['12500452',
#   'Show HN: First React Native iMessage Planning App (iOS 10)',
#   'https://www.producthunt.com/tech/voo-plan-for-imessage',
#   '4',
#   '0',
#   'dozoisch',
#   '9/14/2016 19:31'],
#  ['12499875',
#   'Show HN: Who runs this  A Chrome extension that shows who runs a site',
#   'https://chrome.google.com/webstore/detail/who-runs-this/jfccjdbjpkmppcpdogdfbgillpaakmgn',
#   '50',
#   '44',
#   'kaolti',
#   '9/14/2016 18:27'],
#  ['12499362',
#   'Show HN: Rainbow bezier in React',
#   'https://ripleyaffect.github.io/rainbow-bezier/',
#   '6',
#   '0',
#   'ripleyp',
#   '9/14/2016 17:37'],
#  ['12498976',
#   'Show HN: API for free deep learning models',
#   'http://openapi.keplr.io',
#   '26',
#   '6',
#   'adaorardor',
#   '9/14/2016 17:00'],
#  ['12498216',
#   'Show HN: My LaCroix  Create a Can',
#   'http://mylacroix.com/',
#   '7',
#   '1',
#   'thoughtpalette',
#   '9/14/2016 15:53'],
#  ['12498055',
#   'Show HN: Enhanced Google Drive and Dropbox Integrations',
#   'http://blog.aha.io/google-drive-dropbox-integration/',
#   '2',
#   '0',
#   'bdehaaff',
#   '9/14/2016 15:38'],
#  ['12497887',
#   'Show HN: Run a simulation to see what ethnicity and gender your baby could be',
#   'http://whatwillmybabybe.com',
#   '1',
#   '0',
#   'wwmbb',
#   '9/14/2016 15:26'],
#  ['12497571',
#   'Show HN: Simple pattern-matching in Common Lisp',
#   'https://gist.github.com/andreareina/b8a9cb27cadf7a0860619a006dd8c31b',
#   '1',
#   '1',
#   'andreareina',
#   '9/14/2016 15:00'],
#  ['12497324',
#   'Show HN: Open-source face search engine',
#   'https://github.com/pavelgonchar/face-search',
#   '17',
#   '0',
#   'pavelgonchar',
#   '9/14/2016 14:41'],
#  ['12497259',
#   'Show HN: Cardpop  Snapchat for postcards',
#   'https://itunes.apple.com/us/app/cardpop-design-mail-fun-postcards/id1086532449?mt=8',
#   '1',
#   '1',
#   'tgoldberg',
#   '9/14/2016 14:37'],
#  ['12497080',
#   'Show HN: Text-based histograms in PostgreSQL',
#   'https://github.com/wolever/pg-histogram',
#   '3',
#   '0',
#   'wolever',
#   '9/14/2016 14:20'],
#  ['12497022',
#   'Show HN: Aggregating remote jobs with AI',
#   'http://sagfi.com',
#   '17',
#   '3',
#   'sihaelov',
#   '9/14/2016 14:13'],
#  ['12496964',
#   'Show HN: Directus  Free and Open-Source Headless CMS',
#   'http://getdirectus.com/',
#   '18',
#   '4',
#   'benhaynes',
#   '9/14/2016 14:07'],
#  ['12496937',
#   'Show HN: Learn Modern Cloud Infrastructure Using AWS',
#   'https://badgerops.net/learn-modern-cloud-infrastructure-with-aws.html',
#   '8',
#   '6',
#   'badgerops',
#   '9/14/2016 14:03'],
#  ['12496327',
#   'Show HN: Favorize  Highlight, share, and discover bite-size content',
#   'https://www.producthunt.com/tech/favorize-2',
# ...
#   'https://www.instana.com/blog/introducing-logical-view/',
#   '6',
#   '0',
#   'enricobruschini',
#   '8/22/2016 13:06'],
#  ['12335986',
#   'Show HN: Shortcuts  A CLI manager for text replacements on macOS',
#   'https://github.com/rodionovd/shortcuts',
#   '2',
#   '0',
#   'ololoev',
#   '8/22/2016 13:00'],
#  ['12335796',
#   'Show HN: Ridiculously over-engineered my blog',
#   'https://ponyfoo.com/articles/most-over-engineered-blog-ever?',
#   '15',
#   '3',
#   'bevacqua',
#   '8/22/2016 12:26'],
#  ['12335346',
#   'Show HN: Emprovio  write your diary and improve your workplace',
#   'http://emprovio.com/',
#   '1',
#   '0',
#   'ksaric',
#   '8/22/2016 10:44'],
#  ['12335205',
#   'Show HN: React Router Path Extractor Webpack Plugin',
#   'https://github.com/mbaasy/react-router-path-extractor-webpack-plugin',
#   '2',
#   '0',
#   'marcgreenstock',
#   '8/22/2016 10:04'],
#  ['12335157',
#   'Show HN: AISLER  Ship better electronics together',
#   'https://aisler.net/',
#   '3',
#   '1',
#   'paddi91',
#   '8/22/2016 9:49'],
#  ['12335101',
#   'Show HN: Use performance metrics for health monitoring',
#   'https://github.com/firehol/netdata/wiki/health-monitoring?alarms',
#   '2',
#   '0',
#   'ktsaou',
#   '8/22/2016 9:34'],
#  ['12334976',
#   'Show HN: Firefox crack for linux  run unsigned addons without recompiling',
#   'https://gist.github.com/zb3/cfbb94e45d9318adcb63051a66a586ea',
#   '9',
#   '3',
#   'zb3',
#   '8/22/2016 9:05'],
#  ['12334921',
#   'Show HN: Download and save all videos on a web page',
#   'https://videocyborg.com/',
#   '1',
#   '0',
#   'apancyborg',
#   '8/22/2016 8:47'],
#  ['12334914',
#   'Show HN: IntelliJ TooltipRunner plugin  Java main execution as tooltip result',
#   'https://plugins.jetbrains.com/plugin/8543?pr=idea',
#   '2',
#   '0',
#   'jcraane',
#   '8/22/2016 8:44'],
#  ['12334759',
#   'Show HN: Te  Show network information in colors from the command line',
#   'https://github.com/hypsurus/te',
#   '2',
#   '1',
#   'Hypsurus',
#   '8/22/2016 7:57'],
#  ['12334607',
#   'Show HN: High-level Python 3 library and CLI tool for creating .torrent files',
#   'https://github.com/kz26/dottorrent',
#   '2',
#   '0',
#   'whitehat2k9',
#   '8/22/2016 7:12'],
#  ['12334604',
#   'Show HN: 1) Build Team 2) Interview 3) Offer',
#   'https://netin.co/teams?hn',
#   '2',
#   '1',
#   'soheil',
#   '8/22/2016 7:11'],
#  ['12334521',
#   'Show HN: Try `ssh hackinto.sysengquiz3.host`, a Linux/Systems/Docker challenge',
#   '',
#   '2',
#   '0',
#   'phred_pui',
#   '8/22/2016 6:46'],
#  ['12334300',
#   'Show HN: Get hired as a team',
#   'https://netin.co/teams',
#   '2',
#   '1',
#   'soheil',
#   '8/22/2016 5:27'],
#  ['12333659',
#   'Show HN: New app to stream music from your phone to the browser',
#   'http://www.weezzler.com',
#   '1',
#   '2',
#   'atamagno',
#   '8/22/2016 1:55'],
#  ['12333633',
#   'Show HN: Vanilla JavaScript game with a bare-essentials node server',
#   'http://game.korynunn.com/',
#   '3',
#   '1',
#   'korynunn',
#   '8/22/2016 1:47'],
#  ['12333069',
#   'Show HN: Websee  Naturally Crowdsourcing the Happenings of the Web',
#   'https://www.websee.io/',
#   '5',
#   '3',
#   'laser',
#   '8/21/2016 22:44'],
#  ['12332674',
#   'Show HN: Simple Flow-Based Machine Learning and Automation',
#   'https://github.com/sorpaas/flow',
#   '2',
#   '0',
#   'sorpaas',
#   '8/21/2016 20:48'],
#  ['12332519',
#   'Show HN: Draper  Atomic and Modular Styling for React Native',
#   'https://github.com/winkerVSbecks/draper',
#   '1',
#   '0',
#   'winkerVSbecks',
#   '8/21/2016 20:11'],
#  ['12331915',
#   'Show HN: Cryptic  A sensible secret management toolkit and Go library',
#   'https://github.com/domodwyer/cryptic',
#   '93',
#   '32',
#   'domodwyer',
#   '8/21/2016 17:59'],
#  ['12331688',
#   'Show HN: lickcreator  Web based guitar TAB',
#   'http://lickcreator.com',
#   '2',
#   '0',
#   'arc_of_descent',
#   '8/21/2016 17:14'],
#  ['12331624',
#   'Show HN: Dynamic Web Content Compression Benchmark',
#   'http://encode.ru/threads/2575-SLZ-stateless-zip-fast-zlib-compatible-compressor?p=49537&viewfull=1#post49537',
#   '1',
#   '0',
#   'powturbo',
#   '8/21/2016 17:00'],
#  ['12331109',
#   'Show HN: Become a Web Developer - learn coding, resumes, interviews, and more',
#   'https://HeyMentor.co',
#   '9',
#   '5',
#   'w_h_user',
#   '8/21/2016 14:52'],
#  ['12331089',
#   'Show HN: A static social media sharing button generator, now open source',
#   'https://github.com/fourtonfish/SimpleSharingButtons',
#   '2',
#   '0',
#   'ftfish',
#   '8/21/2016 14:47'],
#  ['12330897',
#   'Show HN: Pride and Prejudice | On-web',
#   'https://bubbl.in/book/pride-and-prejudice-by-jane-austen/1',
#   '3',
#   '0',
#   'marvindanig',
#   '8/21/2016 13:48'],
#  ['12330638',
#   'Show HN: Jira Oh-My-ZSH plugin with Git interaction',
#   'https://github.com/igoradamenko/jira.plugin.zsh',
#   '3',
#   '0',
#   'igoradamenko',
#   '8/21/2016 12:14'],
#  ['12330153',
#   'Show HN: Play peg solitaire in browser',
#   'https://roonyh.github.io/pegs/',
#   '1',
#   '4',
#   'roonyh',
#   '8/21/2016 9:35'],
#  ['12328849',
#   'Show HN: An easy way to browse photo(image) for iOS(OC)',
#   'https://github.com/iphone5solo/PYPhotoBrowser',
#   '1',
#   '0',
#   'iphone5solo',
#   '8/20/2016 23:59'],
#  ['12328557',
#   'Show HN: The Nostalgia Machine  Get your childhood jam on',
#   'http://thenostalgiamachine.com/',
#   '10',
#   '5',
#   'JusticeJuice',
#   '8/20/2016 22:34'],
#  ['12327860',
#   'Show HN: A practical guide to analytics for makers, hackers, and product people',
#   'http://essentialanalytics.xyz',
#   '3',
#   '0',
#   'kierantie',
#   '8/20/2016 18:54'],
#  ['12327822',
#   'Show HN: Iconizer  Effortlessly resize iOS icons',
#   'https://github.com/SandPhoenix/iconizer',
#   '16',
#   '0',
#   'SandPhoenix',
#   '8/20/2016 18:44'],
#  ['12327712',
#   'Show HN: Decided to sell my Voxel engine source',
#   '',
#   '3',
#   '1',
#   'nergal',
#   '8/20/2016 18:17'],
#  ['12327601',
#   'Show HN: Make using plain-old C APIs from C++ more fun (and safer)',
#   'https://github.com/mgelde/CWrap',
#   '2',
#   '0',
#   'redmnic',
#   '8/20/2016 17:51'],
#  ['12327440',
#   'Show HN: Big files and SHA-1 computation in the browser',
#   'https://medium.com/@szydan/big-files-and-sha-1-computation-in-the-browser-6b88e80d2bf1#.hvoz8cgvl',
#   '2',
#   '0',
#   'szydan',
#   '8/20/2016 17:17'],
#  ['12327342',
#   'Show HN, Another Productivity App, Mac OS X',
#   'https://itunes.apple.com/us/app/bspace/id1092405727?mt=12',
#   '1',
#   '1',
#   '_Rohan_',
#   '8/20/2016 16:57'],
#  ['12327339',
#   'Show HN: Every morning get an inspiring video to your mail to motivate you',
#   'http://1ztl6ul0.launchrock.co',
#   '2',
#   '1',
#   'akshaynathr',
#   '8/20/2016 16:56'],
#  ['12327264',
#   'Show HN: Term Term Revolution  Dance Dance Revolution in Your Terminal',
#   'https://github.com/jordanbuchman/termtermrevolution',
#   '2',
#   '0',
#   'timecube',
#   '8/20/2016 16:41'],
#  ['12326986',
#   'Show HN: Cohesion  A tool for measuring Python class cohesion',
#   'https://github.com/mschwager/cohesion',
#   '3',
#   '0',
#   'schwag09',
#   '8/20/2016 15:29'],
#  ['12326949',
#   'Show HN: Newsflow  Real News Feed',
#   'https://itunes.apple.com/us/app/newsflow-real-news-feed/id1144120498',
#   '1',
#   '0',
#   'longsangstan',
#   '8/20/2016 15:18'],
#  ['12326868',
#   'Show HN: Pomodoro.cc  Boost your productivity',
#   'https://pomodoro.cc/',
#   '2',
#   '0',
#   'christian_fei',
#   '8/20/2016 14:58'],
#  ['12326445',
#   "Show HN: Procedural drum n' bass for Bitcoin",
#   'https://procedural.party/',
#   '3',
#   '0',
#   'chr15m',
#   '8/20/2016 13:17'],
#  ['12325658',
#   'Show HN: Matrix lab in JavaScript',
#   'https://github.com/timqian/mathlab',
#   '4',
#   '1',
#   'timqian',
#   '8/20/2016 7:57'],
#  ['12325153',
#   'Show HN: Turn your Terraform .tfstate outputs into a valid .tfvars file',
#   'https://github.com/artktec/tfvars-out',
#   '6',
#   '0',
#   'MobiKid',
#   '8/20/2016 4:08'],
#  ['12324145',
#   'Show HN: My chat app using Redux and Angular 2',
#   'https://github.com/ng-book/angular2-redux-chat',
#   '4',
#   '0',
#   'jashmenn',
#   '8/19/2016 23:03'],
#  ['12323237',
#   'Show HN: A CORS proxy in a container',
#   'https://github.com/imjacobclark/cors-container',
#   '7',
#   '0',
#   'imjacobclark',
#   '8/19/2016 20:30'],
#  ['12322931',
#   'Show HN: Realtime, self-hosted monitoring for Hapi.js like GitHub Status (4fun)',
#   'https://github.com/ziyasal/hapijs-status-monitor',
#   '5',
#   '0',
#   'ziyasal',
#   '8/19/2016 19:45'],
#  ['12322399',
#   'Show HN: Yet another framework for Managing APIs with AWS Lambda',
#   'https://github.com/VdoCipher/cloudhopper',
#   '6',
#   '0',
#   'vibhavsinha',
#   '8/19/2016 18:43'],
#  ['12322206',
#   'Show HN: List of coworking spaces in Berlin (and other cities)',
#   'https://listmap.io/coworking-spaces/berlin-germany/',
#   '5',
#   '1',
#   'Kunix',
#   '8/19/2016 18:24'],
#  ['12322000',
#   'Show HN: Ridiculously over-engineered my blog',
#   'https://ponyfoo.com/articles/most-over-engineered-blog-ever',
#   '13',
#   '0',
#   'bevacqua',
#   '8/19/2016 18:02'],
#  ['12321125',
#   'Show HN: A Scala library to dynamically generate JSON from objects',
#   'https://github.com/rcoh/lasic',
#   '1',
#   '0',
#   'rusbus',
#   '8/19/2016 16:16'],
#  ['12320461',
#   'Show HN: Replify  Create a REPL for any command',
#   'https://gist.github.com/danielrw7/bb88e3dad565c0d8ee54031f6b758a09',
#   '112',
#   '18',
#   'danielrw7',
#   '8/19/2016 14:58'],
#  ['12320393',
#   'Show HN: Twincl Notes  a free Markdown notes web app',
#   'https://twincl.com/community/*68c/twincl-notes',
#   '2',
#   '0',
#   'arthurtw',
#   '8/19/2016 14:51'],
#  ['12320069',
#   'Show HN: Flatmarket, an open source e-commerce platform for static websites',
#   'https://github.com/christophercliff/flatmarket',
#   '4',
#   '0',
#   'ctcliff',
#   '8/19/2016 14:06'],
#  ['12319990',
#   "Show HN: Jumkey.com  India's Largest Fashion Jewellery Store",
#   'https://www.jumkey.com/',
#   '1',
#   '0',
#   'pajju',
#   '8/19/2016 13:56'],
#  ['12319981',
#   'Show HN: Merge PDF Tool  A Free Tool to Join PDF Files',
#   'http://mergepdftool.com',
#   '3',
#   '0',
#   'harryngh',
#   '8/19/2016 13:55'],
#  ['12319769',
#   'Show HN: Visualizing the 2016 Presidential Discussion in Real Time (D3js)',
#   'http://PulseOnPolitics.com',
#   '4',
#   '0',
#   'nstogner',
#   '8/19/2016 13:24'],
#  ['12319711',
#   'Show HN: RobotReviewer, automatic evidence based medicine from PDFs',
#   'https://robot-reviewer.vortext.systems/',
#   '5',
#   '0',
#   'anon1253',
#   '8/19/2016 13:14'],
#  ['12319661',
#   'Show HN: A Multiplayer Geography Game Using WebSockets',
#   'https://github.com/abrenaut/posio',
#   '220',
#   '69',
#   'abrena',
#   '8/19/2016 13:00'],
#  ['12319511',
#   'Show HN: Visualize your data in cool visualizations for free',
#   'http://apps.baapps.com/preview/index.html',
#   '3',
#   '0',
#   'abhishekdesai',
#   '8/19/2016 12:20'],
#  ['12319420',
#   'Show HN: Open Socialism  Hack on a democracy/capitalism alternative',
#   'https://opensocialism.com',
#   '2',
#   '10',
#   'BobTheCoder',
#   '8/19/2016 11:57'],
#  ['12318981',
#   'Show HN: Unmask Real Companies Behind Jobs from Recruiters',
#   '',
#   '4',
#   '3',
#   'antfie',
#   '8/19/2016 10:01'],
#  ['12318750',
#   'Show HN: Content as a service platform. Create once, publish everywhere',
#   'https://snipl.io',
#   '3',
#   '3',
#   'luigim',
#   '8/19/2016 8:53'],
#  ['12318724',
#   'Show HN: Preempt Web Attacks',
#   '',
#   '4',
#   '3',
#   'malleablebyte',
#   '8/19/2016 8:44'],
#  ['12318572',
#   'Show HN: HideMyFaceTime  Stop watching your own face during FaceTime calls',
#   'https://andrewdeniszczyc.com/hidemyfacetime/',
#   '2',
#   '0',
#   'adeniszczyc',
#   '8/19/2016 8:01'],
#  ['12317448',
#   'Show HN: Chatskills  Run Alexa apps on the command-line, in Slack, or anywhere',
#   'https://github.com/primaryobjects/chatskills',
#   '2',
#   '0',
#   'primaryobjects',
#   '8/19/2016 1:29'],
#  ['12317356',
#   'Show HN: Make YAML Snapshots of Your My Personal Kanban Boards',
#   'https://github.com/jmdots/mpkb2yaml',
#   '1',
#   '0',
#   'josh-wrale',
#   '8/19/2016 1:04'],
#  ['12317319',
#   'Show HN: Tesseract4java  A GUI for Training and Performing OCR with Tesseract',
#   'https://github.com/tesseract4java/tesseract4java',
#   '2',
#   '0',
#   'pvorb',
#   '8/19/2016 0:54'],
#  ['12317293',
#   'Show HN: WebGL Voxel Explosions',
#   'https://emnh.github.io/voxel-explosions-demo/#game-test',
#   '1',
#   '0',
#   'hvidevold',
#   '8/19/2016 0:47'],
#  ['12317036',
#   'Show HN: Open-source web-based code compiler/interpreter',
#   'http://hackide.herokuapp.com/',
#   '4',
#   '0',
#   'sahil2305dua',
#   '8/18/2016 23:41'],
#  ['12317003',
#   'Show HN: Command Line Interface (CLI) for GitHub Profiles and Repos',
#   'https://www.npmjs.com/package/github-check-cli',
#   '1',
#   '0',
#   'sahil2305dua',
#   '8/18/2016 23:33'],
#  ['12316178',
#   'Show HN: HTTP proxy server to automatically authenticate through an NTLM proxy',
#   'https://github.com/genotrance/px',
#   '2',
#   '0',
#   'gtrs',
#   '8/18/2016 20:43'],
#  ['12316093',
#   'Show HN: Matrix style Instagram feed in your terminal',
#   'https://github.com/samsiegart/matrixgram',
#   '9',
#   '0',
#   'siegermann',
#   '8/18/2016 20:28'],
#  ['12315832',
#   'Show HN: Simple password protection of web pages in restdb.io',
#   'https://restdb.io/blog/#!posts/57acbc2a1aa8391e00000496',
#   '6',
#   '0',
#   'knutmartin',
#   '8/18/2016 19:54'],
#  ['12315029',
#   'Show HN: Kev  S3 and Redis as Datastores (with Redis Indexing)',
#   'https://github.com/kevproject/kev',
#   '8',
#   '0',
#   'bjinwright',
#   '8/18/2016 18:18'],
#  ['12314829',
#   'Show HN: PokÃ©Hunt - a curated list of PokemonGo resources',
#   'http://pokehunt.in/',
#   '1',
#   '0',
#   'm_hdhazwan',
#   '8/18/2016 17:57'],
#  ['12314610',
#   'Show HN: TurboRLE: Bringing Turbo Run Length Encoding Incl. SIMD to Java',
#   'https://github.com/powturbo/TurboRLE/blob/master/README.md',
#   '2',
#   '1',
#   'powturbo',
#   '8/18/2016 17:34'],
#  ['12314336',
#   'Show HN: Generated Twitch chat messages using Markov chains',
#   'https://fruitflieslikeabanana.com/',
#   '5',
#   '0',
#   'frakkingcylons',
#   '8/18/2016 17:08'],
#  ['12313564',
#   'Show HN: Live coding WebGL apps with PlayCanvas',
#   'https://www.youtube.com/watch?v=PS4oMLPyYfI',
#   '2',
#   '0',
#   'MayorOfMonkeys',
#   '8/18/2016 16:02'],
#  ['12313541',
#   'Show HN: Slog, a simple logger for Python',
#   '',
#   '1',
#   '1',
#   'verandaguy',
#   '8/18/2016 16:00'],
#  ['12313419',
#   'Show HN: Slow-deps  show which dependencies are slowest to npm install',
#   'https://www.npmjs.com/package/slow-deps',
#   '3',
#   '0',
#   'nolanl',
#   '8/18/2016 15:48'],
#  ['12313398',
#   'Show HN: Collaborative Product Strategy',
#   'http://blog.aha.io/collaborate-product-strategy/',
#   '2',
#   '0',
#   'bdehaaff',
#   '8/18/2016 15:46'],
#  ['12312529',
#   'Show HN: A simple generator for React component snapshot tests',
#   'https://github.com/fagerbua/react-snapshot-test-generator',
#   '1',
#   '0',
#   'fagerbua',
#   '8/18/2016 14:06'],
#  ['12312417',
#   'Show HN: Combo.fm for iOS  New curated music every day',
#   'http://combo.fm',
#   '11',
#   '0',
#   'SamPiggott',
#   '8/18/2016 13:47'],
#  ['12312196',
#   'Show HN: WebGL Fire Simulation',
#   'http://ghostinthecode.net/2016/08/17/fire.html',
#   '143',
#   '23',
#   'jharsman',
#   '8/18/2016 13:11'],
#  ['12311973',
#   'Show HN: Fundamental charts and financial data source',
#   'https://stockrow.com',
#   '10',
#   '0',
#   'iShrimp',
#   '8/18/2016 12:33'],
#  ['12311930',
#   'Show HN: A Web Extension to save a page or selection as eBook',
#   'https://github.com/alexadam/save-as-ebook',
#   '106',
#   '25',
#   'eg312',
#   '8/18/2016 12:24'],
#  ['12311636',
#   'Show HN: Share your tmux (readonly) session using ssh',
#   'https://gist.github.com/pvtmert/75288878f51f6755a64cf488ef0e0e35',
#   '7',
#   '0',
#   'pvtmert',
#   '8/18/2016 11:28'],
#  ['12311619',
#   'Show HN: Tradiio  Recurring Funding for Music Creators',
#   'https://tradiio.com/',
#   '2',
#   '0',
#   'wildlifechorus',
#   '8/18/2016 11:25'],
#  ['12311358',
#   'Show HN: Screenja  Efficient OS X screensots with names (? and SHIFT and 5)',
#   'https://dobrotka.sk/blog/post/screenja-efficient-osx-screenshot-taking/',
#   '3',
#   '0',
#   'thomasdd',
#   '8/18/2016 10:00'],
#  ['12311321',
#   'Show HN: Ball falls on the teapot in WebGL',
#   'http://whitestormjs.xyz/playground/?example=model&dir=demo',
#   '49',
#   '30',
#   'alex2401',
#   '8/18/2016 9:46'],
#  ['12311075',
#   'Show HN: Free Dynamic DNS',
#   'http://free53.co',
#   '4',
#   '2',
#   'noir-york',
#   '8/18/2016 8:28'],
#  ['12310712',
#   'Show HN: Make notes, mindmaps, diagrams online  for studying or brainstorming',
#   'http://breakdown-notes.com',
#   '83',
#   '28',
#   'cher14',
#   '8/18/2016 6:18'],
#  ...]

# %%
show_posts[-3:]
# Out:
# [['10177511',
#   'Show HN: MockTheClock  A tiny JavaScript library for spoofing time in browser',
#   'https://github.com/zb3/MockTheClock',
#   '18',
#   '6',
#   'zb3',
#   '9/6/2015 13:02'],
#  ['10177459',
#   'Show HN: AppyPaper  Gift wrap with app icons printed on it',
#   'http://www.appypaper.com/',
#   '6',
#   '4',
#   'submitstartup',
#   '9/6/2015 12:38'],
#  ['10177421',
#   'Show HN: Popularity scoring for arXiv publications',
#   'https://gist.github.com/nebw/5504697c118744677c2d',
#   '17',
#   '1',
#   'nebw',
#   '9/6/2015 12:16']]

# %% [markdown]
# # To verify that the list works fine, we have to take a look at the first and last two rows of each list.

# %%
print(ask_posts[0][1])
print(ask_posts[1][1])
print(ask_posts[-2][1])
print(ask_posts[-1][1])
print("\n")
print(show_posts[0][1])
print(show_posts[1][1])
print(show_posts[-2][1])
print(show_posts[-1][1])
# Out:
# Ask HN: What TLD do you use for local development?
# Ask HN: How do you pass on your work when you die?
# Ask HN: Where do you look for work if you need experience?
# Ask HN: What is/are your favorite quote(s)?
#
#
# Show HN: Finding puns computationally
# Show HN: A simple library for complicated animations
# Show HN: AppyPaper  Gift wrap with app icons printed on it
# Show HN: Popularity scoring for arXiv publications

# %% [markdown]
# # Calculating the average number of comments for Ask HN and Show HN posts.

# %%
#ask hn allways recive comments

# %%
# we find out total_ask_comment
avg_ask_hn = total_ask_comments / len(ask_posts)

# %%
total_ask_comments = 0

for posts in ask_posts:
    comments = int(posts[4])
    total_ask_comments +=comments

# %%
avg_ask_hn = total_ask_comments / len (ask_posts)

# %%
print(avg_ask_hn),"{:.2f}".format(avg_ask_hn)
# Out:
# 10.393478498741656
# (None, '10.39')

# %%
# show hn allways recives points

# %%
# we find out total_show_comment
avg_show_hn = total_ask_comments / len(ask_posts)

# %%
total_show_comments = 0

for posts in show_posts:
    comments = int(posts[4])
    total_show_comments += comments

# %%
avg_show_hn = total_show_comments / len(show_posts)

# %%
print(avg_show_hn),"{:.2f}".format(avg_show_hn)
# Out:
# 4.886099625910612
# (None, '4.89')

# %%
a = avg_ask_hn = 10.39
b = avg_show_hn = 4.89
a -= b
a
"{:.2f}".format(a)
# Out:
# '5.50'

# %% [markdown]
# # Finding the number of Ask posts and comments by hour created.

# %%
result_list = []
# we iterate trough each post in ask_post, then asign
# the timestamp to created_at and the number of comments
# to num_comments. At the end we append a list with that
# data to the result_list

for posts in ask_posts:
    dates = posts[-1]
    n_comm = int(posts[4])
    result_list.append([dates, n_comm])

counts_by_hour = {} # contains the number of ask posts created during each hour of the day
comments_by_hour = {} # contains the corresponding number of comments ask posts created at each hour received

for row in result_list:
    date_str = row[0]
    num_comments = row[1]
    dt_object = dt.datetime.strptime(date_str, '%m/%d/%Y %H:%M') # we convert the date string to a datetime object
    hour = dt_object.strftime('%H') # we ectract the hour (%H) from the datetime object
    
    # now we create a frequent table and count the hour to get
    # the number of posts for each hour and set the comments by hour
    # equal to the comment number to get the comments in each hour.
    
    if hour not in counts_by_hour:
        counts_by_hour[hour] = 1
        comments_by_hour[hour] = num_comments
    else:
        counts_by_hour[hour] += 1
        comments_by_hour[hour] += num_comments

# %%
result_list[:]
# Out:
# [['9/26/2016 2:53', 7],
#  ['9/26/2016 1:17', 3],
#  ['9/25/2016 22:57', 0],
#  ['9/25/2016 22:48', 3],
#  ['9/25/2016 21:50', 2],
#  ['9/25/2016 19:30', 1],
#  ['9/25/2016 19:22', 22],
#  ['9/25/2016 17:55', 3],
#  ['9/25/2016 15:48', 0],
#  ['9/25/2016 15:35', 13],
#  ['9/25/2016 15:28', 0],
#  ['9/25/2016 14:43', 0],
#  ['9/25/2016 14:17', 3],
#  ['9/25/2016 13:08', 2],
#  ['9/25/2016 11:27', 2],
#  ['9/25/2016 10:51', 0],
#  ['9/25/2016 10:47', 6],
#  ['9/25/2016 9:04', 97],
#  ['9/25/2016 7:09', 4],
#  ['9/25/2016 3:00', 1],
#  ['9/24/2016 23:04', 0],
#  ['9/24/2016 22:02', 7],
#  ['9/24/2016 21:18', 2],
#  ['9/24/2016 20:58', 0],
#  ['9/24/2016 19:57', 1],
#  ['9/24/2016 19:02', 0],
#  ['9/24/2016 17:55', 0],
#  ['9/24/2016 17:27', 1],
#  ['9/24/2016 16:50', 0],
#  ['9/24/2016 16:03', 5],
#  ['9/24/2016 15:29', 66],
#  ['9/24/2016 14:03', 1],
#  ['9/24/2016 10:10', 11],
#  ['9/24/2016 8:46', 7],
#  ['9/24/2016 8:39', 1],
#  ['9/24/2016 8:38', 1],
#  ['9/24/2016 8:28', 1],
#  ['9/24/2016 3:36', 3],
#  ['9/24/2016 0:21', 2],
#  ['9/23/2016 23:38', 6],
#  ['9/23/2016 23:35', 6],
#  ['9/23/2016 22:13', 4],
#  ['9/23/2016 20:58', 2],
#  ['9/23/2016 20:42', 0],
#  ['9/23/2016 20:23', 1],
#  ['9/23/2016 20:18', 477],
#  ['9/23/2016 19:33', 3],
#  ['9/23/2016 19:32', 10],
#  ['9/23/2016 18:56', 12],
#  ['9/23/2016 18:53', 4],
#  ['9/23/2016 17:45', 1],
#  ['9/23/2016 17:35', 1],
#  ['9/23/2016 17:28', 25],
#  ['9/23/2016 16:56', 2],
#  ['9/23/2016 16:14', 3],
#  ['9/23/2016 12:39', 6],
#  ['9/23/2016 9:58', 1],
#  ['9/23/2016 4:47', 2],
#  ['9/23/2016 2:28', 3],
#  ['9/23/2016 1:56', 8],
#  ['9/23/2016 1:24', 2],
#  ['9/23/2016 1:23', 1],
#  ['9/23/2016 0:58', 0],
#  ['9/23/2016 0:11', 5],
#  ['9/22/2016 21:45', 3],
#  ['9/22/2016 21:19', 5],
#  ['9/22/2016 19:58', 19],
#  ['9/22/2016 19:42', 6],
#  ['9/22/2016 19:40', 23],
#  ['9/22/2016 19:18', 2],
#  ['9/22/2016 18:16', 1],
#  ['9/22/2016 17:43', 0],
#  ['9/22/2016 17:38', 0],
#  ['9/22/2016 17:27', 0],
#  ['9/22/2016 17:27', 26],
#  ['9/22/2016 17:05', 0],
#  ['9/22/2016 16:34', 0],
#  ['9/22/2016 15:44', 1],
#  ['9/22/2016 15:18', 10],
#  ['9/22/2016 15:18', 1],
#  ['9/22/2016 14:49', 62],
#  ['9/22/2016 13:11', 0],
#  ['9/22/2016 12:58', 0],
#  ['9/22/2016 12:55', 0],
#  ['9/22/2016 12:50', 3],
#  ['9/22/2016 11:52', 266],
#  ['9/22/2016 6:25', 1],
#  ['9/22/2016 6:19', 2],
#  ['9/22/2016 5:03', 0],
#  ['9/22/2016 4:55', 0],
#  ['9/22/2016 0:47', 0],
#  ['9/21/2016 23:37', 0],
#  ['9/21/2016 23:03', 22],
#  ['9/21/2016 21:14', 1],
#  ['9/21/2016 20:53', 6],
#  ['9/21/2016 20:35', 1],
#  ['9/21/2016 20:33', 1],
#  ['9/21/2016 19:30', 1],
#  ['9/21/2016 19:18', 46],
#  ['9/21/2016 18:39', 0],
#  ['9/21/2016 18:11', 2],
#  ['9/21/2016 17:56', 5],
#  ['9/21/2016 17:46', 23],
#  ['9/21/2016 17:36', 0],
#  ['9/21/2016 17:24', 0],
#  ['9/21/2016 14:50', 62],
#  ['9/21/2016 14:35', 2],
#  ['9/21/2016 13:49', 2],
#  ['9/21/2016 13:42', 61],
#  ['9/21/2016 12:24', 1],
#  ['9/21/2016 12:17', 4],
#  ['9/21/2016 12:00', 2],
#  ['9/21/2016 11:28', 0],
#  ['9/21/2016 10:41', 0],
#  ['9/21/2016 9:49', 1],
#  ['9/21/2016 8:26', 1],
#  ['9/21/2016 8:16', 2],
#  ['9/21/2016 7:12', 10],
#  ['9/21/2016 5:27', 0],
#  ['9/21/2016 4:58', 2],
#  ['9/21/2016 4:02', 1],
#  ['9/21/2016 2:45', 94],
#  ['9/21/2016 2:36', 30],
#  ['9/21/2016 0:38', 1],
#  ['9/21/2016 0:31', 1],
#  ['9/20/2016 23:20', 3],
#  ['9/20/2016 22:48', 20],
#  ['9/20/2016 21:41', 14],
#  ['9/20/2016 21:07', 12],
#  ['9/20/2016 21:00', 30],
#  ['9/20/2016 20:37', 2],
#  ['9/20/2016 19:39', 7],
#  ['9/20/2016 19:20', 1],
#  ['9/20/2016 18:45', 7],
#  ['9/20/2016 18:37', 1],
#  ['9/20/2016 18:30', 0],
#  ['9/20/2016 18:20', 3],
#  ['9/20/2016 17:41', 11],
#  ['9/20/2016 17:32', 3],
#  ['9/20/2016 16:35', 1],
#  ['9/20/2016 16:17', 20],
#  ['9/20/2016 16:08', 8],
#  ['9/20/2016 15:30', 3],
#  ['9/20/2016 14:54', 0],
#  ['9/20/2016 14:42', 4],
#  ['9/20/2016 14:22', 2],
#  ['9/20/2016 14:21', 0],
#  ['9/20/2016 12:11', 1],
#  ['9/20/2016 12:09', 2],
#  ['9/20/2016 11:29', 4],
#  ['9/20/2016 11:23', 7],
#  ['9/20/2016 11:02', 2],
#  ['9/20/2016 8:32', 0],
#  ['9/20/2016 8:03', 2],
#  ['9/20/2016 7:20', 0],
#  ['9/20/2016 6:43', 3],
#  ['9/20/2016 6:04', 4],
#  ['9/20/2016 5:13', 3],
#  ['9/20/2016 5:07', 0],
#  ['9/19/2016 23:55', 10],
#  ['9/19/2016 23:31', 59],
#  ['9/19/2016 22:50', 5],
#  ['9/19/2016 21:48', 1],
#  ['9/19/2016 21:42', 3],
#  ['9/19/2016 21:19', 1],
#  ['9/19/2016 19:57', 0],
#  ['9/19/2016 19:40', 1],
#  ['9/19/2016 19:21', 28],
#  ['9/19/2016 19:04', 2],
#  ['9/19/2016 18:55', 0],
#  ['9/19/2016 18:51', 14],
#  ['9/19/2016 18:28', 2],
#  ['9/19/2016 18:23', 0],
#  ['9/19/2016 18:16', 0],
#  ['9/19/2016 16:40', 0],
#  ['9/19/2016 16:04', 2],
#  ['9/19/2016 15:57', 1],
#  ['9/19/2016 15:54', 0],
#  ['9/19/2016 15:51', 7],
#  ['9/19/2016 15:31', 2],
#  ['9/19/2016 15:15', 0],
#  ['9/19/2016 14:43', 6],
#  ['9/19/2016 14:36', 10],
#  ['9/19/2016 14:21', 1],
#  ['9/19/2016 13:40', 11],
#  ['9/19/2016 12:54', 2],
#  ['9/19/2016 9:45', 7],
#  ['9/19/2016 9:42', 1],
#  ['9/19/2016 8:31', 2],
#  ['9/19/2016 7:44', 22],
#  ['9/19/2016 6:06', 73],
#  ['9/19/2016 2:07', 14],
#  ['9/19/2016 0:16', 61],
#  ['9/18/2016 23:05', 1],
#  ['9/18/2016 18:35', 0],
#  ['9/18/2016 18:33', 9],
#  ['9/18/2016 17:30', 0],
#  ['9/18/2016 17:28', 2],
#  ['9/18/2016 16:24', 0],
#  ['9/18/2016 16:05', 1],
#  ['9/18/2016 15:51', 1],
#  ['9/18/2016 15:24', 4],
#  ['9/18/2016 14:48', 0],
#  ['9/18/2016 14:20', 1],
#  ['9/18/2016 8:58', 0],
#  ['9/18/2016 5:41', 1],
#  ['9/18/2016 3:40', 35],
#  ['9/18/2016 3:38', 2],
#  ['9/18/2016 2:20', 0],
#  ['9/17/2016 23:48', 6],
#  ['9/17/2016 23:40', 4],
#  ['9/17/2016 22:23', 0],
#  ['9/17/2016 21:18', 2],
#  ['9/17/2016 19:01', 5],
#  ['9/17/2016 18:47', 10],
#  ['9/17/2016 18:34', 23],
#  ['9/17/2016 18:16', 2],
#  ['9/17/2016 17:43', 4],
#  ['9/17/2016 16:36', 5],
#  ['9/17/2016 16:07', 0],
#  ['9/17/2016 15:58', 1],
#  ['9/17/2016 15:58', 4],
#  ['9/17/2016 15:44', 35],
#  ['9/17/2016 15:02', 0],
#  ['9/17/2016 13:03', 25],
#  ['9/17/2016 10:35', 1],
#  ['9/17/2016 10:17', 10],
#  ['9/17/2016 9:57', 1],
#  ['9/17/2016 8:41', 14],
#  ['9/17/2016 7:34', 1],
#  ['9/17/2016 6:35', 6],
#  ['9/17/2016 4:07', 19],
#  ['9/17/2016 3:48', 1],
#  ['9/17/2016 2:00', 0],
#  ['9/17/2016 1:06', 9],
#  ['9/16/2016 22:56', 33],
#  ['9/16/2016 22:56', 39],
#  ['9/16/2016 22:09', 2],
#  ['9/16/2016 21:39', 3],
#  ['9/16/2016 21:19', 2],
#  ['9/16/2016 21:02', 0],
#  ['9/16/2016 20:51', 14],
#  ['9/16/2016 20:51', 40],
#  ['9/16/2016 20:28', 1],
#  ['9/16/2016 19:46', 0],
#  ['9/16/2016 19:28', 185],
#  ['9/16/2016 19:00', 25],
#  ['9/16/2016 18:14', 2],
#  ['9/16/2016 18:11', 0],
#  ['9/16/2016 18:08', 1],
#  ['9/16/2016 18:04', 0],
#  ['9/16/2016 17:56', 5],
#  ['9/16/2016 16:38', 1],
#  ['9/16/2016 15:59', 0],
#  ['9/16/2016 15:47', 0],
#  ['9/16/2016 14:39', 5],
#  ['9/16/2016 13:43', 6],
#  ['9/16/2016 13:16', 2],
#  ['9/16/2016 12:06', 0],
#  ['9/16/2016 11:47', 1],
#  ['9/16/2016 11:46', 5],
#  ['9/16/2016 10:49', 36],
#  ['9/16/2016 9:31', 5],
#  ['9/16/2016 8:32', 6],
#  ['9/16/2016 8:29', 0],
#  ['9/16/2016 8:26', 2],
#  ['9/16/2016 6:49', 1],
#  ['9/16/2016 6:06', 2],
#  ['9/16/2016 5:55', 2],
#  ['9/16/2016 4:56', 2],
#  ['9/16/2016 3:54', 2],
#  ['9/15/2016 22:42', 9],
#  ['9/15/2016 22:34', 0],
#  ['9/15/2016 22:09', 1],
#  ['9/15/2016 21:09', 1],
#  ['9/15/2016 21:07', 4],
#  ['9/15/2016 21:01', 0],
#  ['9/15/2016 20:54', 1],
#  ['9/15/2016 19:58', 0],
#  ['9/15/2016 19:50', 9],
#  ['9/15/2016 19:22', 0],
#  ['9/15/2016 18:30', 1],
#  ['9/15/2016 18:26', 6],
#  ['9/15/2016 17:57', 1],
#  ['9/15/2016 17:00', 0],
#  ['9/15/2016 16:36', 8],
#  ['9/15/2016 16:30', 11],
#  ['9/15/2016 16:28', 2],
#  ['9/15/2016 16:27', 9],
#  ['9/15/2016 16:03', 3],
#  ['9/15/2016 15:45', 0],
#  ['9/15/2016 15:27', 1],
#  ['9/15/2016 15:04', 2],
#  ['9/15/2016 14:52', 1],
#  ['9/15/2016 14:17', 1],
#  ['9/15/2016 14:15', 0],
#  ['9/15/2016 13:51', 7],
#  ['9/15/2016 13:50', 1],
#  ['9/15/2016 13:46', 1],
#  ['9/15/2016 13:21', 0],
#  ['9/15/2016 12:45', 1],
#  ['9/15/2016 12:00', 55],
#  ['9/15/2016 9:17', 2],
#  ['9/15/2016 8:40', 2],
#  ['9/15/2016 7:49', 0],
#  ['9/15/2016 7:30', 0],
#  ['9/15/2016 7:14', 1],
#  ['9/15/2016 7:11', 3],
#  ['9/15/2016 6:07', 3],
#  ['9/15/2016 6:06', 0],
#  ['9/15/2016 3:23', 1],
#  ['9/15/2016 2:04', 0],
#  ['9/15/2016 1:34', 0],
#  ['9/15/2016 1:11', 2],
#  ['9/15/2016 0:12', 1],
#  ['9/14/2016 23:28', 4],
#  ['9/14/2016 23:26', 0],
#  ['9/14/2016 22:39', 2],
#  ['9/14/2016 22:32', 0],
#  ['9/14/2016 20:54', 1],
#  ['9/14/2016 20:46', 1],
#  ['9/14/2016 20:19', 2],
#  ['9/14/2016 20:19', 4],
#  ['9/14/2016 18:32', 0],
#  ['9/14/2016 18:08', 0],
#  ['9/14/2016 18:02', 27],
#  ['9/14/2016 17:55', 0],
#  ['9/14/2016 17:52', 0],
#  ['9/14/2016 17:45', 1],
#  ['9/14/2016 17:29', 0],
#  ['9/14/2016 17:11', 0],
#  ['9/14/2016 17:06', 0],
#  ['9/14/2016 16:42', 1],
#  ['9/14/2016 15:27', 34],
#  ['9/14/2016 15:23', 0],
#  ['9/14/2016 15:10', 4],
#  ['9/14/2016 15:09', 0],
#  ['9/14/2016 14:55', 0],
#  ['9/14/2016 14:32', 6],
#  ['9/14/2016 14:31', 5],
#  ['9/14/2016 14:22', 1],
#  ['9/14/2016 14:21', 1],
#  ['9/14/2016 13:20', 138],
#  ['9/14/2016 13:17', 7],
#  ['9/14/2016 10:57', 1],
#  ['9/14/2016 10:13', 1],
#  ['9/14/2016 9:05', 75],
#  ['9/14/2016 7:02', 0],
#  ['9/14/2016 5:54', 1],
#  ['9/14/2016 1:50', 2],
#  ['9/14/2016 0:09', 2],
#  ['9/13/2016 22:07', 14],
#  ['9/13/2016 21:43', 1],
#  ['9/13/2016 21:27', 3],
#  ['9/13/2016 21:15', 3],
#  ['9/13/2016 21:09', 1],
#  ['9/13/2016 20:48', 17],
#  ['9/13/2016 19:26', 0],
#  ['9/13/2016 18:21', 7],
#  ['9/13/2016 17:51', 5],
#  ['9/13/2016 17:16', 2],
#  ['9/13/2016 16:36', 26],
#  ['9/13/2016 16:22', 0],
#  ['9/13/2016 15:25', 1],
#  ['9/13/2016 14:59', 4],
#  ['9/13/2016 13:57', 31],
#  ['9/13/2016 13:44', 0],
#  ['9/13/2016 13:07', 1],
#  ['9/13/2016 11:55', 4],
#  ['9/13/2016 11:49', 2],
#  ['9/13/2016 11:47', 8],
#  ['9/13/2016 11:19', 35],
#  ['9/13/2016 11:04', 0],
#  ['9/13/2016 10:48', 3],
#  ['9/13/2016 10:16', 3],
#  ['9/13/2016 9:14', 1],
#  ['9/13/2016 8:10', 1],
#  ['9/13/2016 8:02', 1],
#  ['9/13/2016 8:01', 0],
#  ['9/13/2016 6:25', 2],
#  ['9/13/2016 4:42', 5],
#  ['9/13/2016 3:50', 1],
#  ['9/13/2016 3:46', 2],
#  ['9/13/2016 3:28', 0],
#  ['9/13/2016 2:52', 2],
#  ['9/13/2016 2:51', 5],
#  ['9/13/2016 2:15', 11],
#  ['9/13/2016 1:58', 1],
#  ['9/13/2016 1:09', 3],
#  ['9/13/2016 0:39', 18],
#  ['9/13/2016 0:36', 2],
#  ['9/12/2016 23:57', 1],
#  ['9/12/2016 21:26', 43],
#  ['9/12/2016 20:29', 0],
#  ['9/12/2016 20:28', 4],
#  ['9/12/2016 19:25', 3],
#  ['9/12/2016 19:05', 1],
#  ['9/12/2016 18:29', 0],
#  ['9/12/2016 18:19', 3],
#  ['9/12/2016 18:07', 22],
#  ['9/12/2016 17:59', 0],
#  ['9/12/2016 17:22', 3],
#  ['9/12/2016 17:16', 0],
#  ['9/12/2016 16:52', 7],
#  ['9/12/2016 16:51', 1],
#  ['9/12/2016 15:28', 0],
#  ['9/12/2016 14:52', 3],
#  ['9/12/2016 13:23', 1],
#  ['9/12/2016 13:19', 0],
#  ['9/12/2016 13:18', 0],
#  ['9/12/2016 12:58', 1],
#  ['9/12/2016 12:50', 1],
#  ['9/12/2016 12:39', 0],
#  ['9/12/2016 12:04', 3],
#  ['9/12/2016 10:50', 9],
#  ['9/12/2016 8:33', 45],
#  ['9/12/2016 7:47', 5],
#  ['9/12/2016 7:39', 61],
#  ['9/12/2016 6:26', 3],
#  ['9/12/2016 5:57', 7],
#  ['9/12/2016 4:38', 21],
#  ['9/12/2016 4:29', 660],
#  ['9/12/2016 3:33', 3],
#  ['9/12/2016 2:39', 106],
#  ['9/11/2016 22:09', 2],
#  ['9/11/2016 19:31', 75],
#  ['9/11/2016 18:47', 6],
#  ['9/11/2016 18:09', 1],
#  ['9/11/2016 17:54', 2],
#  ['9/11/2016 15:17', 0],
#  ['9/11/2016 15:03', 42],
#  ['9/11/2016 12:26', 0],
#  ['9/11/2016 5:47', 2],
#  ['9/11/2016 5:43', 2],
#  ['9/11/2016 5:09', 1],
#  ['9/11/2016 4:25', 6],
#  ['9/11/2016 2:39', 0],
#  ['9/11/2016 1:28', 1],
#  ['9/11/2016 0:50', 3],
#  ['9/11/2016 0:20', 6],
#  ['9/10/2016 23:39', 9],
#  ['9/10/2016 23:08', 18],
#  ['9/10/2016 22:30', 0],
#  ['9/10/2016 22:19', 16],
#  ['9/10/2016 21:18', 25],
#  ['9/10/2016 21:01', 4],
#  ['9/10/2016 20:57', 2],
#  ['9/10/2016 18:05', 1],
#  ['9/10/2016 17:48', 6],
#  ['9/10/2016 16:01', 5],
#  ['9/10/2016 14:56', 6],
#  ['9/10/2016 14:31', 30],
#  ['9/10/2016 13:38', 3],
#  ['9/10/2016 12:24', 1],
#  ['9/10/2016 12:11', 0],
#  ['9/10/2016 10:13', 2],
#  ['9/10/2016 9:07', 3],
#  ['9/10/2016 8:39', 0],
#  ['9/10/2016 8:07', 5],
#  ['9/10/2016 7:49', 7],
#  ['9/10/2016 3:44', 0],
#  ['9/10/2016 2:33', 4],
#  ['9/10/2016 1:58', 4],
#  ['9/10/2016 0:17', 4],
#  ['9/9/2016 20:25', 0],
#  ['9/9/2016 20:10', 0],
#  ['9/9/2016 20:09', 5],
#  ['9/9/2016 19:42', 0],
#  ['9/9/2016 18:51', 0],
#  ['9/9/2016 18:40', 10],
#  ['9/9/2016 16:59', 1],
#  ['9/9/2016 16:41', 2],
#  ['9/9/2016 15:16', 0],
#  ['9/9/2016 14:20', 0],
#  ['9/9/2016 13:25', 0],
#  ['9/9/2016 12:46', 1],
#  ['9/9/2016 12:36', 15],
#  ['9/9/2016 12:35', 1],
#  ['9/9/2016 11:08', 1],
#  ['9/9/2016 10:54', 33],
#  ['9/9/2016 10:10', 0],
#  ['9/9/2016 10:09', 2],
#  ['9/9/2016 10:03', 1],
#  ['9/9/2016 6:59', 0],
#  ['9/9/2016 3:32', 18],
#  ['9/9/2016 0:14', 10],
#  ['9/8/2016 23:52', 3],
#  ['9/8/2016 23:32', 3],
#  ['9/8/2016 23:23', 1],
#  ['9/8/2016 21:27', 0],
#  ['9/8/2016 20:16', 0],
#  ['9/8/2016 19:35', 39],
#  ['9/8/2016 18:20', 2],
#  ['9/8/2016 17:57', 5],
#  ['9/8/2016 17:53', 18],
#  ['9/8/2016 17:47', 0],
#  ['9/8/2016 17:45', 4],
#  ['9/8/2016 16:53', 2],
#  ['9/8/2016 15:42', 1],
#  ['9/8/2016 15:18', 1],
#  ['9/8/2016 15:09', 3],
#  ['9/8/2016 14:39', 2],
#  ['9/8/2016 13:06', 0],
#  ['9/8/2016 13:05', 1],
#  ['9/8/2016 12:58', 35],
#  ['9/8/2016 11:23', 2],
#  ['9/8/2016 10:45', 3],
#  ['9/8/2016 10:28', 10],
#  ['9/8/2016 10:18', 5],
#  ['9/8/2016 6:34', 0],
#  ['9/8/2016 3:32', 3],
#  ['9/8/2016 0:50', 0],
#  ['9/8/2016 0:37', 3],
#  ['9/8/2016 0:10', 15],
#  ['9/7/2016 23:57', 3],
#  ['9/7/2016 22:53', 1],
#  ['9/7/2016 22:48', 3],
#  ['9/7/2016 22:14', 4],
#  ['9/7/2016 21:27', 0],
#  ['9/7/2016 21:16', 7],
#  ['9/7/2016 20:28', 7],
#  ['9/7/2016 20:27', 3],
#  ['9/7/2016 20:15', 5],
#  ['9/7/2016 20:03', 0],
#  ['9/7/2016 18:44', 0],
#  ['9/7/2016 18:33', 2],
#  ['9/7/2016 16:11', 5],
#  ['9/7/2016 15:57', 0],
#  ['9/7/2016 15:49', 3],
#  ['9/7/2016 15:26', 14],
#  ['9/7/2016 14:12', 0],
#  ['9/7/2016 13:17', 0],
#  ['9/7/2016 12:20', 0],
#  ['9/7/2016 11:37', 4],
#  ['9/7/2016 11:32', 1],
#  ['9/7/2016 11:14', 3],
#  ['9/7/2016 11:02', 6],
#  ['9/7/2016 10:43', 4],
#  ['9/7/2016 9:40', 1],
#  ['9/7/2016 8:31', 5],
#  ['9/7/2016 8:31', 3],
#  ['9/7/2016 2:21', 6],
#  ['9/7/2016 2:12', 1],
#  ['9/7/2016 2:11', 11],
#  ['9/7/2016 1:47', 35],
#  ['9/7/2016 1:34', 4],
#  ['9/7/2016 1:18', 3],
#  ['9/7/2016 1:02', 5],
#  ['9/6/2016 23:45', 0],
#  ['9/6/2016 22:59', 5],
#  ['9/6/2016 22:59', 3],
#  ['9/6/2016 22:18', 65],
#  ['9/6/2016 21:02', 3],
#  ['9/6/2016 20:15', 1],
#  ['9/6/2016 17:23', 0],
#  ['9/6/2016 17:22', 7],
#  ['9/6/2016 17:11', 10],
#  ['9/6/2016 16:45', 9],
#  ['9/6/2016 15:52', 0],
#  ['9/6/2016 15:26', 1],
#  ['9/6/2016 15:02', 0],
#  ['9/6/2016 14:16', 0],
#  ['9/6/2016 13:36', 43],
#  ['9/6/2016 13:08', 0],
#  ['9/6/2016 12:57', 2],
#  ['9/6/2016 12:53', 7],
#  ['9/6/2016 12:03', 6],
#  ['9/6/2016 10:11', 0],
#  ['9/6/2016 10:10', 0],
#  ['9/6/2016 9:58', 0],
#  ['9/6/2016 9:51', 9],
#  ['9/6/2016 9:14', 0],
#  ['9/6/2016 6:08', 2],
#  ['9/5/2016 22:31', 0],
#  ['9/5/2016 20:01', 1],
#  ['9/5/2016 19:48', 0],
#  ['9/5/2016 19:13', 1],
#  ['9/5/2016 19:08', 0],
#  ['9/5/2016 18:36', 3],
#  ['9/5/2016 17:58', 0],
#  ['9/5/2016 17:15', 0],
#  ['9/5/2016 15:10', 2],
#  ['9/5/2016 13:56', 5],
#  ['9/5/2016 13:45', 4],
#  ['9/5/2016 13:19', 1],
#  ['9/5/2016 12:34', 1],
#  ['9/5/2016 12:13', 4],
#  ['9/5/2016 11:13', 5],
#  ['9/5/2016 11:06', 4],
#  ['9/5/2016 10:08', 2],
#  ['9/5/2016 9:32', 2],
#  ['9/5/2016 9:06', 3],
#  ['9/5/2016 8:35', 4],
#  ['9/5/2016 7:27', 39],
#  ['9/5/2016 7:12', 2],
#  ['9/5/2016 6:58', 40],
#  ['9/5/2016 6:19', 1],
#  ['9/5/2016 5:36', 85],
#  ['9/5/2016 3:04', 39],
#  ['9/5/2016 2:45', 1],
#  ['9/5/2016 2:41', 0],
#  ['9/5/2016 1:42', 2],
#  ['9/5/2016 1:40', 2],
#  ['9/4/2016 21:48', 0],
#  ['9/4/2016 21:34', 6],
#  ['9/4/2016 21:26', 39],
#  ['9/4/2016 21:17', 47],
#  ['9/4/2016 20:41', 0],
#  ['9/4/2016 19:57', 2],
#  ['9/4/2016 19:29', 5],
#  ['9/4/2016 18:23', 1],
#  ['9/4/2016 17:53', 0],
#  ['9/4/2016 17:48', 6],
#  ['9/4/2016 17:33', 5],
#  ['9/4/2016 16:55', 0],
#  ['9/4/2016 16:46', 1],
#  ['9/4/2016 16:18', 0],
#  ['9/4/2016 15:09', 3],
#  ['9/4/2016 14:17', 3],
#  ['9/4/2016 14:15', 0],
#  ['9/4/2016 13:54', 1],
#  ['9/4/2016 13:50', 1],
#  ['9/4/2016 13:41', 84],
#  ['9/4/2016 13:36', 3],
#  ['9/4/2016 13:34', 34],
#  ['9/4/2016 12:59', 3],
#  ['9/4/2016 12:26', 3],
#  ['9/4/2016 11:34', 1],
#  ['9/4/2016 9:54', 1],
#  ['9/4/2016 8:31', 6],
#  ['9/4/2016 7:43', 130],
#  ['9/4/2016 5:41', 3],
#  ['9/4/2016 5:09', 6],
#  ['9/4/2016 3:02', 9],
#  ['9/4/2016 2:57', 1],
#  ['9/4/2016 0:00', 110],
#  ['9/3/2016 23:16', 3],
#  ['9/3/2016 20:25', 1],
#  ['9/3/2016 19:59', 6],
#  ['9/3/2016 19:01', 4],
#  ['9/3/2016 18:45', 1],
#  ['9/3/2016 17:25', 6],
#  ['9/3/2016 17:05', 5],
#  ['9/3/2016 16:14', 3],
#  ['9/3/2016 16:10', 75],
#  ['9/3/2016 15:32', 3],
#  ['9/3/2016 14:31', 5],
#  ['9/3/2016 12:02', 4],
#  ['9/3/2016 10:58', 34],
#  ['9/3/2016 10:06', 3],
#  ['9/3/2016 9:02', 0],
#  ['9/3/2016 1:50', 1],
#  ['9/2/2016 23:53', 6],
#  ['9/2/2016 22:27', 0],
#  ['9/2/2016 22:03', 38],
#  ['9/2/2016 21:59', 0],
#  ['9/2/2016 21:30', 0],
#  ['9/2/2016 19:56', 6],
#  ['9/2/2016 19:31', 105],
#  ['9/2/2016 18:52', 1],
#  ['9/2/2016 18:19', 4],
#  ['9/2/2016 18:10', 49],
#  ['9/2/2016 17:57', 3],
#  ['9/2/2016 16:37', 4],
#  ['9/2/2016 15:04', 0],
#  ['9/2/2016 14:24', 2],
#  ['9/2/2016 14:13', 1],
#  ['9/2/2016 14:13', 0],
#  ['9/2/2016 13:58', 1],
#  ['9/2/2016 13:35', 0],
#  ['9/2/2016 13:29', 0],
#  ['9/2/2016 12:55', 223],
#  ['9/2/2016 12:41', 0],
#  ['9/2/2016 10:48', 2],
#  ['9/2/2016 6:32', 0],
#  ['9/2/2016 5:18', 1],
#  ['9/2/2016 4:39', 13],
#  ['9/2/2016 4:21', 1],
#  ['9/2/2016 2:08', 8],
#  ['9/2/2016 2:05', 8],
#  ['9/2/2016 2:03', 0],
#  ['9/1/2016 21:34', 4],
#  ['9/1/2016 20:23', 32],
#  ['9/1/2016 16:27', 3],
#  ['9/1/2016 15:59', 0],
#  ['9/1/2016 15:00', 37],
#  ['9/1/2016 15:00', 166],
#  ['9/1/2016 15:00', 85],
#  ['9/1/2016 15:00', 910],
#  ['9/1/2016 14:37', 8],
#  ['9/1/2016 14:21', 0],
#  ['9/1/2016 14:17', 0],
#  ['9/1/2016 14:00', 2],
#  ['9/1/2016 13:20', 0],
#  ['9/1/2016 12:25', 4],
#  ['9/1/2016 12:23', 1],
#  ['9/1/2016 12:22', 1],
#  ['9/1/2016 12:09', 2],
#  ['9/1/2016 11:27', 0],
#  ['9/1/2016 10:48', 2],
#  ['9/1/2016 9:58', 3],
#  ['9/1/2016 9:44', 2],
#  ['9/1/2016 8:36', 4],
#  ['9/1/2016 8:16', 1],
#  ['9/1/2016 7:39', 0],
#  ['9/1/2016 4:48', 2],
#  ['9/1/2016 4:31', 2],
#  ['9/1/2016 3:09', 10],
#  ['9/1/2016 2:40', 0],
#  ['9/1/2016 1:13', 6],
#  ['9/1/2016 0:14', 1],
#  ['8/31/2016 23:14', 8],
#  ['8/31/2016 22:51', 2],
#  ['8/31/2016 20:13', 3],
#  ['8/31/2016 19:56', 3],
#  ['8/31/2016 19:45', 6],
#  ['8/31/2016 18:39', 0],
#  ['8/31/2016 18:34', 0],
#  ['8/31/2016 18:26', 0],
#  ['8/31/2016 18:21', 9],
#  ['8/31/2016 18:20', 0],
#  ['8/31/2016 18:09', 0],
#  ['8/31/2016 16:54', 8],
#  ['8/31/2016 16:29', 11],
#  ['8/31/2016 16:21', 3],
#  ['8/31/2016 16:01', 17],
#  ['8/31/2016 15:42', 0],
#  ['8/31/2016 13:55', 172],
#  ['8/31/2016 11:41', 6],
#  ['8/31/2016 11:25', 4],
#  ['8/31/2016 10:39', 3],
#  ['8/31/2016 9:47', 1],
#  ['8/31/2016 9:20', 0],
#  ['8/31/2016 8:46', 93],
#  ['8/31/2016 7:31', 0],
#  ['8/31/2016 7:22', 5],
#  ['8/31/2016 7:21', 4],
#  ['8/31/2016 3:48', 2],
#  ['8/31/2016 2:20', 27],
#  ['8/31/2016 1:23', 5],
#  ['8/31/2016 1:00', 11],
#  ['8/31/2016 0:30', 0],
#  ['8/30/2016 23:50', 0],
#  ['8/30/2016 21:56', 10],
#  ['8/30/2016 21:11', 6],
#  ['8/30/2016 20:57', 6],
#  ['8/30/2016 20:46', 9],
#  ['8/30/2016 20:45', 82],
#  ['8/30/2016 20:32', 4],
#  ['8/30/2016 20:31', 0],
#  ['8/30/2016 20:09', 5],
#  ['8/30/2016 19:36', 0],
#  ['8/30/2016 19:34', 3],
#  ['8/30/2016 19:28', 10],
#  ['8/30/2016 19:17', 4],
#  ['8/30/2016 18:38', 0],
#  ['8/30/2016 18:08', 0],
#  ['8/30/2016 18:01', 0],
#  ['8/30/2016 16:40', 6],
#  ['8/30/2016 16:09', 12],
#  ['8/30/2016 15:33', 2],
#  ['8/30/2016 15:27', 9],
#  ['8/30/2016 15:18', 1],
#  ['8/30/2016 14:54', 0],
#  ['8/30/2016 14:48', 22],
#  ['8/30/2016 13:53', 2],
#  ['8/30/2016 13:00', 30],
#  ['8/30/2016 12:56', 0],
#  ['8/30/2016 12:56', 2],
#  ['8/30/2016 12:43', 6],
#  ['8/30/2016 12:29', 2],
#  ['8/30/2016 12:25', 1],
#  ['8/30/2016 11:58', 1],
#  ['8/30/2016 11:20', 4],
#  ['8/30/2016 11:08', 15],
#  ['8/30/2016 10:26', 1],
#  ['8/30/2016 8:28', 1],
#  ['8/30/2016 7:53', 0],
#  ['8/30/2016 5:57', 11],
#  ['8/30/2016 5:18', 8],
#  ['8/30/2016 4:43', 0],
#  ['8/30/2016 4:25', 1],
#  ['8/30/2016 2:44', 1],
#  ['8/30/2016 2:42', 17],
#  ['8/30/2016 2:14', 1],
#  ['8/30/2016 0:49', 3],
#  ['8/29/2016 22:13', 5],
#  ['8/29/2016 22:12', 3],
#  ['8/29/2016 21:50', 1],
#  ['8/29/2016 21:31', 1],
#  ['8/29/2016 21:19', 2],
#  ['8/29/2016 20:47', 0],
#  ['8/29/2016 19:35', 0],
#  ['8/29/2016 19:33', 2],
#  ['8/29/2016 19:27', 0],
#  ['8/29/2016 18:31', 0],
#  ['8/29/2016 18:26', 4],
#  ['8/29/2016 18:07', 3],
#  ['8/29/2016 17:16', 1],
#  ['8/29/2016 16:41', 5],
#  ['8/29/2016 16:08', 0],
#  ['8/29/2016 15:57', 51],
#  ['8/29/2016 15:22', 0],
#  ['8/29/2016 15:07', 2],
#  ['8/29/2016 14:31', 52],
#  ['8/29/2016 13:15', 13],
#  ['8/29/2016 13:13', 6],
#  ['8/29/2016 13:03', 8],
#  ['8/29/2016 13:01', 0],
#  ['8/29/2016 12:20', 2],
#  ['8/29/2016 11:48', 0],
#  ['8/29/2016 10:25', 0],
#  ['8/29/2016 10:20', 4],
#  ['8/29/2016 9:18', 9],
#  ['8/29/2016 8:36', 5],
#  ['8/29/2016 8:23', 0],
#  ['8/29/2016 7:56', 4],
#  ['8/29/2016 0:07', 1],
#  ['8/28/2016 23:46', 57],
#  ['8/28/2016 23:40', 0],
#  ['8/28/2016 21:24', 2],
#  ['8/28/2016 20:38', 4],
#  ['8/28/2016 20:16', 2],
#  ['8/28/2016 20:05', 0],
#  ['8/28/2016 18:58', 3],
#  ['8/28/2016 18:24', 6],
#  ['8/28/2016 18:06', 2],
#  ['8/28/2016 17:42', 1],
#  ['8/28/2016 16:58', 5],
#  ['8/28/2016 15:40', 2],
#  ['8/28/2016 14:41', 3],
#  ['8/28/2016 14:34', 7],
#  ['8/28/2016 14:16', 106],
#  ['8/28/2016 12:33', 221],
#  ['8/28/2016 11:07', 2],
#  ['8/28/2016 10:13', 3],
#  ['8/28/2016 7:11', 0],
#  ['8/28/2016 6:18', 1],
#  ['8/28/2016 5:24', 1],
#  ['8/28/2016 5:19', 5],
#  ['8/28/2016 4:22', 8],
#  ['8/28/2016 2:00', 4],
#  ['8/28/2016 1:00', 9],
#  ['8/28/2016 0:03', 1],
#  ['8/27/2016 23:52', 10],
#  ['8/27/2016 22:29', 88],
#  ['8/27/2016 21:36', 6],
#  ['8/27/2016 20:09', 3],
#  ['8/27/2016 19:42', 3],
#  ['8/27/2016 19:38', 5],
#  ['8/27/2016 19:31', 93],
#  ['8/27/2016 19:03', 2],
#  ['8/27/2016 18:05', 11],
#  ['8/27/2016 17:07', 1],
#  ['8/27/2016 15:21', 3],
#  ['8/27/2016 13:20', 1],
#  ['8/27/2016 13:15', 5],
#  ['8/27/2016 12:09', 5],
#  ['8/27/2016 11:44', 4],
#  ['8/27/2016 11:33', 21],
#  ['8/27/2016 10:25', 3],
#  ['8/27/2016 8:42', 0],
#  ['8/27/2016 6:19', 7],
#  ['8/27/2016 5:56', 2],
#  ['8/27/2016 2:53', 0],
#  ['8/27/2016 1:47', 2],
#  ['8/27/2016 0:57', 2],
#  ['8/26/2016 22:56', 1],
#  ['8/26/2016 22:38', 0],
#  ['8/26/2016 20:54', 3],
#  ['8/26/2016 20:22', 5],
#  ['8/26/2016 19:25', 15],
#  ['8/26/2016 16:10', 2],
#  ['8/26/2016 15:39', 1],
#  ['8/26/2016 15:36', 0],
#  ['8/26/2016 15:23', 15],
#  ['8/26/2016 15:08', 0],
#  ['8/26/2016 15:07', 0],
#  ['8/26/2016 14:28', 1],
#  ['8/26/2016 14:12', 3],
#  ['8/26/2016 10:01', 1],
#  ['8/26/2016 9:44', 2],
#  ['8/26/2016 8:39', 24],
#  ['8/26/2016 6:57', 1],
#  ['8/26/2016 6:35', 0],
#  ['8/26/2016 3:48', 0],
#  ['8/26/2016 2:19', 6],
#  ['8/26/2016 1:54', 10],
#  ['8/26/2016 1:39', 7],
#  ['8/26/2016 0:49', 1],
#  ['8/25/2016 21:49', 5],
#  ['8/25/2016 21:16', 0],
#  ['8/25/2016 21:11', 8],
#  ['8/25/2016 20:04', 0],
#  ['8/25/2016 18:53', 0],
#  ['8/25/2016 17:43', 12],
#  ['8/25/2016 17:37', 5],
#  ['8/25/2016 16:00', 3],
#  ['8/25/2016 15:31', 10],
#  ['8/25/2016 15:18', 1],
#  ['8/25/2016 15:07', 59],
#  ['8/25/2016 14:51', 1],
#  ['8/25/2016 14:36', 0],
#  ['8/25/2016 13:58', 0],
#  ['8/25/2016 12:47', 2],
#  ['8/25/2016 12:22', 8],
#  ['8/25/2016 11:20', 6],
#  ['8/25/2016 10:49', 2],
#  ['8/25/2016 10:03', 2],
#  ['8/25/2016 9:59', 1],
#  ['8/25/2016 7:33', 5],
#  ['8/25/2016 7:12', 2],
#  ['8/25/2016 6:59', 7],
#  ['8/25/2016 5:35', 7],
#  ['8/25/2016 4:48', 0],
#  ['8/25/2016 3:35', 2],
#  ['8/25/2016 1:54', 2],
#  ['8/25/2016 1:17', 42],
#  ['8/24/2016 23:54', 1],
#  ['8/24/2016 22:41', 10],
#  ['8/24/2016 22:34', 2],
#  ['8/24/2016 22:04', 6],
#  ['8/24/2016 21:52', 6],
#  ['8/24/2016 21:16', 0],
#  ['8/24/2016 21:02', 9],
#  ['8/24/2016 20:27', 1],
#  ['8/24/2016 19:50', 0],
#  ['8/24/2016 18:41', 1],
#  ['8/24/2016 17:38', 1],
#  ['8/24/2016 16:31', 0],
#  ['8/24/2016 16:11', 0],
#  ['8/24/2016 16:03', 2],
#  ['8/24/2016 15:23', 2],
#  ['8/24/2016 14:48', 2],
#  ['8/24/2016 14:10', 0],
#  ['8/24/2016 13:54', 0],
#  ['8/24/2016 12:09', 1],
#  ['8/24/2016 12:07', 2],
#  ['8/24/2016 11:54', 26],
#  ['8/24/2016 10:50', 10],
#  ['8/24/2016 9:57', 83],
#  ['8/24/2016 8:11', 0],
#  ['8/24/2016 6:48', 0],
#  ['8/24/2016 6:17', 1],
#  ['8/24/2016 5:56', 0],
#  ['8/24/2016 3:41', 5],
#  ['8/24/2016 2:35', 1],
#  ['8/24/2016 2:15', 23],
#  ['8/24/2016 2:03', 2],
#  ['8/24/2016 0:05', 234],
#  ['8/23/2016 23:22', 6],
#  ['8/23/2016 21:56', 1],
#  ['8/23/2016 21:02', 3],
#  ['8/23/2016 20:46', 0],
#  ['8/23/2016 20:00', 2],
#  ['8/23/2016 19:11', 2],
#  ['8/23/2016 19:05', 1],
#  ['8/23/2016 18:35', 22],
#  ['8/23/2016 17:58', 5],
#  ['8/23/2016 17:01', 0],
#  ['8/23/2016 16:51', 3],
#  ['8/23/2016 15:01', 5],
#  ['8/23/2016 14:36', 2],
#  ['8/23/2016 14:23', 1],
#  ['8/23/2016 13:49', 10],
#  ['8/23/2016 13:48', 4],
#  ['8/23/2016 13:23', 26],
#  ['8/23/2016 13:13', 2],
#  ['8/23/2016 12:59', 6],
#  ['8/23/2016 12:43', 1],
#  ['8/23/2016 12:43', 4],
#  ['8/23/2016 12:35', 26],
#  ['8/23/2016 12:34', 0],
#  ['8/23/2016 11:50', 8],
#  ['8/23/2016 8:52', 3],
#  ['8/23/2016 7:29', 2],
#  ['8/23/2016 4:32', 3],
#  ['8/23/2016 3:50', 12],
#  ['8/23/2016 1:47', 0],
#  ['8/23/2016 1:17', 0],
#  ['8/23/2016 0:57', 0],
#  ['8/23/2016 0:53', 15],
#  ['8/22/2016 22:28', 0],
#  ['8/22/2016 20:56', 1],
#  ['8/22/2016 19:55', 0],
#  ['8/22/2016 19:28', 9],
#  ['8/22/2016 18:23', 3],
#  ['8/22/2016 18:01', 6],
#  ['8/22/2016 17:17', 8],
#  ['8/22/2016 17:05', 3],
#  ['8/22/2016 17:04', 0],
#  ['8/22/2016 16:56', 0],
#  ['8/22/2016 16:46', 0],
#  ['8/22/2016 16:41', 44],
#  ['8/22/2016 15:14', 0],
#  ['8/22/2016 15:06', 1],
#  ['8/22/2016 14:46', 126],
#  ['8/22/2016 14:45', 1],
#  ['8/22/2016 14:38', 1],
#  ['8/22/2016 13:52', 1],
#  ...]

# %%
len(result_list)
# Out:
# 9139

# %%
result_list[:3]
# Out:
# [['9/26/2016 2:53', 7], ['9/26/2016 1:17', 3], ['9/25/2016 22:57', 0]]

# %%
comments_by_hour
# Out:
# {'02': 2996,
#  '01': 2089,
#  '22': 3372,
#  '21': 4500,
#  '19': 3954,
#  '17': 5547,
#  '15': 18525,
#  '14': 4972,
#  '13': 7245,
#  '11': 2797,
#  '10': 3013,
#  '09': 1477,
#  '07': 1585,
#  '03': 2154,
#  '23': 2297,
#  '20': 4462,
#  '16': 4466,
#  '08': 2362,
#  '00': 2277,
#  '18': 4877,
#  '12': 4234,
#  '04': 2360,
#  '06': 1587,
#  '05': 1838}

# %%
counts_by_hour
# Out:
# {'02': 269,
#  '01': 282,
#  '22': 383,
#  '21': 518,
#  '19': 552,
#  '17': 587,
#  '15': 646,
#  '14': 513,
#  '13': 444,
#  '11': 312,
#  '10': 282,
#  '09': 222,
#  '07': 226,
#  '03': 271,
#  '23': 343,
#  '20': 510,
#  '16': 579,
#  '08': 257,
#  '00': 301,
#  '18': 614,
#  '12': 342,
#  '04': 243,
#  '06': 234,
#  '05': 209}

# %%
# max value of comments_by_hour

# %%
max_by_hour = 0
max_hour = []

for row in counts_by_hour:
    if counts_by_hour[row]>max_by_hour:
        max_by_our = counts_by_hour[row]
        max_hour = [row , counts_by_hour[row]]
        
print('by',max_hour[1], 'posts', max_hour[0],'\'o clock has the highest number of posts.')
# Out:
# by 209 posts 05 'o clock has the highest number of posts.

# %%
# calculating average number of comments for posts during each hour

# %%
avg_by_hour = []

for count in comments_by_hour:
    avg_by_hour.append([count , comments_by_hour[count] / counts_by_hour[count]])

# %%
for row in sorted(avg_by_hour):
    print(row)
# Out:
# ['00', 7.5647840531561465]
# ['01', 7.407801418439717]
# ['02', 11.137546468401487]
# ['03', 7.948339483394834]
# ['04', 9.7119341563786]
# ['05', 8.794258373205741]
# ['06', 6.782051282051282]
# ['07', 7.013274336283186]
# ['08', 9.190661478599221]
# ['09', 6.653153153153153]
# ['10', 10.684397163120567]
# ['11', 8.96474358974359]
# ['12', 12.380116959064328]
# ['13', 16.31756756756757]
# ['14', 9.692007797270955]
# ['15', 28.676470588235293]
# ['16', 7.713298791018998]
# ['17', 9.449744463373083]
# ['18', 7.94299674267101]
# ['19', 7.163043478260869]
# ['20', 8.749019607843136]
# ['21', 8.687258687258687]
# ['22', 8.804177545691905]
# ['23', 6.696793002915452]

# %%
#Let's swap the places of avg_by_hour
#to sort the data at more convenience
swap_avg_by_hour = []
for row in avg_by_hour:
    swap_avg_by_hour.append([row[1], row[0]])
    
print('Most number of comments where obsevered during:')
sorted_swap = sorted(swap_avg_by_hour, reverse = True)
    
for average, hr in sorted_swap[:5]: 
    hour = dt.datetime.strptime(hr,'%H')#convert the string to a datetime object
    time = hour.strftime('%H:%M')#format the datetime object
    print('{time}: {average:.2f} comments per post'.format(time = time, average = average))
# Out:
# Most number of comments where obsevered during:
# 15:00: 28.68 comments per post
# 13:00: 16.32 comments per post
# 12:00: 12.38 comments per post
# 02:00: 11.14 comments per post
# 10:00: 10.68 comments per post

# %%
print('Top 5 hours in IST for Ask Posts comments:')

for average, hr in sorted_swap[:5]: 
    hour = dt.datetime.strptime(hr,'%H')
    ist = hour + dt.timedelta(hours = 10.5)
    time = ist.strftime('%H:%M')
    print('{time}: {average:.2f} comments per post'.format(time = time, average = average))
# Out:
# Top 5 hours in IST for Ask Posts comments:
# 01:30: 28.68 comments per post
# 23:30: 16.32 comments per post
# 22:30: 12.38 comments per post
# 12:30: 11.14 comments per post
# 20:30: 10.68 comments per post

# %%
result_list = []
# we iterate trough each post in show_post, then asign
# the timestamp to created_at and the number of comments
# to num_comments. At the end we append a list with that
# data to the result_list

for row in show_posts:
    dates = row[-1]
    n_points = int(row[4])
    result_list.append([dates, n_points])

posts_by_hour = {} # contains the number of ask posts created during each hour of the day
points_by_hour = {} # contains the corresponding number of comments ask posts created at each hour received

for row in result_list:
    hour = row[0]
    num_points = row[1]
    time = dt.datetime.strptime(hour, '%m/%d/%Y %H:%M') # we convert the date string to a datetime object
    hour = time.strftime('%H') # we ectract the hour (%H) from the datetime object
    
    # now we create a frequent table and count the hour to get
    # the number of posts for each hour and set the comments by hour
    # equal to the comment number to get the comments in each hour.
    
    if hour not in posts_by_hour:
        posts_by_hour[hour] = 1
        points_by_hour[hour] = 1
    else:
        posts_by_hour[hour] += 1
        points_by_hour[hour] += num_points

# %%
result_list
# Out:
# [['9/26/2016 0:36', 0],
#  ['9/26/2016 0:01', 0],
#  ['9/25/2016 23:44', 0],
#  ['9/25/2016 23:17', 0],
#  ['9/25/2016 20:06', 1],
#  ['9/25/2016 19:06', 1],
#  ['9/25/2016 18:32', 0],
#  ['9/25/2016 16:50', 1],
#  ['9/25/2016 16:43', 0],
#  ['9/25/2016 14:30', 1],
#  ['9/25/2016 10:50', 3],
#  ['9/25/2016 10:00', 0],
#  ['9/25/2016 9:19', 1],
#  ['9/25/2016 9:19', 0],
#  ['9/25/2016 8:49', 0],
#  ['9/25/2016 6:48', 1],
#  ['9/25/2016 3:06', 1],
#  ['9/24/2016 23:18', 0],
#  ['9/24/2016 21:36', 0],
#  ['9/24/2016 20:07', 26],
#  ['9/24/2016 19:35', 0],
#  ['9/24/2016 18:42', 2],
#  ['9/24/2016 18:40', 0],
#  ['9/24/2016 18:36', 0],
#  ['9/24/2016 18:35', 1],
#  ['9/24/2016 17:34', 1],
#  ['9/24/2016 15:20', 0],
#  ['9/24/2016 15:06', 102],
#  ['9/24/2016 15:03', 0],
#  ['9/24/2016 11:24', 0],
#  ['9/24/2016 11:23', 1],
#  ['9/24/2016 11:23', 5],
#  ['9/24/2016 7:24', 0],
#  ['9/24/2016 4:16', 0],
#  ['9/24/2016 0:41', 0],
#  ['9/23/2016 21:18', 0],
#  ['9/23/2016 19:38', 1],
#  ['9/23/2016 18:55', 1],
#  ['9/23/2016 18:31', 8],
#  ['9/23/2016 17:52', 0],
#  ['9/23/2016 17:29', 0],
#  ['9/23/2016 17:24', 0],
#  ['9/23/2016 17:03', 0],
#  ['9/23/2016 16:37', 0],
#  ['9/23/2016 15:55', 0],
#  ['9/23/2016 15:43', 0],
#  ['9/23/2016 14:03', 1],
#  ['9/23/2016 13:29', 62],
#  ['9/23/2016 12:11', 0],
#  ['9/23/2016 11:13', 12],
#  ['9/23/2016 9:27', 1],
#  ['9/23/2016 9:19', 0],
#  ['9/23/2016 9:13', 0],
#  ['9/23/2016 9:03', 0],
#  ['9/23/2016 8:54', 0],
#  ['9/23/2016 8:41', 0],
#  ['9/23/2016 1:30', 1],
#  ['9/23/2016 1:22', 0],
#  ['9/22/2016 22:47', 9],
#  ['9/22/2016 20:46', 7],
#  ['9/22/2016 20:22', 1],
#  ['9/22/2016 19:39', 1],
#  ['9/22/2016 19:35', 1],
#  ['9/22/2016 18:21', 0],
#  ['9/22/2016 17:50', 1],
#  ['9/22/2016 17:22', 0],
#  ['9/22/2016 17:14', 0],
#  ['9/22/2016 16:25', 0],
#  ['9/22/2016 15:08', 0],
#  ['9/22/2016 14:40', 2],
#  ['9/22/2016 14:19', 0],
#  ['9/22/2016 14:01', 4],
#  ['9/22/2016 13:08', 0],
#  ['9/22/2016 13:07', 0],
#  ['9/22/2016 13:02', 0],
#  ['9/22/2016 12:43', 1],
#  ['9/22/2016 9:27', 1],
#  ['9/22/2016 8:43', 0],
#  ['9/22/2016 8:36', 3],
#  ['9/22/2016 4:13', 1],
#  ['9/22/2016 2:50', 0],
#  ['9/22/2016 0:53', 0],
#  ['9/22/2016 0:38', 28],
#  ['9/21/2016 22:27', 4],
#  ['9/21/2016 21:55', 167],
#  ['9/21/2016 21:47', 6],
#  ['9/21/2016 21:09', 1],
#  ['9/21/2016 20:02', 0],
#  ['9/21/2016 19:30', 1],
#  ['9/21/2016 19:04', 0],
#  ['9/21/2016 19:01', 4],
#  ['9/21/2016 18:54', 0],
#  ['9/21/2016 18:22', 0],
#  ['9/21/2016 18:10', 0],
#  ['9/21/2016 17:25', 12],
#  ['9/21/2016 16:59', 1],
#  ['9/21/2016 16:43', 75],
#  ['9/21/2016 16:21', 0],
#  ['9/21/2016 16:19', 0],
#  ['9/21/2016 15:47', 0],
#  ['9/21/2016 15:40', 0],
#  ['9/21/2016 15:29', 0],
#  ['9/21/2016 15:11', 2],
#  ['9/21/2016 15:06', 0],
#  ['9/21/2016 13:25', 0],
#  ['9/21/2016 13:11', 0],
#  ['9/21/2016 12:01', 1],
#  ['9/21/2016 11:57', 0],
#  ['9/21/2016 11:55', 0],
#  ['9/21/2016 11:33', 0],
#  ['9/21/2016 11:23', 1],
#  ['9/21/2016 11:22', 0],
#  ['9/21/2016 10:50', 3],
#  ['9/21/2016 8:43', 0],
#  ['9/21/2016 8:36', 21],
#  ['9/21/2016 8:32', 0],
#  ['9/21/2016 5:35', 5],
#  ['9/21/2016 3:44', 3],
#  ['9/21/2016 3:41', 0],
#  ['9/21/2016 3:24', 0],
#  ['9/21/2016 3:02', 0],
#  ['9/21/2016 0:49', 1],
#  ['9/20/2016 21:50', 0],
#  ['9/20/2016 21:09', 2],
#  ['9/20/2016 20:55', 1],
#  ['9/20/2016 19:32', 0],
#  ['9/20/2016 18:27', 2],
#  ['9/20/2016 18:26', 0],
#  ['9/20/2016 17:47', 0],
#  ['9/20/2016 17:22', 2],
#  ['9/20/2016 16:23', 0],
#  ['9/20/2016 15:02', 0],
#  ['9/20/2016 14:36', 0],
#  ['9/20/2016 14:07', 1],
#  ['9/20/2016 14:07', 1],
#  ['9/20/2016 13:24', 1],
#  ['9/20/2016 13:16', 22],
#  ['9/20/2016 13:09', 2],
#  ['9/20/2016 12:55', 169],
#  ['9/20/2016 12:17', 17],
#  ['9/20/2016 11:44', 2],
#  ['9/20/2016 11:15', 0],
#  ['9/20/2016 9:39', 0],
#  ['9/20/2016 8:45', 0],
#  ['9/20/2016 7:53', 0],
#  ['9/20/2016 4:46', 0],
#  ['9/20/2016 3:41', 3],
#  ['9/19/2016 23:59', 0],
#  ['9/19/2016 23:35', 3],
#  ['9/19/2016 20:26', 4],
#  ['9/19/2016 20:03', 3],
#  ['9/19/2016 19:15', 2],
#  ['9/19/2016 19:02', 0],
#  ['9/19/2016 18:54', 0],
#  ['9/19/2016 18:53', 0],
#  ['9/19/2016 18:49', 0],
#  ['9/19/2016 18:45', 0],
#  ['9/19/2016 18:40', 0],
#  ['9/19/2016 18:13', 0],
#  ['9/19/2016 17:39', 1],
#  ['9/19/2016 16:55', 1],
#  ['9/19/2016 15:41', 0],
#  ['9/19/2016 15:39', 3],
#  ['9/19/2016 15:09', 0],
#  ['9/19/2016 14:00', 0],
#  ['9/19/2016 13:03', 0],
#  ['9/19/2016 12:43', 1],
#  ['9/19/2016 12:04', 1],
#  ['9/19/2016 9:55', 0],
#  ['9/19/2016 9:21', 0],
#  ['9/19/2016 8:24', 0],
#  ['9/19/2016 7:42', 4],
#  ['9/19/2016 1:55', 9],
#  ['9/19/2016 0:19', 1],
#  ['9/19/2016 0:11', 21],
#  ['9/18/2016 23:16', 0],
#  ['9/18/2016 22:27', 0],
#  ['9/18/2016 20:52', 0],
#  ['9/18/2016 19:06', 1],
#  ['9/18/2016 18:18', 0],
#  ['9/18/2016 17:35', 1],
#  ['9/18/2016 15:27', 0],
#  ['9/18/2016 14:43', 1],
#  ['9/18/2016 14:32', 27],
#  ['9/18/2016 14:23', 4],
#  ['9/18/2016 12:51', 1],
#  ['9/18/2016 12:45', 28],
#  ['9/18/2016 11:48', 1],
#  ['9/18/2016 9:42', 33],
#  ['9/18/2016 9:33', 24],
#  ['9/18/2016 4:52', 0],
#  ['9/17/2016 23:21', 2],
#  ['9/17/2016 21:31', 1],
#  ['9/17/2016 15:03', 0],
#  ['9/17/2016 13:07', 2],
#  ['9/17/2016 8:22', 0],
#  ['9/17/2016 7:25', 1],
#  ['9/17/2016 4:27', 0],
#  ['9/17/2016 4:03', 0],
#  ['9/16/2016 22:24', 0],
#  ['9/16/2016 21:18', 0],
#  ['9/16/2016 20:51', 0],
#  ['9/16/2016 20:42', 0],
#  ['9/16/2016 20:41', 0],
#  ['9/16/2016 19:00', 0],
#  ['9/16/2016 18:28', 0],
#  ['9/16/2016 17:32', 0],
#  ['9/16/2016 16:51', 5],
#  ['9/16/2016 16:47', 3],
#  ['9/16/2016 15:12', 1],
#  ['9/16/2016 15:09', 1],
#  ['9/16/2016 14:31', 0],
#  ['9/16/2016 14:21', 31],
#  ['9/16/2016 13:51', 3],
#  ['9/16/2016 13:41', 0],
#  ['9/16/2016 12:56', 0],
#  ['9/16/2016 12:45', 0],
#  ['9/16/2016 11:44', 0],
#  ['9/16/2016 10:08', 26],
#  ['9/16/2016 9:56', 1],
#  ['9/16/2016 8:23', 18],
#  ['9/16/2016 7:46', 8],
#  ['9/16/2016 6:55', 0],
#  ['9/16/2016 6:18', 0],
#  ['9/16/2016 4:57', 2],
#  ['9/16/2016 4:05', 0],
#  ['9/16/2016 1:13', 0],
#  ['9/15/2016 22:11', 1],
#  ['9/15/2016 22:00', 1],
#  ['9/15/2016 21:55', 0],
#  ['9/15/2016 21:04', 10],
#  ['9/15/2016 20:37', 0],
#  ['9/15/2016 19:59', 9],
#  ['9/15/2016 19:43', 1],
#  ['9/15/2016 19:34', 0],
#  ['9/15/2016 18:33', 7],
#  ['9/15/2016 17:55', 0],
#  ['9/15/2016 17:14', 0],
#  ['9/15/2016 17:09', 1],
#  ['9/15/2016 16:59', 8],
#  ['9/15/2016 16:59', 0],
#  ['9/15/2016 16:15', 70],
#  ['9/15/2016 16:12', 0],
#  ['9/15/2016 16:05', 1],
#  ['9/15/2016 16:00', 6],
#  ['9/15/2016 15:16', 0],
#  ['9/15/2016 15:15', 0],
#  ['9/15/2016 15:10', 0],
#  ['9/15/2016 14:59', 0],
#  ['9/15/2016 14:06', 0],
#  ['9/15/2016 13:43', 1],
#  ['9/15/2016 13:26', 17],
#  ['9/15/2016 11:36', 43],
#  ['9/15/2016 10:41', 0],
#  ['9/15/2016 10:34', 1],
#  ['9/15/2016 10:31', 3],
#  ['9/15/2016 9:38', 1],
#  ['9/15/2016 9:06', 0],
#  ['9/15/2016 8:27', 0],
#  ['9/15/2016 8:16', 0],
#  ['9/15/2016 7:07', 280],
#  ['9/15/2016 5:58', 3],
#  ['9/15/2016 5:06', 1],
#  ['9/15/2016 0:32', 0],
#  ['9/15/2016 0:32', 5],
#  ['9/14/2016 23:17', 1],
#  ['9/14/2016 22:33', 26],
#  ['9/14/2016 22:15', 0],
#  ['9/14/2016 21:03', 0],
#  ['9/14/2016 20:25', 0],
#  ['9/14/2016 19:31', 0],
#  ['9/14/2016 18:27', 44],
#  ['9/14/2016 17:37', 0],
#  ['9/14/2016 17:00', 6],
#  ['9/14/2016 15:53', 1],
#  ['9/14/2016 15:38', 0],
#  ['9/14/2016 15:26', 0],
#  ['9/14/2016 15:00', 1],
#  ['9/14/2016 14:41', 0],
#  ['9/14/2016 14:37', 1],
#  ['9/14/2016 14:20', 0],
#  ['9/14/2016 14:13', 3],
#  ['9/14/2016 14:07', 4],
#  ['9/14/2016 14:03', 6],
#  ['9/14/2016 12:55', 0],
#  ['9/14/2016 12:50', 7],
#  ['9/14/2016 12:38', 0],
#  ['9/14/2016 11:18', 1],
#  ['9/14/2016 9:53', 0],
#  ['9/14/2016 9:29', 5],
#  ['9/14/2016 8:48', 27],
#  ['9/14/2016 8:26', 0],
#  ['9/14/2016 8:14', 1],
#  ['9/14/2016 6:40', 0],
#  ['9/14/2016 6:14', 0],
#  ['9/14/2016 4:48', 0],
#  ['9/14/2016 4:19', 0],
#  ['9/14/2016 2:30', 1],
#  ['9/14/2016 0:24', 5],
#  ['9/13/2016 22:57', 10],
#  ['9/13/2016 22:51', 0],
#  ['9/13/2016 22:11', 0],
#  ['9/13/2016 21:54', 0],
#  ['9/13/2016 21:47', 0],
#  ['9/13/2016 21:22', 0],
#  ['9/13/2016 20:49', 6],
#  ['9/13/2016 19:37', 0],
#  ['9/13/2016 18:55', 2],
#  ['9/13/2016 17:16', 1],
#  ['9/13/2016 17:12', 1],
#  ['9/13/2016 16:27', 0],
#  ['9/13/2016 16:04', 0],
#  ['9/13/2016 15:57', 1],
#  ['9/13/2016 15:57', 0],
#  ['9/13/2016 15:50', 0],
#  ['9/13/2016 15:33', 0],
#  ['9/13/2016 14:21', 4],
#  ['9/13/2016 14:16', 0],
#  ['9/13/2016 14:11', 3],
#  ['9/13/2016 14:09', 0],
#  ['9/13/2016 13:27', 3],
#  ['9/13/2016 12:47', 10],
#  ['9/13/2016 11:56', 1],
#  ['9/13/2016 11:45', 0],
#  ['9/13/2016 11:43', 3],
#  ['9/13/2016 11:05', 1],
#  ['9/13/2016 10:16', 11],
#  ['9/13/2016 9:31', 139],
#  ['9/13/2016 8:40', 1],
#  ['9/13/2016 8:31', 3],
#  ['9/13/2016 4:44', 0],
#  ['9/13/2016 2:35', 2],
#  ['9/12/2016 23:41', 1],
#  ['9/12/2016 20:16', 0],
#  ['9/12/2016 19:40', 0],
#  ['9/12/2016 19:14', 0],
#  ['9/12/2016 18:58', 0],
#  ['9/12/2016 18:38', 0],
#  ['9/12/2016 18:29', 0],
#  ['9/12/2016 18:06', 6],
#  ['9/12/2016 17:47', 0],
#  ['9/12/2016 17:23', 0],
#  ['9/12/2016 17:10', 0],
#  ['9/12/2016 16:50', 0],
#  ['9/12/2016 16:05', 15],
#  ['9/12/2016 14:25', 0],
#  ['9/12/2016 14:24', 2],
#  ['9/12/2016 14:09', 0],
#  ['9/12/2016 14:03', 1],
#  ['9/12/2016 13:47', 0],
#  ['9/12/2016 13:37', 0],
#  ['9/12/2016 13:26', 0],
#  ['9/12/2016 12:53', 0],
#  ['9/12/2016 12:26', 1],
#  ['9/12/2016 11:32', 4],
#  ['9/12/2016 10:24', 0],
#  ['9/12/2016 10:02', 4],
#  ['9/12/2016 10:01', 5],
#  ['9/12/2016 8:09', 0],
#  ['9/12/2016 7:41', 3],
#  ['9/12/2016 5:01', 48],
#  ['9/12/2016 4:32', 3],
#  ['9/12/2016 3:43', 15],
#  ['9/12/2016 1:39', 24],
#  ['9/12/2016 0:21', 5],
#  ['9/11/2016 21:42', 1],
#  ['9/11/2016 21:42', 0],
#  ['9/11/2016 21:40', 0],
#  ['9/11/2016 19:22', 0],
#  ['9/11/2016 19:20', 0],
#  ['9/11/2016 19:13', 4],
#  ['9/11/2016 17:49', 1],
#  ['9/11/2016 17:27', 0],
#  ['9/11/2016 17:20', 37],
#  ['9/11/2016 14:59', 1],
#  ['9/11/2016 14:49', 0],
#  ['9/11/2016 13:54', 0],
#  ['9/11/2016 13:24', 0],
#  ['9/11/2016 10:55', 0],
#  ['9/11/2016 10:21', 3],
#  ['9/11/2016 9:57', 0],
#  ['9/11/2016 7:54', 0],
#  ['9/11/2016 6:23', 0],
#  ['9/11/2016 0:26', 3],
#  ['9/11/2016 0:02', 1],
#  ['9/10/2016 22:01', 2],
#  ['9/10/2016 20:43', 2],
#  ['9/10/2016 19:54', 0],
#  ['9/10/2016 17:33', 1],
#  ['9/10/2016 17:07', 11],
#  ['9/10/2016 16:23', 2],
#  ['9/10/2016 15:45', 0],
#  ['9/10/2016 15:41', 3],
#  ['9/10/2016 15:29', 1],
#  ['9/10/2016 15:15', 3],
#  ['9/10/2016 14:40', 0],
#  ['9/10/2016 14:19', 0],
#  ['9/10/2016 13:39', 0],
#  ['9/10/2016 11:36', 49],
#  ['9/10/2016 11:26', 1],
#  ['9/10/2016 10:37', 0],
#  ['9/10/2016 9:38', 0],
#  ['9/10/2016 9:27', 9],
#  ['9/10/2016 0:35', 4],
#  ['9/9/2016 23:34', 0],
#  ['9/9/2016 23:00', 38],
#  ['9/9/2016 20:10', 31],
#  ['9/9/2016 19:13', 1],
#  ['9/9/2016 17:53', 1],
#  ['9/9/2016 17:46', 9],
#  ['9/9/2016 17:15', 0],
#  ['9/9/2016 16:51', 0],
#  ['9/9/2016 16:47', 1],
#  ['9/9/2016 16:35', 0],
#  ['9/9/2016 16:06', 1],
#  ['9/9/2016 15:41', 8],
#  ['9/9/2016 15:04', 0],
#  ['9/9/2016 14:16', 4],
#  ['9/9/2016 14:09', 0],
#  ['9/9/2016 14:04', 1],
#  ['9/9/2016 13:09', 0],
#  ['9/9/2016 13:04', 6],
#  ['9/9/2016 12:27', 0],
#  ['9/9/2016 10:02', 0],
#  ['9/9/2016 8:20', 2],
#  ['9/9/2016 8:00', 0],
#  ['9/9/2016 7:31', 0],
#  ['9/9/2016 7:30', 3],
#  ['9/9/2016 5:15', 1],
#  ['9/9/2016 1:00', 0],
#  ['9/8/2016 23:39', 6],
#  ['9/8/2016 22:34', 0],
#  ['9/8/2016 22:09', 41],
#  ['9/8/2016 21:23', 1],
#  ['9/8/2016 20:03', 2],
#  ['9/8/2016 19:52', 0],
#  ['9/8/2016 19:16', 43],
#  ['9/8/2016 19:05', 0],
#  ['9/8/2016 18:54', 1],
#  ['9/8/2016 18:51', 0],
#  ['9/8/2016 18:26', 0],
#  ['9/8/2016 18:06', 0],
#  ['9/8/2016 18:02', 2],
#  ['9/8/2016 17:49', 3],
#  ['9/8/2016 17:37', 6],
#  ['9/8/2016 16:58', 0],
#  ['9/8/2016 16:55', 56],
#  ['9/8/2016 16:36', 0],
#  ['9/8/2016 16:35', 0],
#  ['9/8/2016 16:34', 2],
#  ['9/8/2016 16:27', 1],
#  ['9/8/2016 16:19', 0],
#  ['9/8/2016 15:55', 16],
#  ['9/8/2016 15:38', 1],
#  ['9/8/2016 15:36', 0],
#  ['9/8/2016 15:20', 0],
#  ['9/8/2016 14:53', 0],
#  ['9/8/2016 14:51', 2],
#  ['9/8/2016 13:13', 0],
#  ['9/8/2016 12:20', 3],
#  ['9/8/2016 9:44', 0],
#  ['9/8/2016 9:33', 1],
#  ['9/8/2016 9:04', 0],
#  ['9/8/2016 7:40', 0],
#  ['9/8/2016 6:18', 46],
#  ['9/8/2016 5:07', 0],
#  ['9/8/2016 5:04', 3],
#  ['9/8/2016 3:58', 1],
#  ['9/7/2016 22:36', 0],
#  ['9/7/2016 22:18', 1],
#  ['9/7/2016 21:55', 0],
#  ['9/7/2016 21:28', 2],
#  ['9/7/2016 20:50', 1],
#  ['9/7/2016 19:49', 0],
#  ['9/7/2016 19:11', 1],
#  ['9/7/2016 18:48', 0],
#  ['9/7/2016 18:34', 3],
#  ['9/7/2016 18:31', 0],
#  ['9/7/2016 17:27', 1],
#  ['9/7/2016 17:02', 2],
#  ['9/7/2016 15:59', 2],
#  ['9/7/2016 15:19', 9],
#  ['9/7/2016 14:00', 0],
#  ['9/7/2016 13:57', 3],
#  ['9/7/2016 13:12', 0],
#  ['9/7/2016 12:18', 0],
#  ['9/7/2016 12:03', 0],
#  ['9/7/2016 11:46', 2],
#  ['9/7/2016 11:20', 4],
#  ['9/7/2016 10:06', 44],
#  ['9/7/2016 9:15', 3],
#  ['9/7/2016 9:03', 0],
#  ['9/7/2016 7:52', 0],
#  ['9/7/2016 6:37', 35],
#  ['9/7/2016 3:19', 1],
#  ['9/7/2016 1:55', 0],
#  ['9/6/2016 22:58', 1],
#  ['9/6/2016 21:52', 0],
#  ['9/6/2016 20:40', 0],
#  ['9/6/2016 20:26', 0],
#  ['9/6/2016 20:18', 0],
#  ['9/6/2016 20:04', 4],
#  ['9/6/2016 18:59', 1],
#  ['9/6/2016 18:43', 3],
#  ['9/6/2016 18:25', 30],
#  ['9/6/2016 18:21', 1],
#  ['9/6/2016 18:13', 0],
#  ['9/6/2016 18:12', 7],
#  ['9/6/2016 15:43', 0],
#  ['9/6/2016 15:08', 1],
#  ['9/6/2016 14:50', 0],
#  ['9/6/2016 14:50', 0],
#  ['9/6/2016 13:44', 0],
#  ['9/6/2016 13:14', 1],
#  ['9/6/2016 13:13', 0],
#  ['9/6/2016 12:11', 0],
#  ['9/6/2016 12:03', 4],
#  ['9/6/2016 11:27', 0],
#  ['9/6/2016 11:17', 0],
#  ['9/6/2016 10:46', 0],
#  ['9/6/2016 10:19', 0],
#  ['9/6/2016 9:44', 0],
#  ['9/6/2016 8:29', 0],
#  ['9/6/2016 7:38', 0],
#  ['9/6/2016 7:04', 0],
#  ['9/6/2016 6:40', 1],
#  ['9/6/2016 4:57', 2],
#  ['9/6/2016 4:51', 0],
#  ['9/6/2016 4:16', 1],
#  ['9/6/2016 3:41', 31],
#  ['9/6/2016 2:16', 1],
#  ['9/6/2016 2:13', 0],
#  ['9/6/2016 0:21', 43],
#  ['9/5/2016 23:46', 0],
#  ['9/5/2016 22:59', 0],
#  ['9/5/2016 22:49', 0],
#  ['9/5/2016 22:14', 0],
#  ['9/5/2016 20:45', 0],
#  ['9/5/2016 20:32', 3],
#  ['9/5/2016 20:00', 1],
#  ['9/5/2016 19:14', 2],
#  ['9/5/2016 18:53', 80],
#  ['9/5/2016 18:41', 3],
#  ['9/5/2016 18:41', 1],
#  ['9/5/2016 16:05', 0],
#  ['9/5/2016 15:44', 0],
#  ['9/5/2016 15:05', 3],
#  ['9/5/2016 14:42', 0],
#  ['9/5/2016 13:47', 0],
#  ['9/5/2016 13:16', 3],
#  ['9/5/2016 12:47', 0],
#  ['9/5/2016 12:28', 1],
#  ['9/5/2016 11:14', 0],
#  ['9/5/2016 9:48', 0],
#  ['9/5/2016 8:57', 1],
#  ['9/5/2016 8:48', 0],
#  ['9/5/2016 8:29', 0],
#  ['9/5/2016 7:49', 0],
#  ['9/5/2016 6:55', 2],
#  ['9/5/2016 6:27', 4],
#  ['9/5/2016 0:55', 88],
#  ['9/5/2016 0:29', 0],
#  ['9/4/2016 21:59', 0],
#  ['9/4/2016 21:00', 0],
#  ['9/4/2016 20:56', 1],
#  ['9/4/2016 17:39', 12],
#  ['9/4/2016 17:13', 1],
#  ['9/4/2016 17:01', 0],
#  ['9/4/2016 15:15', 23],
#  ['9/4/2016 13:45', 3],
#  ['9/4/2016 13:05', 1],
#  ['9/4/2016 12:59', 1],
#  ['9/4/2016 10:08', 1],
#  ['9/4/2016 10:06', 0],
#  ['9/4/2016 9:11', 0],
#  ['9/4/2016 8:54', 0],
#  ['9/4/2016 7:28', 3],
#  ['9/4/2016 5:47', 0],
#  ['9/4/2016 1:57', 15],
#  ['9/3/2016 23:37', 32],
#  ['9/3/2016 22:35', 0],
#  ['9/3/2016 20:30', 45],
#  ['9/3/2016 20:19', 0],
#  ['9/3/2016 17:55', 0],
#  ['9/3/2016 16:13', 49],
#  ['9/3/2016 14:55', 0],
#  ['9/3/2016 14:29', 0],
#  ['9/3/2016 14:09', 0],
#  ['9/3/2016 13:29', 0],
#  ['9/3/2016 12:12', 1],
#  ['9/3/2016 10:49', 1],
#  ['9/3/2016 7:32', 0],
#  ['9/3/2016 4:21', 1],
#  ['9/3/2016 1:11', 1],
#  ['9/3/2016 0:10', 1],
#  ['9/2/2016 22:38', 2],
#  ['9/2/2016 22:14', 0],
#  ['9/2/2016 21:19', 2],
#  ['9/2/2016 19:48', 2],
#  ['9/2/2016 18:47', 0],
#  ['9/2/2016 17:58', 1],
#  ['9/2/2016 17:18', 0],
#  ['9/2/2016 16:58', 1],
#  ['9/2/2016 16:23', 0],
#  ['9/2/2016 16:19', 2],
#  ['9/2/2016 16:12', 1],
#  ['9/2/2016 15:11', 1],
#  ['9/2/2016 14:41', 0],
#  ['9/2/2016 14:23', 0],
#  ['9/2/2016 14:12', 22],
#  ['9/2/2016 8:21', 1],
#  ['9/2/2016 7:42', 19],
#  ['9/2/2016 6:47', 0],
#  ['9/2/2016 6:32', 1],
#  ['9/2/2016 6:29', 0],
#  ['9/2/2016 6:19', 2],
#  ['9/1/2016 23:33', 0],
#  ['9/1/2016 21:09', 0],
#  ['9/1/2016 20:53', 0],
#  ['9/1/2016 19:34', 4],
#  ['9/1/2016 18:48', 0],
#  ['9/1/2016 17:37', 0],
#  ['9/1/2016 16:25', 1],
#  ['9/1/2016 16:18', 0],
#  ['9/1/2016 15:03', 5],
#  ['9/1/2016 14:25', 0],
#  ['9/1/2016 14:16', 3],
#  ['9/1/2016 13:48', 2],
#  ['9/1/2016 13:24', 0],
#  ['9/1/2016 12:59', 154],
#  ['9/1/2016 11:57', 23],
#  ['9/1/2016 11:08', 0],
#  ['9/1/2016 10:46', 5],
#  ['9/1/2016 10:40', 1],
#  ['9/1/2016 10:22', 0],
#  ['9/1/2016 9:33', 1],
#  ['9/1/2016 7:51', 76],
#  ['9/1/2016 7:20', 0],
#  ['9/1/2016 6:51', 0],
#  ['9/1/2016 4:43', 1],
#  ['9/1/2016 4:03', 4],
#  ['9/1/2016 2:26', 1],
#  ['9/1/2016 0:51', 0],
#  ['8/31/2016 22:52', 2],
#  ['8/31/2016 22:04', 1],
#  ['8/31/2016 22:02', 0],
#  ['8/31/2016 20:05', 1],
#  ['8/31/2016 19:18', 1],
#  ['8/31/2016 19:04', 1],
#  ['8/31/2016 18:35', 0],
#  ['8/31/2016 17:28', 34],
#  ['8/31/2016 16:49', 24],
#  ['8/31/2016 16:43', 1],
#  ['8/31/2016 16:35', 2],
#  ['8/31/2016 16:02', 0],
#  ['8/31/2016 14:56', 0],
#  ['8/31/2016 14:55', 0],
#  ['8/31/2016 14:39', 2],
#  ['8/31/2016 14:03', 0],
#  ['8/31/2016 13:56', 1],
#  ['8/31/2016 13:52', 60],
#  ['8/31/2016 13:45', 1],
#  ['8/31/2016 13:37', 1],
#  ['8/31/2016 13:36', 0],
#  ['8/31/2016 13:26', 0],
#  ['8/31/2016 12:59', 3],
#  ['8/31/2016 12:49', 1],
#  ['8/31/2016 12:17', 12],
#  ['8/31/2016 12:14', 3],
#  ['8/31/2016 11:25', 1],
#  ['8/31/2016 11:01', 0],
#  ['8/31/2016 10:55', 4],
#  ['8/31/2016 8:36', 6],
#  ['8/31/2016 7:16', 0],
#  ['8/31/2016 6:47', 0],
#  ['8/31/2016 6:15', 1],
#  ['8/31/2016 4:31', 2],
#  ['8/30/2016 23:02', 2],
#  ['8/30/2016 22:14', 0],
#  ['8/30/2016 21:56', 0],
#  ['8/30/2016 19:31', 0],
#  ['8/30/2016 18:55', 0],
#  ['8/30/2016 18:06', 0],
#  ['8/30/2016 17:29', 90],
#  ['8/30/2016 17:10', 0],
#  ['8/30/2016 15:28', 0],
#  ['8/30/2016 15:28', 47],
#  ['8/30/2016 15:09', 0],
#  ['8/30/2016 15:05', 1],
#  ['8/30/2016 15:01', 8],
#  ['8/30/2016 14:16', 36],
#  ['8/30/2016 12:55', 27],
#  ['8/30/2016 11:16', 2],
#  ['8/30/2016 10:55', 1],
#  ['8/30/2016 10:34', 0],
#  ['8/30/2016 9:59', 1],
#  ['8/30/2016 9:38', 0],
#  ['8/30/2016 9:24', 0],
#  ['8/30/2016 8:05', 0],
#  ['8/30/2016 7:45', 1],
#  ['8/30/2016 6:20', 0],
#  ['8/30/2016 6:17', 0],
#  ['8/30/2016 5:50', 0],
#  ['8/30/2016 5:28', 0],
#  ['8/30/2016 5:27', 0],
#  ['8/30/2016 5:16', 0],
#  ['8/30/2016 3:38', 0],
#  ['8/30/2016 3:20', 3],
#  ['8/30/2016 2:48', 2],
#  ['8/30/2016 2:15', 0],
#  ['8/29/2016 23:56', 48],
#  ['8/29/2016 23:51', 0],
#  ['8/29/2016 23:18', 0],
#  ['8/29/2016 22:18', 11],
#  ['8/29/2016 22:13', 0],
#  ['8/29/2016 20:40', 0],
#  ['8/29/2016 20:25', 0],
#  ['8/29/2016 19:14', 0],
#  ['8/29/2016 18:20', 28],
#  ['8/29/2016 17:35', 0],
#  ['8/29/2016 16:16', 17],
#  ['8/29/2016 15:44', 0],
#  ['8/29/2016 15:20', 0],
#  ['8/29/2016 14:55', 0],
#  ['8/29/2016 14:55', 0],
#  ['8/29/2016 14:33', 2],
#  ['8/29/2016 14:27', 0],
#  ['8/29/2016 13:19', 0],
#  ['8/29/2016 12:57', 3],
#  ['8/29/2016 11:10', 0],
#  ['8/29/2016 10:41', 44],
#  ['8/29/2016 10:18', 1],
#  ['8/29/2016 8:20', 0],
#  ['8/29/2016 8:11', 0],
#  ['8/29/2016 7:40', 4],
#  ['8/29/2016 7:19', 0],
#  ['8/29/2016 6:53', 3],
#  ['8/29/2016 6:00', 0],
#  ['8/29/2016 5:48', 9],
#  ['8/29/2016 1:56', 0],
#  ['8/28/2016 23:33', 1],
#  ['8/28/2016 21:50', 0],
#  ['8/28/2016 19:29', 0],
#  ['8/28/2016 19:08', 0],
#  ['8/28/2016 19:00', 1],
#  ['8/28/2016 18:35', 0],
#  ['8/28/2016 17:48', 1],
#  ['8/28/2016 16:46', 7],
#  ['8/28/2016 16:19', 1],
#  ['8/28/2016 16:10', 0],
#  ['8/28/2016 15:53', 2],
#  ['8/28/2016 15:48', 13],
#  ['8/28/2016 14:18', 0],
#  ['8/28/2016 14:14', 1],
#  ['8/28/2016 14:09', 0],
#  ['8/28/2016 14:08', 39],
#  ['8/28/2016 13:13', 7],
#  ['8/28/2016 11:19', 2],
#  ['8/28/2016 10:05', 1],
#  ['8/28/2016 9:01', 1],
#  ['8/28/2016 6:56', 2],
#  ['8/28/2016 6:44', 1],
#  ['8/28/2016 6:36', 1],
#  ['8/28/2016 3:09', 0],
#  ['8/28/2016 2:10', 0],
#  ['8/28/2016 1:39', 1],
#  ['8/28/2016 0:37', 1],
#  ['8/27/2016 20:06', 1],
#  ['8/27/2016 19:22', 30],
#  ['8/27/2016 18:36', 1],
#  ['8/27/2016 17:11', 0],
#  ['8/27/2016 16:11', 0],
#  ['8/27/2016 16:11', 0],
#  ['8/27/2016 15:39', 0],
#  ['8/27/2016 13:13', 1],
#  ['8/27/2016 12:59', 62],
#  ['8/27/2016 12:58', 0],
#  ['8/27/2016 3:44', 3],
#  ['8/27/2016 3:31', 1],
#  ['8/26/2016 22:45', 24],
#  ['8/26/2016 22:42', 3],
#  ['8/26/2016 21:32', 2],
#  ['8/26/2016 21:16', 2],
#  ['8/26/2016 20:46', 1],
#  ['8/26/2016 20:27', 5],
#  ['8/26/2016 18:59', 1],
#  ['8/26/2016 18:16', 0],
#  ['8/26/2016 17:17', 0],
#  ['8/26/2016 16:13', 0],
#  ['8/26/2016 15:49', 0],
#  ['8/26/2016 14:50', 0],
#  ['8/26/2016 14:43', 0],
#  ['8/26/2016 14:43', 0],
#  ['8/26/2016 14:35', 1],
#  ['8/26/2016 14:31', 0],
#  ['8/26/2016 14:07', 0],
#  ['8/26/2016 13:36', 0],
#  ['8/26/2016 13:35', 0],
#  ['8/26/2016 12:28', 184],
#  ['8/26/2016 12:10', 1],
#  ['8/26/2016 10:11', 0],
#  ['8/26/2016 9:00', 19],
#  ['8/26/2016 7:03', 0],
#  ['8/26/2016 6:19', 1],
#  ['8/26/2016 5:13', 0],
#  ['8/26/2016 5:00', 3],
#  ['8/26/2016 2:26', 0],
#  ['8/26/2016 1:24', 2],
#  ['8/25/2016 23:21', 0],
#  ['8/25/2016 19:48', 0],
#  ['8/25/2016 19:34', 0],
#  ['8/25/2016 19:15', 0],
#  ['8/25/2016 18:48', 1],
#  ['8/25/2016 17:53', 1],
#  ['8/25/2016 17:44', 0],
#  ['8/25/2016 17:30', 10],
#  ['8/25/2016 17:22', 34],
#  ['8/25/2016 17:02', 4],
#  ['8/25/2016 16:22', 0],
#  ['8/25/2016 15:04', 0],
#  ['8/25/2016 14:55', 0],
#  ['8/25/2016 14:53', 0],
#  ['8/25/2016 14:42', 0],
#  ['8/25/2016 13:53', 0],
#  ['8/25/2016 13:04', 0],
#  ['8/25/2016 12:43', 0],
#  ['8/25/2016 10:54', 0],
#  ['8/25/2016 9:43', 0],
#  ['8/25/2016 8:02', 1],
#  ['8/25/2016 2:00', 0],
#  ['8/25/2016 1:59', 0],
#  ['8/25/2016 1:06', 1],
#  ['8/24/2016 23:20', 1],
#  ['8/24/2016 21:22', 0],
#  ['8/24/2016 21:12', 1],
#  ['8/24/2016 20:42', 136],
#  ['8/24/2016 20:38', 0],
#  ['8/24/2016 19:34', 6],
#  ['8/24/2016 19:31', 2],
#  ['8/24/2016 18:51', 0],
#  ['8/24/2016 18:36', 0],
#  ['8/24/2016 18:20', 0],
#  ['8/24/2016 18:11', 1],
#  ['8/24/2016 17:50', 0],
#  ['8/24/2016 17:49', 2],
#  ['8/24/2016 17:25', 0],
#  ['8/24/2016 16:39', 0],
#  ['8/24/2016 16:03', 0],
#  ['8/24/2016 16:01', 0],
#  ['8/24/2016 15:47', 0],
#  ['8/24/2016 15:30', 0],
#  ['8/24/2016 15:16', 1],
#  ['8/24/2016 15:14', 1],
#  ['8/24/2016 14:02', 0],
#  ['8/24/2016 13:53', 0],
#  ['8/24/2016 13:29', 0],
#  ['8/24/2016 13:01', 0],
#  ['8/24/2016 12:59', 1],
#  ['8/24/2016 12:34', 0],
#  ['8/24/2016 11:25', 0],
#  ['8/24/2016 6:58', 3],
#  ['8/24/2016 2:59', 0],
#  ['8/24/2016 2:36', 0],
#  ['8/24/2016 1:18', 1],
#  ['8/23/2016 20:39', 0],
#  ['8/23/2016 19:20', 2],
#  ['8/23/2016 19:12', 1],
#  ['8/23/2016 18:41', 3],
#  ['8/23/2016 18:40', 1],
#  ['8/23/2016 17:36', 0],
#  ['8/23/2016 16:49', 0],
#  ['8/23/2016 16:27', 0],
#  ['8/23/2016 16:19', 0],
#  ['8/23/2016 16:18', 0],
#  ['8/23/2016 16:00', 5],
#  ['8/23/2016 15:05', 0],
#  ['8/23/2016 14:51', 0],
#  ['8/23/2016 14:02', 0],
#  ['8/23/2016 13:55', 0],
#  ['8/23/2016 11:54', 0],
#  ['8/23/2016 11:35', 35],
#  ['8/23/2016 11:18', 59],
#  ['8/23/2016 8:31', 1],
#  ['8/23/2016 7:40', 0],
#  ['8/23/2016 6:04', 0],
#  ['8/23/2016 5:29', 0],
#  ['8/23/2016 3:04', 35],
#  ['8/23/2016 2:44', 26],
#  ['8/23/2016 1:48', 1],
#  ['8/22/2016 23:48', 0],
#  ['8/22/2016 23:37', 0],
#  ['8/22/2016 22:08', 2],
#  ['8/22/2016 21:44', 0],
#  ['8/22/2016 19:06', 1],
#  ['8/22/2016 18:34', 5],
#  ['8/22/2016 18:21', 2],
#  ['8/22/2016 18:08', 0],
#  ['8/22/2016 17:50', 0],
#  ['8/22/2016 17:18', 0],
#  ['8/22/2016 17:06', 0],
#  ['8/22/2016 17:03', 6],
#  ['8/22/2016 15:34', 1],
#  ['8/22/2016 15:23', 0],
#  ['8/22/2016 15:20', 0],
#  ['8/22/2016 15:16', 0],
#  ['8/22/2016 15:10', 0],
#  ['8/22/2016 13:45', 1],
#  ['8/22/2016 13:06', 0],
#  ['8/22/2016 13:00', 0],
#  ['8/22/2016 12:26', 3],
#  ['8/22/2016 10:44', 0],
#  ['8/22/2016 10:04', 0],
#  ['8/22/2016 9:49', 1],
#  ['8/22/2016 9:34', 0],
#  ['8/22/2016 9:05', 3],
#  ['8/22/2016 8:47', 0],
#  ['8/22/2016 8:44', 0],
#  ['8/22/2016 7:57', 1],
#  ['8/22/2016 7:12', 0],
#  ['8/22/2016 7:11', 1],
#  ['8/22/2016 6:46', 0],
#  ['8/22/2016 5:27', 1],
#  ['8/22/2016 1:55', 2],
#  ['8/22/2016 1:47', 1],
#  ['8/21/2016 22:44', 3],
#  ['8/21/2016 20:48', 0],
#  ['8/21/2016 20:11', 0],
#  ['8/21/2016 17:59', 32],
#  ['8/21/2016 17:14', 0],
#  ['8/21/2016 17:00', 0],
#  ['8/21/2016 14:52', 5],
#  ['8/21/2016 14:47', 0],
#  ['8/21/2016 13:48', 0],
#  ['8/21/2016 12:14', 0],
#  ['8/21/2016 9:35', 4],
#  ['8/20/2016 23:59', 0],
#  ['8/20/2016 22:34', 5],
#  ['8/20/2016 18:54', 0],
#  ['8/20/2016 18:44', 0],
#  ['8/20/2016 18:17', 1],
#  ['8/20/2016 17:51', 0],
#  ['8/20/2016 17:17', 0],
#  ['8/20/2016 16:57', 1],
#  ['8/20/2016 16:56', 1],
#  ['8/20/2016 16:41', 0],
#  ['8/20/2016 15:29', 0],
#  ['8/20/2016 15:18', 0],
#  ['8/20/2016 14:58', 0],
#  ['8/20/2016 13:17', 0],
#  ['8/20/2016 7:57', 1],
#  ['8/20/2016 4:08', 0],
#  ['8/19/2016 23:03', 0],
#  ['8/19/2016 20:30', 0],
#  ['8/19/2016 19:45', 0],
#  ['8/19/2016 18:43', 0],
#  ['8/19/2016 18:24', 1],
#  ['8/19/2016 18:02', 0],
#  ['8/19/2016 16:16', 0],
#  ['8/19/2016 14:58', 18],
#  ['8/19/2016 14:51', 0],
#  ['8/19/2016 14:06', 0],
#  ['8/19/2016 13:56', 0],
#  ['8/19/2016 13:55', 0],
#  ['8/19/2016 13:24', 0],
#  ['8/19/2016 13:14', 0],
#  ['8/19/2016 13:00', 69],
#  ['8/19/2016 12:20', 0],
#  ['8/19/2016 11:57', 10],
#  ['8/19/2016 10:01', 3],
#  ['8/19/2016 8:53', 3],
#  ['8/19/2016 8:44', 3],
#  ['8/19/2016 8:01', 0],
#  ['8/19/2016 1:29', 0],
#  ['8/19/2016 1:04', 0],
#  ['8/19/2016 0:54', 0],
#  ['8/19/2016 0:47', 0],
#  ['8/18/2016 23:41', 0],
#  ['8/18/2016 23:33', 0],
#  ['8/18/2016 20:43', 0],
#  ['8/18/2016 20:28', 0],
#  ['8/18/2016 19:54', 0],
#  ['8/18/2016 18:18', 0],
#  ['8/18/2016 17:57', 0],
#  ['8/18/2016 17:34', 1],
#  ['8/18/2016 17:08', 0],
#  ['8/18/2016 16:02', 0],
#  ['8/18/2016 16:00', 1],
#  ['8/18/2016 15:48', 0],
#  ['8/18/2016 15:46', 0],
#  ['8/18/2016 14:06', 0],
#  ['8/18/2016 13:47', 0],
#  ['8/18/2016 13:11', 23],
#  ['8/18/2016 12:33', 0],
#  ['8/18/2016 12:24', 25],
#  ['8/18/2016 11:28', 0],
#  ['8/18/2016 11:25', 0],
#  ['8/18/2016 10:00', 0],
#  ['8/18/2016 9:46', 30],
#  ['8/18/2016 8:28', 2],
#  ['8/18/2016 6:18', 28],
#  ...]

# %%
len(result_list)
# Out:
# 10158

# %%
result_list[:3]
# Out:
# [['9/26/2016 0:36', 0], ['9/26/2016 0:01', 0], ['9/25/2016 23:44', 0]]
